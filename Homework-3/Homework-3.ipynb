# %% [markdown]
# __Name: Subhiksha Rani ; USC ID: 9907399097__

# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import itertools
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc
from scipy import stats
import statsmodels.api as sm
from sklearn.multiclass import OneVsRestClassifier
from sklearn import svm, datasets
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.preprocessing import label_binarize

# %%
bending1_test_data1 = pd.read_csv("bending1/dataset1.csv", skiprows=4, error_bad_lines=False)
bending1_test_data2 = pd.read_csv("bending1/dataset2.csv", skiprows=4, error_bad_lines=False)

bending1_train_data1 = pd.read_csv("bending1/dataset3.csv", skiprows=4, error_bad_lines=False)
bending1_train_data2 = pd.read_csv("bending1/dataset4.csv", skiprows=4, error_bad_lines=False)
bending1_train_data3 = pd.read_csv("bending1/dataset5.csv", skiprows=4, error_bad_lines=False)
bending1_train_data4 = pd.read_csv("bending1/dataset6.csv", skiprows=4, error_bad_lines=False)
bending1_train_data5 = pd.read_csv("bending1/dataset7.csv", skiprows=4, error_bad_lines=False)

bending2_test_data1 = pd.read_csv("bending2/dataset1.csv", skiprows=4, error_bad_lines=False)
bending2_test_data2 = pd.read_csv("bending2/dataset2.csv", skiprows=4, error_bad_lines=False)

bending2_train_data1 = pd.read_csv("bending2/dataset3.csv", skiprows=4, error_bad_lines=False)
bending2_train_data2 = pd.read_csv("bending2/dataset4.csv", skiprows=4, error_bad_lines=False)
bending2_train_data3 = pd.read_csv("bending2/dataset5.csv", skiprows=4, error_bad_lines=False)
bending2_train_data4 = pd.read_csv("bending2/dataset6.csv", skiprows=4, error_bad_lines=False)

cycling_test_data1 = pd.read_csv("cycling/dataset1.csv", skiprows=4, error_bad_lines=False)
cycling_test_data2 = pd.read_csv("cycling/dataset2.csv", skiprows=4, error_bad_lines=False)
cycling_test_data3 = pd.read_csv("cycling/dataset3.csv", skiprows=4, error_bad_lines=False)

cycling_train_data1 = pd.read_csv("cycling/dataset4.csv", skiprows=4, error_bad_lines=False)
cycling_train_data2 = pd.read_csv("cycling/dataset5.csv", skiprows=4, error_bad_lines=False)
cycling_train_data3 = pd.read_csv("cycling/dataset6.csv", skiprows=4, error_bad_lines=False)
cycling_train_data4 = pd.read_csv("cycling/dataset7.csv", skiprows=4, error_bad_lines=False)
cycling_train_data5 = pd.read_csv("cycling/dataset8.csv", skiprows=4, error_bad_lines=False)
cycling_train_data6 = pd.read_csv("cycling/dataset9.csv", skiprows=4, error_bad_lines=False)
cycling_train_data7 = pd.read_csv("cycling/dataset10.csv", skiprows=4, error_bad_lines=False)
cycling_train_data8 = pd.read_csv("cycling/dataset11.csv", skiprows=4, error_bad_lines=False)
cycling_train_data9 = pd.read_csv("cycling/dataset12.csv", skiprows=4, error_bad_lines=False)
cycling_train_data10 = pd.read_csv("cycling/dataset13.csv", skiprows=4, error_bad_lines=False)
cycling_train_data11 = pd.read_csv("cycling/dataset14.csv", skiprows=4, error_bad_lines=False)
cycling_train_data12 = pd.read_csv("cycling/dataset15.csv", skiprows=4, error_bad_lines=False)

lying_test_data1 = pd.read_csv("lying/dataset1.csv", skiprows=4, error_bad_lines=False)
lying_test_data2 = pd.read_csv("lying/dataset2.csv", skiprows=4, error_bad_lines=False)
lying_test_data3 = pd.read_csv("lying/dataset3.csv", skiprows=4, error_bad_lines=False)

lying_train_data1 = pd.read_csv("lying/dataset4.csv", skiprows=4, error_bad_lines=False)
lying_train_data2 = pd.read_csv("lying/dataset5.csv", skiprows=4, error_bad_lines=False)
lying_train_data3 = pd.read_csv("lying/dataset6.csv", skiprows=4, error_bad_lines=False)
lying_train_data4 = pd.read_csv("lying/dataset7.csv", skiprows=4, error_bad_lines=False)
lying_train_data5 = pd.read_csv("lying/dataset8.csv", skiprows=4, error_bad_lines=False)
lying_train_data6 = pd.read_csv("lying/dataset9.csv", skiprows=4, error_bad_lines=False)
lying_train_data7 = pd.read_csv("lying/dataset10.csv", skiprows=4, error_bad_lines=False)
lying_train_data8 = pd.read_csv("lying/dataset11.csv", skiprows=4, error_bad_lines=False)
lying_train_data9 = pd.read_csv("lying/dataset12.csv", skiprows=4, error_bad_lines=False)
lying_train_data10 = pd.read_csv("lying/dataset13.csv", skiprows=4, error_bad_lines=False)
lying_train_data11 = pd.read_csv("lying/dataset14.csv", skiprows=4, error_bad_lines=False)
lying_train_data12 = pd.read_csv("lying/dataset15.csv", skiprows=4, error_bad_lines=False)

sitting_test_data1 = pd.read_csv("sitting/dataset1.csv", skiprows=4, error_bad_lines=False)
sitting_test_data2 = pd.read_csv("sitting/dataset2.csv", skiprows=4, error_bad_lines=False)
sitting_test_data3 = pd.read_csv("sitting/dataset3.csv", skiprows=4, error_bad_lines=False)

sitting_train_data1 = pd.read_csv("sitting/dataset4.csv", skiprows=4, error_bad_lines=False)
sitting_train_data2 = pd.read_csv("sitting/dataset5.csv", skiprows=4, error_bad_lines=False)
sitting_train_data3 = pd.read_csv("sitting/dataset6.csv", skiprows=4, error_bad_lines=False)
sitting_train_data4 = pd.read_csv("sitting/dataset7.csv", skiprows=4, error_bad_lines=False)
sitting_train_data5 = pd.read_csv("sitting/dataset8.csv", skiprows=4, error_bad_lines=False)
sitting_train_data6 = pd.read_csv("sitting/dataset9.csv", skiprows=4, error_bad_lines=False)
sitting_train_data7 = pd.read_csv("sitting/dataset10.csv", skiprows=4, error_bad_lines=False)
sitting_train_data8 = pd.read_csv("sitting/dataset11.csv", skiprows=4, error_bad_lines=False)
sitting_train_data9 = pd.read_csv("sitting/dataset12.csv", skiprows=4, error_bad_lines=False)
sitting_train_data10 = pd.read_csv("sitting/dataset13.csv", skiprows=4, error_bad_lines=False)
sitting_train_data11 = pd.read_csv("sitting/dataset14.csv", skiprows=4, error_bad_lines=False)
sitting_train_data12 = pd.read_csv("sitting/dataset15.csv", skiprows=4, error_bad_lines=False)

standing_test_data1 = pd.read_csv("standing/dataset1.csv", skiprows=4, error_bad_lines=False)
standing_test_data2 = pd.read_csv("standing/dataset2.csv", skiprows=4, error_bad_lines=False)
standing_test_data3 = pd.read_csv("standing/dataset3.csv", skiprows=4, error_bad_lines=False)

standing_train_data1 = pd.read_csv("standing/dataset4.csv", skiprows=4, error_bad_lines=False)
standing_train_data2 = pd.read_csv("standing/dataset5.csv", skiprows=4, error_bad_lines=False)
standing_train_data3 = pd.read_csv("standing/dataset6.csv", skiprows=4, error_bad_lines=False)
standing_train_data4 = pd.read_csv("standing/dataset7.csv", skiprows=4, error_bad_lines=False)
standing_train_data5 = pd.read_csv("standing/dataset8.csv", skiprows=4, error_bad_lines=False)
standing_train_data6 = pd.read_csv("standing/dataset9.csv", skiprows=4, error_bad_lines=False)
standing_train_data7 = pd.read_csv("standing/dataset10.csv", skiprows=4, error_bad_lines=False)
standing_train_data8 = pd.read_csv("standing/dataset11.csv", skiprows=4, error_bad_lines=False)
standing_train_data9 = pd.read_csv("standing/dataset12.csv", skiprows=4, error_bad_lines=False)
standing_train_data10 = pd.read_csv("standing/dataset13.csv", skiprows=4, error_bad_lines=False)
standing_train_data11 = pd.read_csv("standing/dataset14.csv", skiprows=4, error_bad_lines=False)
standing_train_data12 = pd.read_csv("standing/dataset15.csv", skiprows=4, error_bad_lines=False)

walking_test_data1 = pd.read_csv("walking/dataset1.csv", skiprows=4, error_bad_lines=False)
walking_test_data2 = pd.read_csv("walking/dataset2.csv", skiprows=4, error_bad_lines=False)
walking_test_data3 = pd.read_csv("walking/dataset3.csv", skiprows=4, error_bad_lines=False)

walking_train_data1 = pd.read_csv("walking/dataset4.csv", skiprows=4, error_bad_lines=False)
walking_train_data2 = pd.read_csv("walking/dataset5.csv", skiprows=4, error_bad_lines=False)
walking_train_data3 = pd.read_csv("walking/dataset6.csv", skiprows=4, error_bad_lines=False)
walking_train_data4 = pd.read_csv("walking/dataset7.csv", skiprows=4, error_bad_lines=False)
walking_train_data5 = pd.read_csv("walking/dataset8.csv", skiprows=4, error_bad_lines=False)
walking_train_data6 = pd.read_csv("walking/dataset9.csv", skiprows=4, error_bad_lines=False)
walking_train_data7 = pd.read_csv("walking/dataset10.csv", skiprows=4, error_bad_lines=False)
walking_train_data8 = pd.read_csv("walking/dataset11.csv", skiprows=4, error_bad_lines=False)
walking_train_data9 = pd.read_csv("walking/dataset12.csv", skiprows=4, error_bad_lines=False)
walking_train_data10 = pd.read_csv("walking/dataset13.csv", skiprows=4, error_bad_lines=False)
walking_train_data11 = pd.read_csv("walking/dataset14.csv", skiprows=4, error_bad_lines=False)
walking_train_data12 = pd.read_csv("walking/dataset15.csv", skiprows=4, error_bad_lines=False)
# Out:
# b'Skipping line 485: expected 7 fields, saw 8\n'
# b'Skipping line 485: expected 7 fields, saw 8\n'

# %%
instance = []
for i in range(1,89):
    instance = np.append(instance,i)

min1 = [bending1_test_data1['avg_rss12'].min(),bending1_test_data2['avg_rss12'].min(),bending1_train_data1['avg_rss12'].min(),bending1_train_data2['avg_rss12'].min(),bending1_train_data3['avg_rss12'].min(),bending1_train_data4['avg_rss12'].min(),bending1_train_data5['avg_rss12'].min(),bending2_test_data1['avg_rss12'].min(),bending2_test_data2['avg_rss12'].min(),bending2_train_data1['avg_rss12'].min(),bending2_train_data2['avg_rss12'].min(),bending2_train_data3['avg_rss12'].min(),bending2_train_data4['avg_rss12'].min(),cycling_test_data1['avg_rss12'].min(),cycling_test_data2['avg_rss12'].min(),cycling_test_data3['avg_rss12'].min(),cycling_train_data1['avg_rss12'].min(),cycling_train_data2['avg_rss12'].min(),cycling_train_data3['avg_rss12'].min(),cycling_train_data4['avg_rss12'].min(),cycling_train_data5['avg_rss12'].min(),cycling_train_data6['avg_rss12'].min(),cycling_train_data7['avg_rss12'].min(),cycling_train_data8['avg_rss12'].min(),cycling_train_data9['avg_rss12'].min(),cycling_train_data10['avg_rss12'].min(),cycling_train_data11['avg_rss12'].min(),cycling_train_data12['avg_rss12'].min(),lying_test_data1['avg_rss12'].min(),lying_test_data2['avg_rss12'].min(),lying_test_data3['avg_rss12'].min(),lying_train_data1['avg_rss12'].min(),lying_train_data2['avg_rss12'].min(),lying_train_data3['avg_rss12'].min(),lying_train_data4['avg_rss12'].min(),lying_train_data5['avg_rss12'].min(),lying_train_data6['avg_rss12'].min(),lying_train_data7['avg_rss12'].min(),lying_train_data8['avg_rss12'].min(),lying_train_data9['avg_rss12'].min(),lying_train_data10['avg_rss12'].min(),lying_train_data11['avg_rss12'].min(),lying_train_data12['avg_rss12'].min(),sitting_test_data1['avg_rss12'].min(),sitting_test_data2['avg_rss12'].min(),sitting_test_data3['avg_rss12'].min(),sitting_train_data1['avg_rss12'].min(),sitting_train_data2['avg_rss12'].min(),sitting_train_data3['avg_rss12'].min(),sitting_train_data4['avg_rss12'].min(),sitting_train_data5['avg_rss12'].min(),sitting_train_data6['avg_rss12'].min(),sitting_train_data7['avg_rss12'].min(),sitting_train_data8['avg_rss12'].min(),sitting_train_data9['avg_rss12'].min(),sitting_train_data10['avg_rss12'].min(),sitting_train_data11['avg_rss12'].min(),sitting_train_data12['avg_rss12'].min(),standing_test_data1['avg_rss12'].min(),standing_test_data2['avg_rss12'].min(),standing_test_data3['avg_rss12'].min(),standing_train_data1['avg_rss12'].min(),standing_train_data2['avg_rss12'].min(),standing_train_data3['avg_rss12'].min(),standing_train_data4['avg_rss12'].min(),standing_train_data5['avg_rss12'].min(),standing_train_data6['avg_rss12'].min(),standing_train_data7['avg_rss12'].min(),standing_train_data8['avg_rss12'].min(),standing_train_data9['avg_rss12'].min(),standing_train_data10['avg_rss12'].min(),standing_train_data11['avg_rss12'].min(),standing_train_data12['avg_rss12'].min(),walking_test_data1['avg_rss12'].min(),walking_test_data2['avg_rss12'].min(),walking_test_data3['avg_rss12'].min(),walking_train_data1['avg_rss12'].min(),walking_train_data2['avg_rss12'].min(),walking_train_data3['avg_rss12'].min(),walking_train_data4['avg_rss12'].min(),walking_train_data5['avg_rss12'].min(),walking_train_data6['avg_rss12'].min(),walking_train_data7['avg_rss12'].min(),walking_train_data8['avg_rss12'].min(),walking_train_data9['avg_rss12'].min(),walking_train_data10['avg_rss12'].min(),walking_train_data11['avg_rss12'].min(),walking_train_data12['avg_rss12'].min()]

max1 = [bending1_test_data1['avg_rss12'].max(),bending1_test_data2['avg_rss12'].max(),bending1_train_data1['avg_rss12'].max(),bending1_train_data2['avg_rss12'].max(),bending1_train_data3['avg_rss12'].max(),bending1_train_data4['avg_rss12'].max(),bending1_train_data5['avg_rss12'].max(),bending2_test_data1['avg_rss12'].max(),bending2_test_data2['avg_rss12'].max(),bending2_train_data1['avg_rss12'].max(),bending2_train_data2['avg_rss12'].max(),bending2_train_data3['avg_rss12'].max(),bending2_train_data4['avg_rss12'].max(),cycling_test_data1['avg_rss12'].max(),cycling_test_data2['avg_rss12'].max(),cycling_test_data3['avg_rss12'].max(),cycling_train_data1['avg_rss12'].max(),cycling_train_data2['avg_rss12'].max(),cycling_train_data3['avg_rss12'].max(),cycling_train_data4['avg_rss12'].max(),cycling_train_data5['avg_rss12'].max(),cycling_train_data6['avg_rss12'].max(),cycling_train_data7['avg_rss12'].max(),cycling_train_data8['avg_rss12'].max(),cycling_train_data9['avg_rss12'].max(),cycling_train_data10['avg_rss12'].max(),cycling_train_data11['avg_rss12'].max(),cycling_train_data12['avg_rss12'].max(),lying_test_data1['avg_rss12'].max(),lying_test_data2['avg_rss12'].max(),lying_test_data3['avg_rss12'].max(),lying_train_data1['avg_rss12'].max(),lying_train_data2['avg_rss12'].max(),lying_train_data3['avg_rss12'].max(),lying_train_data4['avg_rss12'].max(),lying_train_data5['avg_rss12'].max(),lying_train_data6['avg_rss12'].max(),lying_train_data7['avg_rss12'].max(),lying_train_data8['avg_rss12'].max(),lying_train_data9['avg_rss12'].max(),lying_train_data10['avg_rss12'].max(),lying_train_data11['avg_rss12'].max(),lying_train_data12['avg_rss12'].max(),sitting_test_data1['avg_rss12'].max(),sitting_test_data2['avg_rss12'].max(),sitting_test_data3['avg_rss12'].max(),sitting_train_data1['avg_rss12'].max(),sitting_train_data2['avg_rss12'].max(),sitting_train_data3['avg_rss12'].max(),sitting_train_data4['avg_rss12'].max(),sitting_train_data5['avg_rss12'].max(),sitting_train_data6['avg_rss12'].max(),sitting_train_data7['avg_rss12'].max(),sitting_train_data8['avg_rss12'].max(),sitting_train_data9['avg_rss12'].max(),sitting_train_data10['avg_rss12'].max(),sitting_train_data11['avg_rss12'].max(),sitting_train_data12['avg_rss12'].max(),standing_test_data1['avg_rss12'].max(),standing_test_data2['avg_rss12'].max(),standing_test_data3['avg_rss12'].max(),standing_train_data1['avg_rss12'].max(),standing_train_data2['avg_rss12'].max(),standing_train_data3['avg_rss12'].max(),standing_train_data4['avg_rss12'].max(),standing_train_data5['avg_rss12'].max(),standing_train_data6['avg_rss12'].max(),standing_train_data7['avg_rss12'].max(),standing_train_data8['avg_rss12'].max(),standing_train_data9['avg_rss12'].max(),standing_train_data10['avg_rss12'].max(),standing_train_data11['avg_rss12'].max(),standing_train_data12['avg_rss12'].max(),walking_test_data1['avg_rss12'].max(),walking_test_data2['avg_rss12'].max(),walking_test_data3['avg_rss12'].max(),walking_train_data1['avg_rss12'].max(),walking_train_data2['avg_rss12'].max(),walking_train_data3['avg_rss12'].max(),walking_train_data4['avg_rss12'].max(),walking_train_data5['avg_rss12'].max(),walking_train_data6['avg_rss12'].max(),walking_train_data7['avg_rss12'].max(),walking_train_data8['avg_rss12'].max(),walking_train_data9['avg_rss12'].max(),walking_train_data10['avg_rss12'].max(),walking_train_data11['avg_rss12'].max(),walking_train_data12['avg_rss12'].max()]

mean1 = [bending1_test_data1['avg_rss12'].mean(),bending1_test_data2['avg_rss12'].mean(),bending1_train_data1['avg_rss12'].mean(),bending1_train_data2['avg_rss12'].mean(),bending1_train_data3['avg_rss12'].mean(),bending1_train_data4['avg_rss12'].mean(),bending1_train_data5['avg_rss12'].mean(),bending2_test_data1['avg_rss12'].mean(),bending2_test_data2['avg_rss12'].mean(),bending2_train_data1['avg_rss12'].mean(),bending2_train_data2['avg_rss12'].mean(),bending2_train_data3['avg_rss12'].mean(),bending2_train_data4['avg_rss12'].mean(),cycling_test_data1['avg_rss12'].mean(),cycling_test_data2['avg_rss12'].mean(),cycling_test_data3['avg_rss12'].mean(),cycling_train_data1['avg_rss12'].mean(),cycling_train_data2['avg_rss12'].mean(),cycling_train_data3['avg_rss12'].mean(),cycling_train_data4['avg_rss12'].mean(),cycling_train_data5['avg_rss12'].mean(),cycling_train_data6['avg_rss12'].mean(),cycling_train_data7['avg_rss12'].mean(),cycling_train_data8['avg_rss12'].mean(),cycling_train_data9['avg_rss12'].mean(),cycling_train_data10['avg_rss12'].mean(),cycling_train_data11['avg_rss12'].mean(),cycling_train_data12['avg_rss12'].mean(),lying_test_data1['avg_rss12'].mean(),lying_test_data2['avg_rss12'].mean(),lying_test_data3['avg_rss12'].mean(),lying_train_data1['avg_rss12'].mean(),lying_train_data2['avg_rss12'].mean(),lying_train_data3['avg_rss12'].mean(),lying_train_data4['avg_rss12'].mean(),lying_train_data5['avg_rss12'].mean(),lying_train_data6['avg_rss12'].mean(),lying_train_data7['avg_rss12'].mean(),lying_train_data8['avg_rss12'].mean(),lying_train_data9['avg_rss12'].mean(),lying_train_data10['avg_rss12'].mean(),lying_train_data11['avg_rss12'].mean(),lying_train_data12['avg_rss12'].mean(),sitting_test_data1['avg_rss12'].mean(),sitting_test_data2['avg_rss12'].mean(),sitting_test_data3['avg_rss12'].mean(),sitting_train_data1['avg_rss12'].mean(),sitting_train_data2['avg_rss12'].mean(),sitting_train_data3['avg_rss12'].mean(),sitting_train_data4['avg_rss12'].mean(),sitting_train_data5['avg_rss12'].mean(),sitting_train_data6['avg_rss12'].mean(),sitting_train_data7['avg_rss12'].mean(),sitting_train_data8['avg_rss12'].mean(),sitting_train_data9['avg_rss12'].mean(),sitting_train_data10['avg_rss12'].mean(),sitting_train_data11['avg_rss12'].mean(),sitting_train_data12['avg_rss12'].mean(),standing_test_data1['avg_rss12'].mean(),standing_test_data2['avg_rss12'].mean(),standing_test_data3['avg_rss12'].mean(),standing_train_data1['avg_rss12'].mean(),standing_train_data2['avg_rss12'].mean(),standing_train_data3['avg_rss12'].mean(),standing_train_data4['avg_rss12'].mean(),standing_train_data5['avg_rss12'].mean(),standing_train_data6['avg_rss12'].mean(),standing_train_data7['avg_rss12'].mean(),standing_train_data8['avg_rss12'].mean(),standing_train_data9['avg_rss12'].mean(),standing_train_data10['avg_rss12'].mean(),standing_train_data11['avg_rss12'].mean(),standing_train_data12['avg_rss12'].mean(),walking_test_data1['avg_rss12'].mean(),walking_test_data2['avg_rss12'].mean(),walking_test_data3['avg_rss12'].mean(),walking_train_data1['avg_rss12'].mean(),walking_train_data2['avg_rss12'].mean(),walking_train_data3['avg_rss12'].mean(),walking_train_data4['avg_rss12'].mean(),walking_train_data5['avg_rss12'].mean(),walking_train_data6['avg_rss12'].mean(),walking_train_data7['avg_rss12'].mean(),walking_train_data8['avg_rss12'].mean(),walking_train_data9['avg_rss12'].mean(),walking_train_data10['avg_rss12'].mean(),walking_train_data11['avg_rss12'].mean(),walking_train_data12['avg_rss12'].mean()]

median1 = [bending1_test_data1['avg_rss12'].median(),bending1_test_data2['avg_rss12'].median(),bending1_train_data1['avg_rss12'].median(),bending1_train_data2['avg_rss12'].median(),bending1_train_data3['avg_rss12'].median(),bending1_train_data4['avg_rss12'].median(),bending1_train_data5['avg_rss12'].median(),bending2_test_data1['avg_rss12'].median(),bending2_test_data2['avg_rss12'].median(),bending2_train_data1['avg_rss12'].median(),bending2_train_data2['avg_rss12'].median(),bending2_train_data3['avg_rss12'].median(),bending2_train_data4['avg_rss12'].median(),cycling_test_data1['avg_rss12'].median(),cycling_test_data2['avg_rss12'].median(),cycling_test_data3['avg_rss12'].median(),cycling_train_data1['avg_rss12'].median(),cycling_train_data2['avg_rss12'].median(),cycling_train_data3['avg_rss12'].median(),cycling_train_data4['avg_rss12'].median(),cycling_train_data5['avg_rss12'].median(),cycling_train_data6['avg_rss12'].median(),cycling_train_data7['avg_rss12'].median(),cycling_train_data8['avg_rss12'].median(),cycling_train_data9['avg_rss12'].median(),cycling_train_data10['avg_rss12'].median(),cycling_train_data11['avg_rss12'].median(),cycling_train_data12['avg_rss12'].median(),lying_test_data1['avg_rss12'].median(),lying_test_data2['avg_rss12'].median(),lying_test_data3['avg_rss12'].median(),lying_train_data1['avg_rss12'].median(),lying_train_data2['avg_rss12'].median(),lying_train_data3['avg_rss12'].median(),lying_train_data4['avg_rss12'].median(),lying_train_data5['avg_rss12'].median(),lying_train_data6['avg_rss12'].median(),lying_train_data7['avg_rss12'].median(),lying_train_data8['avg_rss12'].median(),lying_train_data9['avg_rss12'].median(),lying_train_data10['avg_rss12'].median(),lying_train_data11['avg_rss12'].median(),lying_train_data12['avg_rss12'].median(),sitting_test_data1['avg_rss12'].median(),sitting_test_data2['avg_rss12'].median(),sitting_test_data3['avg_rss12'].median(),sitting_train_data1['avg_rss12'].median(),sitting_train_data2['avg_rss12'].median(),sitting_train_data3['avg_rss12'].median(),sitting_train_data4['avg_rss12'].median(),sitting_train_data5['avg_rss12'].median(),sitting_train_data6['avg_rss12'].median(),sitting_train_data7['avg_rss12'].median(),sitting_train_data8['avg_rss12'].median(),sitting_train_data9['avg_rss12'].median(),sitting_train_data10['avg_rss12'].median(),sitting_train_data11['avg_rss12'].median(),sitting_train_data12['avg_rss12'].median(),standing_test_data1['avg_rss12'].median(),standing_test_data2['avg_rss12'].median(),standing_test_data3['avg_rss12'].median(),standing_train_data1['avg_rss12'].median(),standing_train_data2['avg_rss12'].median(),standing_train_data3['avg_rss12'].median(),standing_train_data4['avg_rss12'].median(),standing_train_data5['avg_rss12'].median(),standing_train_data6['avg_rss12'].median(),standing_train_data7['avg_rss12'].median(),standing_train_data8['avg_rss12'].median(),standing_train_data9['avg_rss12'].median(),standing_train_data10['avg_rss12'].median(),standing_train_data11['avg_rss12'].median(),standing_train_data12['avg_rss12'].median(),walking_test_data1['avg_rss12'].median(),walking_test_data2['avg_rss12'].median(),walking_test_data3['avg_rss12'].median(),walking_train_data1['avg_rss12'].median(),walking_train_data2['avg_rss12'].median(),walking_train_data3['avg_rss12'].median(),walking_train_data4['avg_rss12'].median(),walking_train_data5['avg_rss12'].median(),walking_train_data6['avg_rss12'].median(),walking_train_data7['avg_rss12'].median(),walking_train_data8['avg_rss12'].median(),walking_train_data9['avg_rss12'].median(),walking_train_data10['avg_rss12'].median(),walking_train_data11['avg_rss12'].median(),walking_train_data12['avg_rss12'].median()]

sd1 = [bending1_test_data1['avg_rss12'].std(),bending1_test_data2['avg_rss12'].std(),bending1_train_data1['avg_rss12'].std(),bending1_train_data2['avg_rss12'].std(),bending1_train_data3['avg_rss12'].std(),bending1_train_data4['avg_rss12'].std(),bending1_train_data5['avg_rss12'].std(),bending2_test_data1['avg_rss12'].std(),bending2_test_data2['avg_rss12'].std(),bending2_train_data1['avg_rss12'].std(),bending2_train_data2['avg_rss12'].std(),bending2_train_data3['avg_rss12'].std(),bending2_train_data4['avg_rss12'].std(),cycling_test_data1['avg_rss12'].std(),cycling_test_data2['avg_rss12'].std(),cycling_test_data3['avg_rss12'].std(),cycling_train_data1['avg_rss12'].std(),cycling_train_data2['avg_rss12'].std(),cycling_train_data3['avg_rss12'].std(),cycling_train_data4['avg_rss12'].std(),cycling_train_data5['avg_rss12'].std(),cycling_train_data6['avg_rss12'].std(),cycling_train_data7['avg_rss12'].std(),cycling_train_data8['avg_rss12'].std(),cycling_train_data9['avg_rss12'].std(),cycling_train_data10['avg_rss12'].std(),cycling_train_data11['avg_rss12'].std(),cycling_train_data12['avg_rss12'].std(),lying_test_data1['avg_rss12'].std(),lying_test_data2['avg_rss12'].std(),lying_test_data3['avg_rss12'].std(),lying_train_data1['avg_rss12'].std(),lying_train_data2['avg_rss12'].std(),lying_train_data3['avg_rss12'].std(),lying_train_data4['avg_rss12'].std(),lying_train_data5['avg_rss12'].std(),lying_train_data6['avg_rss12'].std(),lying_train_data7['avg_rss12'].std(),lying_train_data8['avg_rss12'].std(),lying_train_data9['avg_rss12'].std(),lying_train_data10['avg_rss12'].std(),lying_train_data11['avg_rss12'].std(),lying_train_data12['avg_rss12'].std(),sitting_test_data1['avg_rss12'].std(),sitting_test_data2['avg_rss12'].std(),sitting_test_data3['avg_rss12'].std(),sitting_train_data1['avg_rss12'].std(),sitting_train_data2['avg_rss12'].std(),sitting_train_data3['avg_rss12'].std(),sitting_train_data4['avg_rss12'].std(),sitting_train_data5['avg_rss12'].std(),sitting_train_data6['avg_rss12'].std(),sitting_train_data7['avg_rss12'].std(),sitting_train_data8['avg_rss12'].std(),sitting_train_data9['avg_rss12'].std(),sitting_train_data10['avg_rss12'].std(),sitting_train_data11['avg_rss12'].std(),sitting_train_data12['avg_rss12'].std(),standing_test_data1['avg_rss12'].std(),standing_test_data2['avg_rss12'].std(),standing_test_data3['avg_rss12'].std(),standing_train_data1['avg_rss12'].std(),standing_train_data2['avg_rss12'].std(),standing_train_data3['avg_rss12'].std(),standing_train_data4['avg_rss12'].std(),standing_train_data5['avg_rss12'].std(),standing_train_data6['avg_rss12'].std(),standing_train_data7['avg_rss12'].std(),standing_train_data8['avg_rss12'].std(),standing_train_data9['avg_rss12'].std(),standing_train_data10['avg_rss12'].std(),standing_train_data11['avg_rss12'].std(),standing_train_data12['avg_rss12'].std(),walking_test_data1['avg_rss12'].std(),walking_test_data2['avg_rss12'].std(),walking_test_data3['avg_rss12'].std(),walking_train_data1['avg_rss12'].std(),walking_train_data2['avg_rss12'].std(),walking_train_data3['avg_rss12'].std(),walking_train_data4['avg_rss12'].std(),walking_train_data5['avg_rss12'].std(),walking_train_data6['avg_rss12'].std(),walking_train_data7['avg_rss12'].std(),walking_train_data8['avg_rss12'].std(),walking_train_data9['avg_rss12'].std(),walking_train_data10['avg_rss12'].std(),walking_train_data11['avg_rss12'].std(),walking_train_data12['avg_rss12'].std()]

quart1_1 = [bending1_test_data1['avg_rss12'].quantile(0.25),bending1_test_data2['avg_rss12'].quantile(0.25),bending1_train_data1['avg_rss12'].quantile(0.25),bending1_train_data2['avg_rss12'].quantile(0.25),bending1_train_data3['avg_rss12'].quantile(0.25),bending1_train_data4['avg_rss12'].quantile(0.25),bending1_train_data5['avg_rss12'].quantile(0.25),bending2_test_data1['avg_rss12'].quantile(0.25),bending2_test_data2['avg_rss12'].quantile(0.25),bending2_train_data1['avg_rss12'].quantile(0.25),bending2_train_data2['avg_rss12'].quantile(0.25),bending2_train_data3['avg_rss12'].quantile(0.25),bending2_train_data4['avg_rss12'].quantile(0.25),cycling_test_data1['avg_rss12'].quantile(0.25),cycling_test_data2['avg_rss12'].quantile(0.25),cycling_test_data3['avg_rss12'].quantile(0.25),cycling_train_data1['avg_rss12'].quantile(0.25),cycling_train_data2['avg_rss12'].quantile(0.25),cycling_train_data3['avg_rss12'].quantile(0.25),cycling_train_data4['avg_rss12'].quantile(0.25),cycling_train_data5['avg_rss12'].quantile(0.25),cycling_train_data6['avg_rss12'].quantile(0.25),cycling_train_data7['avg_rss12'].quantile(0.25),cycling_train_data8['avg_rss12'].quantile(0.25),cycling_train_data9['avg_rss12'].quantile(0.25),cycling_train_data10['avg_rss12'].quantile(0.25),cycling_train_data11['avg_rss12'].quantile(0.25),cycling_train_data12['avg_rss12'].quantile(0.25),lying_test_data1['avg_rss12'].quantile(0.25),lying_test_data2['avg_rss12'].quantile(0.25),lying_test_data3['avg_rss12'].quantile(0.25),lying_train_data1['avg_rss12'].quantile(0.25),lying_train_data2['avg_rss12'].quantile(0.25),lying_train_data3['avg_rss12'].quantile(0.25),lying_train_data4['avg_rss12'].quantile(0.25),lying_train_data5['avg_rss12'].quantile(0.25),lying_train_data6['avg_rss12'].quantile(0.25),lying_train_data7['avg_rss12'].quantile(0.25),lying_train_data8['avg_rss12'].quantile(0.25),lying_train_data9['avg_rss12'].quantile(0.25),lying_train_data10['avg_rss12'].quantile(0.25),lying_train_data11['avg_rss12'].quantile(0.25),lying_train_data12['avg_rss12'].quantile(0.25),sitting_test_data1['avg_rss12'].quantile(0.25),sitting_test_data2['avg_rss12'].quantile(0.25),sitting_test_data3['avg_rss12'].quantile(0.25),sitting_train_data1['avg_rss12'].quantile(0.25),sitting_train_data2['avg_rss12'].quantile(0.25),sitting_train_data3['avg_rss12'].quantile(0.25),sitting_train_data4['avg_rss12'].quantile(0.25),sitting_train_data5['avg_rss12'].quantile(0.25),sitting_train_data6['avg_rss12'].quantile(0.25),sitting_train_data7['avg_rss12'].quantile(0.25),sitting_train_data8['avg_rss12'].quantile(0.25),sitting_train_data9['avg_rss12'].quantile(0.25),sitting_train_data10['avg_rss12'].quantile(0.25),sitting_train_data11['avg_rss12'].quantile(0.25),sitting_train_data12['avg_rss12'].quantile(0.25),standing_test_data1['avg_rss12'].quantile(0.25),standing_test_data2['avg_rss12'].quantile(0.25),standing_test_data3['avg_rss12'].quantile(0.25),standing_train_data1['avg_rss12'].quantile(0.25),standing_train_data2['avg_rss12'].quantile(0.25),standing_train_data3['avg_rss12'].quantile(0.25),standing_train_data4['avg_rss12'].quantile(0.25),standing_train_data5['avg_rss12'].quantile(0.25),standing_train_data6['avg_rss12'].quantile(0.25),standing_train_data7['avg_rss12'].quantile(0.25),standing_train_data8['avg_rss12'].quantile(0.25),standing_train_data9['avg_rss12'].quantile(0.25),standing_train_data10['avg_rss12'].quantile(0.25),standing_train_data11['avg_rss12'].quantile(0.25),standing_train_data12['avg_rss12'].quantile(0.25),walking_test_data1['avg_rss12'].quantile(0.25),walking_test_data2['avg_rss12'].quantile(0.25),walking_test_data3['avg_rss12'].quantile(0.25),walking_train_data1['avg_rss12'].quantile(0.25),walking_train_data2['avg_rss12'].quantile(0.25),walking_train_data3['avg_rss12'].quantile(0.25),walking_train_data4['avg_rss12'].quantile(0.25),walking_train_data5['avg_rss12'].quantile(0.25),walking_train_data6['avg_rss12'].quantile(0.25),walking_train_data7['avg_rss12'].quantile(0.25),walking_train_data8['avg_rss12'].quantile(0.25),walking_train_data9['avg_rss12'].quantile(0.25),walking_train_data10['avg_rss12'].quantile(0.25),walking_train_data11['avg_rss12'].quantile(0.25),walking_train_data12['avg_rss12'].quantile(0.25)]

quart3_1 = [bending1_test_data1['avg_rss12'].quantile(0.75),bending1_test_data2['avg_rss12'].quantile(0.75),bending1_train_data1['avg_rss12'].quantile(0.75),bending1_train_data2['avg_rss12'].quantile(0.75),bending1_train_data3['avg_rss12'].quantile(0.75),bending1_train_data4['avg_rss12'].quantile(0.75),bending1_train_data5['avg_rss12'].quantile(0.75),bending2_test_data1['avg_rss12'].quantile(0.75),bending2_test_data2['avg_rss12'].quantile(0.75),bending2_train_data1['avg_rss12'].quantile(0.75),bending2_train_data2['avg_rss12'].quantile(0.75),bending2_train_data3['avg_rss12'].quantile(0.75),bending2_train_data4['avg_rss12'].quantile(0.75),cycling_test_data1['avg_rss12'].quantile(0.75),cycling_test_data2['avg_rss12'].quantile(0.75),cycling_test_data3['avg_rss12'].quantile(0.75),cycling_train_data1['avg_rss12'].quantile(0.75),cycling_train_data2['avg_rss12'].quantile(0.75),cycling_train_data3['avg_rss12'].quantile(0.75),cycling_train_data4['avg_rss12'].quantile(0.75),cycling_train_data5['avg_rss12'].quantile(0.75),cycling_train_data6['avg_rss12'].quantile(0.75),cycling_train_data7['avg_rss12'].quantile(0.75),cycling_train_data8['avg_rss12'].quantile(0.75),cycling_train_data9['avg_rss12'].quantile(0.75),cycling_train_data10['avg_rss12'].quantile(0.75),cycling_train_data11['avg_rss12'].quantile(0.75),cycling_train_data12['avg_rss12'].quantile(0.75),lying_test_data1['avg_rss12'].quantile(0.75),lying_test_data2['avg_rss12'].quantile(0.75),lying_test_data3['avg_rss12'].quantile(0.75),lying_train_data1['avg_rss12'].quantile(0.75),lying_train_data2['avg_rss12'].quantile(0.75),lying_train_data3['avg_rss12'].quantile(0.75),lying_train_data4['avg_rss12'].quantile(0.75),lying_train_data5['avg_rss12'].quantile(0.75),lying_train_data6['avg_rss12'].quantile(0.75),lying_train_data7['avg_rss12'].quantile(0.75),lying_train_data8['avg_rss12'].quantile(0.75),lying_train_data9['avg_rss12'].quantile(0.75),lying_train_data10['avg_rss12'].quantile(0.75),lying_train_data11['avg_rss12'].quantile(0.75),lying_train_data12['avg_rss12'].quantile(0.75),sitting_test_data1['avg_rss12'].quantile(0.75),sitting_test_data2['avg_rss12'].quantile(0.75),sitting_test_data3['avg_rss12'].quantile(0.75),sitting_train_data1['avg_rss12'].quantile(0.75),sitting_train_data2['avg_rss12'].quantile(0.75),sitting_train_data3['avg_rss12'].quantile(0.75),sitting_train_data4['avg_rss12'].quantile(0.75),sitting_train_data5['avg_rss12'].quantile(0.75),sitting_train_data6['avg_rss12'].quantile(0.75),sitting_train_data7['avg_rss12'].quantile(0.75),sitting_train_data8['avg_rss12'].quantile(0.75),sitting_train_data9['avg_rss12'].quantile(0.75),sitting_train_data10['avg_rss12'].quantile(0.75),sitting_train_data11['avg_rss12'].quantile(0.75),sitting_train_data12['avg_rss12'].quantile(0.75),standing_test_data1['avg_rss12'].quantile(0.75),standing_test_data2['avg_rss12'].quantile(0.75),standing_test_data3['avg_rss12'].quantile(0.75),standing_train_data1['avg_rss12'].quantile(0.75),standing_train_data2['avg_rss12'].quantile(0.75),standing_train_data3['avg_rss12'].quantile(0.75),standing_train_data4['avg_rss12'].quantile(0.75),standing_train_data5['avg_rss12'].quantile(0.75),standing_train_data6['avg_rss12'].quantile(0.75),standing_train_data7['avg_rss12'].quantile(0.75),standing_train_data8['avg_rss12'].quantile(0.75),standing_train_data9['avg_rss12'].quantile(0.75),standing_train_data10['avg_rss12'].quantile(0.75),standing_train_data11['avg_rss12'].quantile(0.75),standing_train_data12['avg_rss12'].quantile(0.75),walking_test_data1['avg_rss12'].quantile(0.75),walking_test_data2['avg_rss12'].quantile(0.75),walking_test_data3['avg_rss12'].quantile(0.75),walking_train_data1['avg_rss12'].quantile(0.75),walking_train_data2['avg_rss12'].quantile(0.75),walking_train_data3['avg_rss12'].quantile(0.75),walking_train_data4['avg_rss12'].quantile(0.75),walking_train_data5['avg_rss12'].quantile(0.75),walking_train_data6['avg_rss12'].quantile(0.75),walking_train_data7['avg_rss12'].quantile(0.75),walking_train_data8['avg_rss12'].quantile(0.75),walking_train_data9['avg_rss12'].quantile(0.75),walking_train_data10['avg_rss12'].quantile(0.75),walking_train_data11['avg_rss12'].quantile(0.75),walking_train_data12['avg_rss12'].quantile(0.75)]

min2 = [bending1_test_data1['var_rss12'].min(),bending1_test_data2['var_rss12'].min(),bending1_train_data1['var_rss12'].min(),bending1_train_data2['var_rss12'].min(),bending1_train_data3['var_rss12'].min(),bending1_train_data4['var_rss12'].min(),bending1_train_data5['var_rss12'].min(),bending2_test_data1['var_rss12'].min(),bending2_test_data2['var_rss12'].min(),bending2_train_data1['var_rss12'].min(),bending2_train_data2['var_rss12'].min(),bending2_train_data3['var_rss12'].min(),bending2_train_data4['var_rss12'].min(),cycling_test_data1['var_rss12'].min(),cycling_test_data2['var_rss12'].min(),cycling_test_data3['var_rss12'].min(),cycling_train_data1['var_rss12'].min(),cycling_train_data2['var_rss12'].min(),cycling_train_data3['var_rss12'].min(),cycling_train_data4['var_rss12'].min(),cycling_train_data5['var_rss12'].min(),cycling_train_data6['var_rss12'].min(),cycling_train_data7['var_rss12'].min(),cycling_train_data8['var_rss12'].min(),cycling_train_data9['var_rss12'].min(),cycling_train_data10['var_rss12'].min(),cycling_train_data11['var_rss12'].min(),cycling_train_data12['var_rss12'].min(),lying_test_data1['var_rss12'].min(),lying_test_data2['var_rss12'].min(),lying_test_data3['var_rss12'].min(),lying_train_data1['var_rss12'].min(),lying_train_data2['var_rss12'].min(),lying_train_data3['var_rss12'].min(),lying_train_data4['var_rss12'].min(),lying_train_data5['var_rss12'].min(),lying_train_data6['var_rss12'].min(),lying_train_data7['var_rss12'].min(),lying_train_data8['var_rss12'].min(),lying_train_data9['var_rss12'].min(),lying_train_data10['var_rss12'].min(),lying_train_data11['var_rss12'].min(),lying_train_data12['var_rss12'].min(),sitting_test_data1['var_rss12'].min(),sitting_test_data2['var_rss12'].min(),sitting_test_data3['var_rss12'].min(),sitting_train_data1['var_rss12'].min(),sitting_train_data2['var_rss12'].min(),sitting_train_data3['var_rss12'].min(),sitting_train_data4['var_rss12'].min(),sitting_train_data5['var_rss12'].min(),sitting_train_data6['var_rss12'].min(),sitting_train_data7['var_rss12'].min(),sitting_train_data8['var_rss12'].min(),sitting_train_data9['var_rss12'].min(),sitting_train_data10['var_rss12'].min(),sitting_train_data11['var_rss12'].min(),sitting_train_data12['var_rss12'].min(),standing_test_data1['var_rss12'].min(),standing_test_data2['var_rss12'].min(),standing_test_data3['var_rss12'].min(),standing_train_data1['var_rss12'].min(),standing_train_data2['var_rss12'].min(),standing_train_data3['var_rss12'].min(),standing_train_data4['var_rss12'].min(),standing_train_data5['var_rss12'].min(),standing_train_data6['var_rss12'].min(),standing_train_data7['var_rss12'].min(),standing_train_data8['var_rss12'].min(),standing_train_data9['var_rss12'].min(),standing_train_data10['var_rss12'].min(),standing_train_data11['var_rss12'].min(),standing_train_data12['var_rss12'].min(),walking_test_data1['var_rss12'].min(),walking_test_data2['var_rss12'].min(),walking_test_data3['var_rss12'].min(),walking_train_data1['var_rss12'].min(),walking_train_data2['var_rss12'].min(),walking_train_data3['var_rss12'].min(),walking_train_data4['var_rss12'].min(),walking_train_data5['var_rss12'].min(),walking_train_data6['var_rss12'].min(),walking_train_data7['var_rss12'].min(),walking_train_data8['var_rss12'].min(),walking_train_data9['var_rss12'].min(),walking_train_data10['var_rss12'].min(),walking_train_data11['var_rss12'].min(),walking_train_data12['var_rss12'].min()]

max2 = [bending1_test_data1['var_rss12'].max(),bending1_test_data2['var_rss12'].max(),bending1_train_data1['var_rss12'].max(),bending1_train_data2['var_rss12'].max(),bending1_train_data3['var_rss12'].max(),bending1_train_data4['var_rss12'].max(),bending1_train_data5['var_rss12'].max(),bending2_test_data1['var_rss12'].max(),bending2_test_data2['var_rss12'].max(),bending2_train_data1['var_rss12'].max(),bending2_train_data2['var_rss12'].max(),bending2_train_data3['var_rss12'].max(),bending2_train_data4['var_rss12'].max(),cycling_test_data1['var_rss12'].max(),cycling_test_data2['var_rss12'].max(),cycling_test_data3['var_rss12'].max(),cycling_train_data1['var_rss12'].max(),cycling_train_data2['var_rss12'].max(),cycling_train_data3['var_rss12'].max(),cycling_train_data4['var_rss12'].max(),cycling_train_data5['var_rss12'].max(),cycling_train_data6['var_rss12'].max(),cycling_train_data7['var_rss12'].max(),cycling_train_data8['var_rss12'].max(),cycling_train_data9['var_rss12'].max(),cycling_train_data10['var_rss12'].max(),cycling_train_data11['var_rss12'].max(),cycling_train_data12['var_rss12'].max(),lying_test_data1['var_rss12'].max(),lying_test_data2['var_rss12'].max(),lying_test_data3['var_rss12'].max(),lying_train_data1['var_rss12'].max(),lying_train_data2['var_rss12'].max(),lying_train_data3['var_rss12'].max(),lying_train_data4['var_rss12'].max(),lying_train_data5['var_rss12'].max(),lying_train_data6['var_rss12'].max(),lying_train_data7['var_rss12'].max(),lying_train_data8['var_rss12'].max(),lying_train_data9['var_rss12'].max(),lying_train_data10['var_rss12'].max(),lying_train_data11['var_rss12'].max(),lying_train_data12['var_rss12'].max(),sitting_test_data1['var_rss12'].max(),sitting_test_data2['var_rss12'].max(),sitting_test_data3['var_rss12'].max(),sitting_train_data1['var_rss12'].max(),sitting_train_data2['var_rss12'].max(),sitting_train_data3['var_rss12'].max(),sitting_train_data4['var_rss12'].max(),sitting_train_data5['var_rss12'].max(),sitting_train_data6['var_rss12'].max(),sitting_train_data7['var_rss12'].max(),sitting_train_data8['var_rss12'].max(),sitting_train_data9['var_rss12'].max(),sitting_train_data10['var_rss12'].max(),sitting_train_data11['var_rss12'].max(),sitting_train_data12['var_rss12'].max(),standing_test_data1['var_rss12'].max(),standing_test_data2['var_rss12'].max(),standing_test_data3['var_rss12'].max(),standing_train_data1['var_rss12'].max(),standing_train_data2['var_rss12'].max(),standing_train_data3['var_rss12'].max(),standing_train_data4['var_rss12'].max(),standing_train_data5['var_rss12'].max(),standing_train_data6['var_rss12'].max(),standing_train_data7['var_rss12'].max(),standing_train_data8['var_rss12'].max(),standing_train_data9['var_rss12'].max(),standing_train_data10['var_rss12'].max(),standing_train_data11['var_rss12'].max(),standing_train_data12['var_rss12'].max(),walking_test_data1['var_rss12'].max(),walking_test_data2['var_rss12'].max(),walking_test_data3['var_rss12'].max(),walking_train_data1['var_rss12'].max(),walking_train_data2['var_rss12'].max(),walking_train_data3['var_rss12'].max(),walking_train_data4['var_rss12'].max(),walking_train_data5['var_rss12'].max(),walking_train_data6['var_rss12'].max(),walking_train_data7['var_rss12'].max(),walking_train_data8['var_rss12'].max(),walking_train_data9['var_rss12'].max(),walking_train_data10['var_rss12'].max(),walking_train_data11['var_rss12'].max(),walking_train_data12['var_rss12'].max()]

mean2 = [bending1_test_data1['var_rss12'].mean(),bending1_test_data2['var_rss12'].mean(),bending1_train_data1['var_rss12'].mean(),bending1_train_data2['var_rss12'].mean(),bending1_train_data3['var_rss12'].mean(),bending1_train_data4['var_rss12'].mean(),bending1_train_data5['var_rss12'].mean(),bending2_test_data1['var_rss12'].mean(),bending2_test_data2['var_rss12'].mean(),bending2_train_data1['var_rss12'].mean(),bending2_train_data2['var_rss12'].mean(),bending2_train_data3['var_rss12'].mean(),bending2_train_data4['var_rss12'].mean(),cycling_test_data1['var_rss12'].mean(),cycling_test_data2['var_rss12'].mean(),cycling_test_data3['var_rss12'].mean(),cycling_train_data1['var_rss12'].mean(),cycling_train_data2['var_rss12'].mean(),cycling_train_data3['var_rss12'].mean(),cycling_train_data4['var_rss12'].mean(),cycling_train_data5['var_rss12'].mean(),cycling_train_data6['var_rss12'].mean(),cycling_train_data7['var_rss12'].mean(),cycling_train_data8['var_rss12'].mean(),cycling_train_data9['var_rss12'].mean(),cycling_train_data10['var_rss12'].mean(),cycling_train_data11['var_rss12'].mean(),cycling_train_data12['var_rss12'].mean(),lying_test_data1['var_rss12'].mean(),lying_test_data2['var_rss12'].mean(),lying_test_data3['var_rss12'].mean(),lying_train_data1['var_rss12'].mean(),lying_train_data2['var_rss12'].mean(),lying_train_data3['var_rss12'].mean(),lying_train_data4['var_rss12'].mean(),lying_train_data5['var_rss12'].mean(),lying_train_data6['var_rss12'].mean(),lying_train_data7['var_rss12'].mean(),lying_train_data8['var_rss12'].mean(),lying_train_data9['var_rss12'].mean(),lying_train_data10['var_rss12'].mean(),lying_train_data11['var_rss12'].mean(),lying_train_data12['var_rss12'].mean(),sitting_test_data1['var_rss12'].mean(),sitting_test_data2['var_rss12'].mean(),sitting_test_data3['var_rss12'].mean(),sitting_train_data1['var_rss12'].mean(),sitting_train_data2['var_rss12'].mean(),sitting_train_data3['var_rss12'].mean(),sitting_train_data4['var_rss12'].mean(),sitting_train_data5['var_rss12'].mean(),sitting_train_data6['var_rss12'].mean(),sitting_train_data7['var_rss12'].mean(),sitting_train_data8['var_rss12'].mean(),sitting_train_data9['var_rss12'].mean(),sitting_train_data10['var_rss12'].mean(),sitting_train_data11['var_rss12'].mean(),sitting_train_data12['var_rss12'].mean(),standing_test_data1['var_rss12'].mean(),standing_test_data2['var_rss12'].mean(),standing_test_data3['var_rss12'].mean(),standing_train_data1['var_rss12'].mean(),standing_train_data2['var_rss12'].mean(),standing_train_data3['var_rss12'].mean(),standing_train_data4['var_rss12'].mean(),standing_train_data5['var_rss12'].mean(),standing_train_data6['var_rss12'].mean(),standing_train_data7['var_rss12'].mean(),standing_train_data8['var_rss12'].mean(),standing_train_data9['var_rss12'].mean(),standing_train_data10['var_rss12'].mean(),standing_train_data11['var_rss12'].mean(),standing_train_data12['var_rss12'].mean(),walking_test_data1['var_rss12'].mean(),walking_test_data2['var_rss12'].mean(),walking_test_data3['var_rss12'].mean(),walking_train_data1['var_rss12'].mean(),walking_train_data2['var_rss12'].mean(),walking_train_data3['var_rss12'].mean(),walking_train_data4['var_rss12'].mean(),walking_train_data5['var_rss12'].mean(),walking_train_data6['var_rss12'].mean(),walking_train_data7['var_rss12'].mean(),walking_train_data8['var_rss12'].mean(),walking_train_data9['var_rss12'].mean(),walking_train_data10['var_rss12'].mean(),walking_train_data11['var_rss12'].mean(),walking_train_data12['var_rss12'].mean()]

median2 = [bending1_test_data1['var_rss12'].median(),bending1_test_data2['var_rss12'].median(),bending1_train_data1['var_rss12'].median(),bending1_train_data2['var_rss12'].median(),bending1_train_data3['var_rss12'].median(),bending1_train_data4['var_rss12'].median(),bending1_train_data5['var_rss12'].median(),bending2_test_data1['var_rss12'].median(),bending2_test_data2['var_rss12'].median(),bending2_train_data1['var_rss12'].median(),bending2_train_data2['var_rss12'].median(),bending2_train_data3['var_rss12'].median(),bending2_train_data4['var_rss12'].median(),cycling_test_data1['var_rss12'].median(),cycling_test_data2['var_rss12'].median(),cycling_test_data3['var_rss12'].median(),cycling_train_data1['var_rss12'].median(),cycling_train_data2['var_rss12'].median(),cycling_train_data3['var_rss12'].median(),cycling_train_data4['var_rss12'].median(),cycling_train_data5['var_rss12'].median(),cycling_train_data6['var_rss12'].median(),cycling_train_data7['var_rss12'].median(),cycling_train_data8['var_rss12'].median(),cycling_train_data9['var_rss12'].median(),cycling_train_data10['var_rss12'].median(),cycling_train_data11['var_rss12'].median(),cycling_train_data12['var_rss12'].median(),lying_test_data1['var_rss12'].median(),lying_test_data2['var_rss12'].median(),lying_test_data3['var_rss12'].median(),lying_train_data1['var_rss12'].median(),lying_train_data2['var_rss12'].median(),lying_train_data3['var_rss12'].median(),lying_train_data4['var_rss12'].median(),lying_train_data5['var_rss12'].median(),lying_train_data6['var_rss12'].median(),lying_train_data7['var_rss12'].median(),lying_train_data8['var_rss12'].median(),lying_train_data9['var_rss12'].median(),lying_train_data10['var_rss12'].median(),lying_train_data11['var_rss12'].median(),lying_train_data12['var_rss12'].median(),sitting_test_data1['var_rss12'].median(),sitting_test_data2['var_rss12'].median(),sitting_test_data3['var_rss12'].median(),sitting_train_data1['var_rss12'].median(),sitting_train_data2['var_rss12'].median(),sitting_train_data3['var_rss12'].median(),sitting_train_data4['var_rss12'].median(),sitting_train_data5['var_rss12'].median(),sitting_train_data6['var_rss12'].median(),sitting_train_data7['var_rss12'].median(),sitting_train_data8['var_rss12'].median(),sitting_train_data9['var_rss12'].median(),sitting_train_data10['var_rss12'].median(),sitting_train_data11['var_rss12'].median(),sitting_train_data12['var_rss12'].median(),standing_test_data1['var_rss12'].median(),standing_test_data2['var_rss12'].median(),standing_test_data3['var_rss12'].median(),standing_train_data1['var_rss12'].median(),standing_train_data2['var_rss12'].median(),standing_train_data3['var_rss12'].median(),standing_train_data4['var_rss12'].median(),standing_train_data5['var_rss12'].median(),standing_train_data6['var_rss12'].median(),standing_train_data7['var_rss12'].median(),standing_train_data8['var_rss12'].median(),standing_train_data9['var_rss12'].median(),standing_train_data10['var_rss12'].median(),standing_train_data11['var_rss12'].median(),standing_train_data12['var_rss12'].median(),walking_test_data1['var_rss12'].median(),walking_test_data2['var_rss12'].median(),walking_test_data3['var_rss12'].median(),walking_train_data1['var_rss12'].median(),walking_train_data2['var_rss12'].median(),walking_train_data3['var_rss12'].median(),walking_train_data4['var_rss12'].median(),walking_train_data5['var_rss12'].median(),walking_train_data6['var_rss12'].median(),walking_train_data7['var_rss12'].median(),walking_train_data8['var_rss12'].median(),walking_train_data9['var_rss12'].median(),walking_train_data10['var_rss12'].median(),walking_train_data11['var_rss12'].median(),walking_train_data12['var_rss12'].median()]

sd2 = [bending1_test_data1['var_rss12'].std(),bending1_test_data2['var_rss12'].std(),bending1_train_data1['var_rss12'].std(),bending1_train_data2['var_rss12'].std(),bending1_train_data3['var_rss12'].std(),bending1_train_data4['var_rss12'].std(),bending1_train_data5['var_rss12'].std(),bending2_test_data1['var_rss12'].std(),bending2_test_data2['var_rss12'].std(),bending2_train_data1['var_rss12'].std(),bending2_train_data2['var_rss12'].std(),bending2_train_data3['var_rss12'].std(),bending2_train_data4['var_rss12'].std(),cycling_test_data1['var_rss12'].std(),cycling_test_data2['var_rss12'].std(),cycling_test_data3['var_rss12'].std(),cycling_train_data1['var_rss12'].std(),cycling_train_data2['var_rss12'].std(),cycling_train_data3['var_rss12'].std(),cycling_train_data4['var_rss12'].std(),cycling_train_data5['var_rss12'].std(),cycling_train_data6['var_rss12'].std(),cycling_train_data7['var_rss12'].std(),cycling_train_data8['var_rss12'].std(),cycling_train_data9['var_rss12'].std(),cycling_train_data10['var_rss12'].std(),cycling_train_data11['var_rss12'].std(),cycling_train_data12['var_rss12'].std(),lying_test_data1['var_rss12'].std(),lying_test_data2['var_rss12'].std(),lying_test_data3['var_rss12'].std(),lying_train_data1['var_rss12'].std(),lying_train_data2['var_rss12'].std(),lying_train_data3['var_rss12'].std(),lying_train_data4['var_rss12'].std(),lying_train_data5['var_rss12'].std(),lying_train_data6['var_rss12'].std(),lying_train_data7['var_rss12'].std(),lying_train_data8['var_rss12'].std(),lying_train_data9['var_rss12'].std(),lying_train_data10['var_rss12'].std(),lying_train_data11['var_rss12'].std(),lying_train_data12['var_rss12'].std(),sitting_test_data1['var_rss12'].std(),sitting_test_data2['var_rss12'].std(),sitting_test_data3['var_rss12'].std(),sitting_train_data1['var_rss12'].std(),sitting_train_data2['var_rss12'].std(),sitting_train_data3['var_rss12'].std(),sitting_train_data4['var_rss12'].std(),sitting_train_data5['var_rss12'].std(),sitting_train_data6['var_rss12'].std(),sitting_train_data7['var_rss12'].std(),sitting_train_data8['var_rss12'].std(),sitting_train_data9['var_rss12'].std(),sitting_train_data10['var_rss12'].std(),sitting_train_data11['var_rss12'].std(),sitting_train_data12['var_rss12'].std(),standing_test_data1['var_rss12'].std(),standing_test_data2['var_rss12'].std(),standing_test_data3['var_rss12'].std(),standing_train_data1['var_rss12'].std(),standing_train_data2['var_rss12'].std(),standing_train_data3['var_rss12'].std(),standing_train_data4['var_rss12'].std(),standing_train_data5['var_rss12'].std(),standing_train_data6['var_rss12'].std(),standing_train_data7['var_rss12'].std(),standing_train_data8['var_rss12'].std(),standing_train_data9['var_rss12'].std(),standing_train_data10['var_rss12'].std(),standing_train_data11['var_rss12'].std(),standing_train_data12['var_rss12'].std(),walking_test_data1['var_rss12'].std(),walking_test_data2['var_rss12'].std(),walking_test_data3['var_rss12'].std(),walking_train_data1['var_rss12'].std(),walking_train_data2['var_rss12'].std(),walking_train_data3['var_rss12'].std(),walking_train_data4['var_rss12'].std(),walking_train_data5['var_rss12'].std(),walking_train_data6['var_rss12'].std(),walking_train_data7['var_rss12'].std(),walking_train_data8['var_rss12'].std(),walking_train_data9['var_rss12'].std(),walking_train_data10['var_rss12'].std(),walking_train_data11['var_rss12'].std(),walking_train_data12['var_rss12'].std()]

quart1_2 = [bending1_test_data1['var_rss12'].quantile(0.25),bending1_test_data2['var_rss12'].quantile(0.25),bending1_train_data1['var_rss12'].quantile(0.25),bending1_train_data2['var_rss12'].quantile(0.25),bending1_train_data3['var_rss12'].quantile(0.25),bending1_train_data4['var_rss12'].quantile(0.25),bending1_train_data5['var_rss12'].quantile(0.25),bending2_test_data1['var_rss12'].quantile(0.25),bending2_test_data2['var_rss12'].quantile(0.25),bending2_train_data1['var_rss12'].quantile(0.25),bending2_train_data2['var_rss12'].quantile(0.25),bending2_train_data3['var_rss12'].quantile(0.25),bending2_train_data4['var_rss12'].quantile(0.25),cycling_test_data1['var_rss12'].quantile(0.25),cycling_test_data2['var_rss12'].quantile(0.25),cycling_test_data3['var_rss12'].quantile(0.25),cycling_train_data1['var_rss12'].quantile(0.25),cycling_train_data2['var_rss12'].quantile(0.25),cycling_train_data3['var_rss12'].quantile(0.25),cycling_train_data4['var_rss12'].quantile(0.25),cycling_train_data5['var_rss12'].quantile(0.25),cycling_train_data6['var_rss12'].quantile(0.25),cycling_train_data7['var_rss12'].quantile(0.25),cycling_train_data8['var_rss12'].quantile(0.25),cycling_train_data9['var_rss12'].quantile(0.25),cycling_train_data10['var_rss12'].quantile(0.25),cycling_train_data11['var_rss12'].quantile(0.25),cycling_train_data12['var_rss12'].quantile(0.25),lying_test_data1['var_rss12'].quantile(0.25),lying_test_data2['var_rss12'].quantile(0.25),lying_test_data3['var_rss12'].quantile(0.25),lying_train_data1['var_rss12'].quantile(0.25),lying_train_data2['var_rss12'].quantile(0.25),lying_train_data3['var_rss12'].quantile(0.25),lying_train_data4['var_rss12'].quantile(0.25),lying_train_data5['var_rss12'].quantile(0.25),lying_train_data6['var_rss12'].quantile(0.25),lying_train_data7['var_rss12'].quantile(0.25),lying_train_data8['var_rss12'].quantile(0.25),lying_train_data9['var_rss12'].quantile(0.25),lying_train_data10['var_rss12'].quantile(0.25),lying_train_data11['var_rss12'].quantile(0.25),lying_train_data12['var_rss12'].quantile(0.25),sitting_test_data1['var_rss12'].quantile(0.25),sitting_test_data2['var_rss12'].quantile(0.25),sitting_test_data3['var_rss12'].quantile(0.25),sitting_train_data1['var_rss12'].quantile(0.25),sitting_train_data2['var_rss12'].quantile(0.25),sitting_train_data3['var_rss12'].quantile(0.25),sitting_train_data4['var_rss12'].quantile(0.25),sitting_train_data5['var_rss12'].quantile(0.25),sitting_train_data6['var_rss12'].quantile(0.25),sitting_train_data7['var_rss12'].quantile(0.25),sitting_train_data8['var_rss12'].quantile(0.25),sitting_train_data9['var_rss12'].quantile(0.25),sitting_train_data10['var_rss12'].quantile(0.25),sitting_train_data11['var_rss12'].quantile(0.25),sitting_train_data12['var_rss12'].quantile(0.25),standing_test_data1['var_rss12'].quantile(0.25),standing_test_data2['var_rss12'].quantile(0.25),standing_test_data3['var_rss12'].quantile(0.25),standing_train_data1['var_rss12'].quantile(0.25),standing_train_data2['var_rss12'].quantile(0.25),standing_train_data3['var_rss12'].quantile(0.25),standing_train_data4['var_rss12'].quantile(0.25),standing_train_data5['var_rss12'].quantile(0.25),standing_train_data6['var_rss12'].quantile(0.25),standing_train_data7['var_rss12'].quantile(0.25),standing_train_data8['var_rss12'].quantile(0.25),standing_train_data9['var_rss12'].quantile(0.25),standing_train_data10['var_rss12'].quantile(0.25),standing_train_data11['var_rss12'].quantile(0.25),standing_train_data12['var_rss12'].quantile(0.25),walking_test_data1['var_rss12'].quantile(0.25),walking_test_data2['var_rss12'].quantile(0.25),walking_test_data3['var_rss12'].quantile(0.25),walking_train_data1['var_rss12'].quantile(0.25),walking_train_data2['var_rss12'].quantile(0.25),walking_train_data3['var_rss12'].quantile(0.25),walking_train_data4['var_rss12'].quantile(0.25),walking_train_data5['var_rss12'].quantile(0.25),walking_train_data6['var_rss12'].quantile(0.25),walking_train_data7['var_rss12'].quantile(0.25),walking_train_data8['var_rss12'].quantile(0.25),walking_train_data9['var_rss12'].quantile(0.25),walking_train_data10['var_rss12'].quantile(0.25),walking_train_data11['var_rss12'].quantile(0.25),walking_train_data12['var_rss12'].quantile(0.25)]

quart3_2 = [bending1_test_data1['var_rss12'].quantile(0.75),bending1_test_data2['var_rss12'].quantile(0.75),bending1_train_data1['var_rss12'].quantile(0.75),bending1_train_data2['var_rss12'].quantile(0.75),bending1_train_data3['var_rss12'].quantile(0.75),bending1_train_data4['var_rss12'].quantile(0.75),bending1_train_data5['var_rss12'].quantile(0.75),bending2_test_data1['var_rss12'].quantile(0.75),bending2_test_data2['var_rss12'].quantile(0.75),bending2_train_data1['var_rss12'].quantile(0.75),bending2_train_data2['var_rss12'].quantile(0.75),bending2_train_data3['var_rss12'].quantile(0.75),bending2_train_data4['var_rss12'].quantile(0.75),cycling_test_data1['var_rss12'].quantile(0.75),cycling_test_data2['var_rss12'].quantile(0.75),cycling_test_data3['var_rss12'].quantile(0.75),cycling_train_data1['var_rss12'].quantile(0.75),cycling_train_data2['var_rss12'].quantile(0.75),cycling_train_data3['var_rss12'].quantile(0.75),cycling_train_data4['var_rss12'].quantile(0.75),cycling_train_data5['var_rss12'].quantile(0.75),cycling_train_data6['var_rss12'].quantile(0.75),cycling_train_data7['var_rss12'].quantile(0.75),cycling_train_data8['var_rss12'].quantile(0.75),cycling_train_data9['var_rss12'].quantile(0.75),cycling_train_data10['var_rss12'].quantile(0.75),cycling_train_data11['var_rss12'].quantile(0.75),cycling_train_data12['var_rss12'].quantile(0.75),lying_test_data1['var_rss12'].quantile(0.75),lying_test_data2['var_rss12'].quantile(0.75),lying_test_data3['var_rss12'].quantile(0.75),lying_train_data1['var_rss12'].quantile(0.75),lying_train_data2['var_rss12'].quantile(0.75),lying_train_data3['var_rss12'].quantile(0.75),lying_train_data4['var_rss12'].quantile(0.75),lying_train_data5['var_rss12'].quantile(0.75),lying_train_data6['var_rss12'].quantile(0.75),lying_train_data7['var_rss12'].quantile(0.75),lying_train_data8['var_rss12'].quantile(0.75),lying_train_data9['var_rss12'].quantile(0.75),lying_train_data10['var_rss12'].quantile(0.75),lying_train_data11['var_rss12'].quantile(0.75),lying_train_data12['var_rss12'].quantile(0.75),sitting_test_data1['var_rss12'].quantile(0.75),sitting_test_data2['var_rss12'].quantile(0.75),sitting_test_data3['var_rss12'].quantile(0.75),sitting_train_data1['var_rss12'].quantile(0.75),sitting_train_data2['var_rss12'].quantile(0.75),sitting_train_data3['var_rss12'].quantile(0.75),sitting_train_data4['var_rss12'].quantile(0.75),sitting_train_data5['var_rss12'].quantile(0.75),sitting_train_data6['var_rss12'].quantile(0.75),sitting_train_data7['var_rss12'].quantile(0.75),sitting_train_data8['var_rss12'].quantile(0.75),sitting_train_data9['var_rss12'].quantile(0.75),sitting_train_data10['var_rss12'].quantile(0.75),sitting_train_data11['var_rss12'].quantile(0.75),sitting_train_data12['var_rss12'].quantile(0.75),standing_test_data1['var_rss12'].quantile(0.75),standing_test_data2['var_rss12'].quantile(0.75),standing_test_data3['var_rss12'].quantile(0.75),standing_train_data1['var_rss12'].quantile(0.75),standing_train_data2['var_rss12'].quantile(0.75),standing_train_data3['var_rss12'].quantile(0.75),standing_train_data4['var_rss12'].quantile(0.75),standing_train_data5['var_rss12'].quantile(0.75),standing_train_data6['var_rss12'].quantile(0.75),standing_train_data7['var_rss12'].quantile(0.75),standing_train_data8['var_rss12'].quantile(0.75),standing_train_data9['var_rss12'].quantile(0.75),standing_train_data10['var_rss12'].quantile(0.75),standing_train_data11['var_rss12'].quantile(0.75),standing_train_data12['var_rss12'].quantile(0.75),walking_test_data1['var_rss12'].quantile(0.75),walking_test_data2['var_rss12'].quantile(0.75),walking_test_data3['var_rss12'].quantile(0.75),walking_train_data1['var_rss12'].quantile(0.75),walking_train_data2['var_rss12'].quantile(0.75),walking_train_data3['var_rss12'].quantile(0.75),walking_train_data4['var_rss12'].quantile(0.75),walking_train_data5['var_rss12'].quantile(0.75),walking_train_data6['var_rss12'].quantile(0.75),walking_train_data7['var_rss12'].quantile(0.75),walking_train_data8['var_rss12'].quantile(0.75),walking_train_data9['var_rss12'].quantile(0.75),walking_train_data10['var_rss12'].quantile(0.75),walking_train_data11['var_rss12'].quantile(0.75),walking_train_data12['var_rss12'].quantile(0.75)]

min3 = [bending1_test_data1['avg_rss13'].min(),bending1_test_data2['avg_rss13'].min(),bending1_train_data1['avg_rss13'].min(),bending1_train_data2['avg_rss13'].min(),bending1_train_data3['avg_rss13'].min(),bending1_train_data4['avg_rss13'].min(),bending1_train_data5['avg_rss13'].min(),bending2_test_data1['avg_rss13'].min(),bending2_test_data2['avg_rss13'].min(),bending2_train_data1['avg_rss13'].min(),bending2_train_data2['avg_rss13'].min(),bending2_train_data3['avg_rss13'].min(),bending2_train_data4['avg_rss13'].min(),cycling_test_data1['avg_rss13'].min(),cycling_test_data2['avg_rss13'].min(),cycling_test_data3['avg_rss13'].min(),cycling_train_data1['avg_rss13'].min(),cycling_train_data2['avg_rss13'].min(),cycling_train_data3['avg_rss13'].min(),cycling_train_data4['avg_rss13'].min(),cycling_train_data5['avg_rss13'].min(),cycling_train_data6['avg_rss13'].min(),cycling_train_data7['avg_rss13'].min(),cycling_train_data8['avg_rss13'].min(),cycling_train_data9['avg_rss13'].min(),cycling_train_data10['avg_rss13'].min(),cycling_train_data11['avg_rss13'].min(),cycling_train_data12['avg_rss13'].min(),lying_test_data1['avg_rss13'].min(),lying_test_data2['avg_rss13'].min(),lying_test_data3['avg_rss13'].min(),lying_train_data1['avg_rss13'].min(),lying_train_data2['avg_rss13'].min(),lying_train_data3['avg_rss13'].min(),lying_train_data4['avg_rss13'].min(),lying_train_data5['avg_rss13'].min(),lying_train_data6['avg_rss13'].min(),lying_train_data7['avg_rss13'].min(),lying_train_data8['avg_rss13'].min(),lying_train_data9['avg_rss13'].min(),lying_train_data10['avg_rss13'].min(),lying_train_data11['avg_rss13'].min(),lying_train_data12['avg_rss13'].min(),sitting_test_data1['avg_rss13'].min(),sitting_test_data2['avg_rss13'].min(),sitting_test_data3['avg_rss13'].min(),sitting_train_data1['avg_rss13'].min(),sitting_train_data2['avg_rss13'].min(),sitting_train_data3['avg_rss13'].min(),sitting_train_data4['avg_rss13'].min(),sitting_train_data5['avg_rss13'].min(),sitting_train_data6['avg_rss13'].min(),sitting_train_data7['avg_rss13'].min(),sitting_train_data8['avg_rss13'].min(),sitting_train_data9['avg_rss13'].min(),sitting_train_data10['avg_rss13'].min(),sitting_train_data11['avg_rss13'].min(),sitting_train_data12['avg_rss13'].min(),standing_test_data1['avg_rss13'].min(),standing_test_data2['avg_rss13'].min(),standing_test_data3['avg_rss13'].min(),standing_train_data1['avg_rss13'].min(),standing_train_data2['avg_rss13'].min(),standing_train_data3['avg_rss13'].min(),standing_train_data4['avg_rss13'].min(),standing_train_data5['avg_rss13'].min(),standing_train_data6['avg_rss13'].min(),standing_train_data7['avg_rss13'].min(),standing_train_data8['avg_rss13'].min(),standing_train_data9['avg_rss13'].min(),standing_train_data10['avg_rss13'].min(),standing_train_data11['avg_rss13'].min(),standing_train_data12['avg_rss13'].min(),walking_test_data1['avg_rss13'].min(),walking_test_data2['avg_rss13'].min(),walking_test_data3['avg_rss13'].min(),walking_train_data1['avg_rss13'].min(),walking_train_data2['avg_rss13'].min(),walking_train_data3['avg_rss13'].min(),walking_train_data4['avg_rss13'].min(),walking_train_data5['avg_rss13'].min(),walking_train_data6['avg_rss13'].min(),walking_train_data7['avg_rss13'].min(),walking_train_data8['avg_rss13'].min(),walking_train_data9['avg_rss13'].min(),walking_train_data10['avg_rss13'].min(),walking_train_data11['avg_rss13'].min(),walking_train_data12['avg_rss13'].min()]

max3 = [bending1_test_data1['avg_rss13'].max(),bending1_test_data2['avg_rss13'].max(),bending1_train_data1['avg_rss13'].max(),bending1_train_data2['avg_rss13'].max(),bending1_train_data3['avg_rss13'].max(),bending1_train_data4['avg_rss13'].max(),bending1_train_data5['avg_rss13'].max(),bending2_test_data1['avg_rss13'].max(),bending2_test_data2['avg_rss13'].max(),bending2_train_data1['avg_rss13'].max(),bending2_train_data2['avg_rss13'].max(),bending2_train_data3['avg_rss13'].max(),bending2_train_data4['avg_rss13'].max(),cycling_test_data1['avg_rss13'].max(),cycling_test_data2['avg_rss13'].max(),cycling_test_data3['avg_rss13'].max(),cycling_train_data1['avg_rss13'].max(),cycling_train_data2['avg_rss13'].max(),cycling_train_data3['avg_rss13'].max(),cycling_train_data4['avg_rss13'].max(),cycling_train_data5['avg_rss13'].max(),cycling_train_data6['avg_rss13'].max(),cycling_train_data7['avg_rss13'].max(),cycling_train_data8['avg_rss13'].max(),cycling_train_data9['avg_rss13'].max(),cycling_train_data10['avg_rss13'].max(),cycling_train_data11['avg_rss13'].max(),cycling_train_data12['avg_rss13'].max(),lying_test_data1['avg_rss13'].max(),lying_test_data2['avg_rss13'].max(),lying_test_data3['avg_rss13'].max(),lying_train_data1['avg_rss13'].max(),lying_train_data2['avg_rss13'].max(),lying_train_data3['avg_rss13'].max(),lying_train_data4['avg_rss13'].max(),lying_train_data5['avg_rss13'].max(),lying_train_data6['avg_rss13'].max(),lying_train_data7['avg_rss13'].max(),lying_train_data8['avg_rss13'].max(),lying_train_data9['avg_rss13'].max(),lying_train_data10['avg_rss13'].max(),lying_train_data11['avg_rss13'].max(),lying_train_data12['avg_rss13'].max(),sitting_test_data1['avg_rss13'].max(),sitting_test_data2['avg_rss13'].max(),sitting_test_data3['avg_rss13'].max(),sitting_train_data1['avg_rss13'].max(),sitting_train_data2['avg_rss13'].max(),sitting_train_data3['avg_rss13'].max(),sitting_train_data4['avg_rss13'].max(),sitting_train_data5['avg_rss13'].max(),sitting_train_data6['avg_rss13'].max(),sitting_train_data7['avg_rss13'].max(),sitting_train_data8['avg_rss13'].max(),sitting_train_data9['avg_rss13'].max(),sitting_train_data10['avg_rss13'].max(),sitting_train_data11['avg_rss13'].max(),sitting_train_data12['avg_rss13'].max(),standing_test_data1['avg_rss13'].max(),standing_test_data2['avg_rss13'].max(),standing_test_data3['avg_rss13'].max(),standing_train_data1['avg_rss13'].max(),standing_train_data2['avg_rss13'].max(),standing_train_data3['avg_rss13'].max(),standing_train_data4['avg_rss13'].max(),standing_train_data5['avg_rss13'].max(),standing_train_data6['avg_rss13'].max(),standing_train_data7['avg_rss13'].max(),standing_train_data8['avg_rss13'].max(),standing_train_data9['avg_rss13'].max(),standing_train_data10['avg_rss13'].max(),standing_train_data11['avg_rss13'].max(),standing_train_data12['avg_rss13'].max(),walking_test_data1['avg_rss13'].max(),walking_test_data2['avg_rss13'].max(),walking_test_data3['avg_rss13'].max(),walking_train_data1['avg_rss13'].max(),walking_train_data2['avg_rss13'].max(),walking_train_data3['avg_rss13'].max(),walking_train_data4['avg_rss13'].max(),walking_train_data5['avg_rss13'].max(),walking_train_data6['avg_rss13'].max(),walking_train_data7['avg_rss13'].max(),walking_train_data8['avg_rss13'].max(),walking_train_data9['avg_rss13'].max(),walking_train_data10['avg_rss13'].max(),walking_train_data11['avg_rss13'].max(),walking_train_data12['avg_rss13'].max()]

mean3 = [bending1_test_data1['avg_rss13'].mean(),bending1_test_data2['avg_rss13'].mean(),bending1_train_data1['avg_rss13'].mean(),bending1_train_data2['avg_rss13'].mean(),bending1_train_data3['avg_rss13'].mean(),bending1_train_data4['avg_rss13'].mean(),bending1_train_data5['avg_rss13'].mean(),bending2_test_data1['avg_rss13'].mean(),bending2_test_data2['avg_rss13'].mean(),bending2_train_data1['avg_rss13'].mean(),bending2_train_data2['avg_rss13'].mean(),bending2_train_data3['avg_rss13'].mean(),bending2_train_data4['avg_rss13'].mean(),cycling_test_data1['avg_rss13'].mean(),cycling_test_data2['avg_rss13'].mean(),cycling_test_data3['avg_rss13'].mean(),cycling_train_data1['avg_rss13'].mean(),cycling_train_data2['avg_rss13'].mean(),cycling_train_data3['avg_rss13'].mean(),cycling_train_data4['avg_rss13'].mean(),cycling_train_data5['avg_rss13'].mean(),cycling_train_data6['avg_rss13'].mean(),cycling_train_data7['avg_rss13'].mean(),cycling_train_data8['avg_rss13'].mean(),cycling_train_data9['avg_rss13'].mean(),cycling_train_data10['avg_rss13'].mean(),cycling_train_data11['avg_rss13'].mean(),cycling_train_data12['avg_rss13'].mean(),lying_test_data1['avg_rss13'].mean(),lying_test_data2['avg_rss13'].mean(),lying_test_data3['avg_rss13'].mean(),lying_train_data1['avg_rss13'].mean(),lying_train_data2['avg_rss13'].mean(),lying_train_data3['avg_rss13'].mean(),lying_train_data4['avg_rss13'].mean(),lying_train_data5['avg_rss13'].mean(),lying_train_data6['avg_rss13'].mean(),lying_train_data7['avg_rss13'].mean(),lying_train_data8['avg_rss13'].mean(),lying_train_data9['avg_rss13'].mean(),lying_train_data10['avg_rss13'].mean(),lying_train_data11['avg_rss13'].mean(),lying_train_data12['avg_rss13'].mean(),sitting_test_data1['avg_rss13'].mean(),sitting_test_data2['avg_rss13'].mean(),sitting_test_data3['avg_rss13'].mean(),sitting_train_data1['avg_rss13'].mean(),sitting_train_data2['avg_rss13'].mean(),sitting_train_data3['avg_rss13'].mean(),sitting_train_data4['avg_rss13'].mean(),sitting_train_data5['avg_rss13'].mean(),sitting_train_data6['avg_rss13'].mean(),sitting_train_data7['avg_rss13'].mean(),sitting_train_data8['avg_rss13'].mean(),sitting_train_data9['avg_rss13'].mean(),sitting_train_data10['avg_rss13'].mean(),sitting_train_data11['avg_rss13'].mean(),sitting_train_data12['avg_rss13'].mean(),standing_test_data1['avg_rss13'].mean(),standing_test_data2['avg_rss13'].mean(),standing_test_data3['avg_rss13'].mean(),standing_train_data1['avg_rss13'].mean(),standing_train_data2['avg_rss13'].mean(),standing_train_data3['avg_rss13'].mean(),standing_train_data4['avg_rss13'].mean(),standing_train_data5['avg_rss13'].mean(),standing_train_data6['avg_rss13'].mean(),standing_train_data7['avg_rss13'].mean(),standing_train_data8['avg_rss13'].mean(),standing_train_data9['avg_rss13'].mean(),standing_train_data10['avg_rss13'].mean(),standing_train_data11['avg_rss13'].mean(),standing_train_data12['avg_rss13'].mean(),walking_test_data1['avg_rss13'].mean(),walking_test_data2['avg_rss13'].mean(),walking_test_data3['avg_rss13'].mean(),walking_train_data1['avg_rss13'].mean(),walking_train_data2['avg_rss13'].mean(),walking_train_data3['avg_rss13'].mean(),walking_train_data4['avg_rss13'].mean(),walking_train_data5['avg_rss13'].mean(),walking_train_data6['avg_rss13'].mean(),walking_train_data7['avg_rss13'].mean(),walking_train_data8['avg_rss13'].mean(),walking_train_data9['avg_rss13'].mean(),walking_train_data10['avg_rss13'].mean(),walking_train_data11['avg_rss13'].mean(),walking_train_data12['avg_rss13'].mean()]

median3 = [bending1_test_data1['avg_rss13'].median(),bending1_test_data2['avg_rss13'].median(),bending1_train_data1['avg_rss13'].median(),bending1_train_data2['avg_rss13'].median(),bending1_train_data3['avg_rss13'].median(),bending1_train_data4['avg_rss13'].median(),bending1_train_data5['avg_rss13'].median(),bending2_test_data1['avg_rss13'].median(),bending2_test_data2['avg_rss13'].median(),bending2_train_data1['avg_rss13'].median(),bending2_train_data2['avg_rss13'].median(),bending2_train_data3['avg_rss13'].median(),bending2_train_data4['avg_rss13'].median(),cycling_test_data1['avg_rss13'].median(),cycling_test_data2['avg_rss13'].median(),cycling_test_data3['avg_rss13'].median(),cycling_train_data1['avg_rss13'].median(),cycling_train_data2['avg_rss13'].median(),cycling_train_data3['avg_rss13'].median(),cycling_train_data4['avg_rss13'].median(),cycling_train_data5['avg_rss13'].median(),cycling_train_data6['avg_rss13'].median(),cycling_train_data7['avg_rss13'].median(),cycling_train_data8['avg_rss13'].median(),cycling_train_data9['avg_rss13'].median(),cycling_train_data10['avg_rss13'].median(),cycling_train_data11['avg_rss13'].median(),cycling_train_data12['avg_rss13'].median(),lying_test_data1['avg_rss13'].median(),lying_test_data2['avg_rss13'].median(),lying_test_data3['avg_rss13'].median(),lying_train_data1['avg_rss13'].median(),lying_train_data2['avg_rss13'].median(),lying_train_data3['avg_rss13'].median(),lying_train_data4['avg_rss13'].median(),lying_train_data5['avg_rss13'].median(),lying_train_data6['avg_rss13'].median(),lying_train_data7['avg_rss13'].median(),lying_train_data8['avg_rss13'].median(),lying_train_data9['avg_rss13'].median(),lying_train_data10['avg_rss13'].median(),lying_train_data11['avg_rss13'].median(),lying_train_data12['avg_rss13'].median(),sitting_test_data1['avg_rss13'].median(),sitting_test_data2['avg_rss13'].median(),sitting_test_data3['avg_rss13'].median(),sitting_train_data1['avg_rss13'].median(),sitting_train_data2['avg_rss13'].median(),sitting_train_data3['avg_rss13'].median(),sitting_train_data4['avg_rss13'].median(),sitting_train_data5['avg_rss13'].median(),sitting_train_data6['avg_rss13'].median(),sitting_train_data7['avg_rss13'].median(),sitting_train_data8['avg_rss13'].median(),sitting_train_data9['avg_rss13'].median(),sitting_train_data10['avg_rss13'].median(),sitting_train_data11['avg_rss13'].median(),sitting_train_data12['avg_rss13'].median(),standing_test_data1['avg_rss13'].median(),standing_test_data2['avg_rss13'].median(),standing_test_data3['avg_rss13'].median(),standing_train_data1['avg_rss13'].median(),standing_train_data2['avg_rss13'].median(),standing_train_data3['avg_rss13'].median(),standing_train_data4['avg_rss13'].median(),standing_train_data5['avg_rss13'].median(),standing_train_data6['avg_rss13'].median(),standing_train_data7['avg_rss13'].median(),standing_train_data8['avg_rss13'].median(),standing_train_data9['avg_rss13'].median(),standing_train_data10['avg_rss13'].median(),standing_train_data11['avg_rss13'].median(),standing_train_data12['avg_rss13'].median(),walking_test_data1['avg_rss13'].median(),walking_test_data2['avg_rss13'].median(),walking_test_data3['avg_rss13'].median(),walking_train_data1['avg_rss13'].median(),walking_train_data2['avg_rss13'].median(),walking_train_data3['avg_rss13'].median(),walking_train_data4['avg_rss13'].median(),walking_train_data5['avg_rss13'].median(),walking_train_data6['avg_rss13'].median(),walking_train_data7['avg_rss13'].median(),walking_train_data8['avg_rss13'].median(),walking_train_data9['avg_rss13'].median(),walking_train_data10['avg_rss13'].median(),walking_train_data11['avg_rss13'].median(),walking_train_data12['avg_rss13'].median()]

sd3 = [bending1_test_data1['avg_rss13'].std(),bending1_test_data2['avg_rss13'].std(),bending1_train_data1['avg_rss13'].std(),bending1_train_data2['avg_rss13'].std(),bending1_train_data3['avg_rss13'].std(),bending1_train_data4['avg_rss13'].std(),bending1_train_data5['avg_rss13'].std(),bending2_test_data1['avg_rss13'].std(),bending2_test_data2['avg_rss13'].std(),bending2_train_data1['avg_rss13'].std(),bending2_train_data2['avg_rss13'].std(),bending2_train_data3['avg_rss13'].std(),bending2_train_data4['avg_rss13'].std(),cycling_test_data1['avg_rss13'].std(),cycling_test_data2['avg_rss13'].std(),cycling_test_data3['avg_rss13'].std(),cycling_train_data1['avg_rss13'].std(),cycling_train_data2['avg_rss13'].std(),cycling_train_data3['avg_rss13'].std(),cycling_train_data4['avg_rss13'].std(),cycling_train_data5['avg_rss13'].std(),cycling_train_data6['avg_rss13'].std(),cycling_train_data7['avg_rss13'].std(),cycling_train_data8['avg_rss13'].std(),cycling_train_data9['avg_rss13'].std(),cycling_train_data10['avg_rss13'].std(),cycling_train_data11['avg_rss13'].std(),cycling_train_data12['avg_rss13'].std(),lying_test_data1['avg_rss13'].std(),lying_test_data2['avg_rss13'].std(),lying_test_data3['avg_rss13'].std(),lying_train_data1['avg_rss13'].std(),lying_train_data2['avg_rss13'].std(),lying_train_data3['avg_rss13'].std(),lying_train_data4['avg_rss13'].std(),lying_train_data5['avg_rss13'].std(),lying_train_data6['avg_rss13'].std(),lying_train_data7['avg_rss13'].std(),lying_train_data8['avg_rss13'].std(),lying_train_data9['avg_rss13'].std(),lying_train_data10['avg_rss13'].std(),lying_train_data11['avg_rss13'].std(),lying_train_data12['avg_rss13'].std(),sitting_test_data1['avg_rss13'].std(),sitting_test_data2['avg_rss13'].std(),sitting_test_data3['avg_rss13'].std(),sitting_train_data1['avg_rss13'].std(),sitting_train_data2['avg_rss13'].std(),sitting_train_data3['avg_rss13'].std(),sitting_train_data4['avg_rss13'].std(),sitting_train_data5['avg_rss13'].std(),sitting_train_data6['avg_rss13'].std(),sitting_train_data7['avg_rss13'].std(),sitting_train_data8['avg_rss13'].std(),sitting_train_data9['avg_rss13'].std(),sitting_train_data10['avg_rss13'].std(),sitting_train_data11['avg_rss13'].std(),sitting_train_data12['avg_rss13'].std(),standing_test_data1['avg_rss13'].std(),standing_test_data2['avg_rss13'].std(),standing_test_data3['avg_rss13'].std(),standing_train_data1['avg_rss13'].std(),standing_train_data2['avg_rss13'].std(),standing_train_data3['avg_rss13'].std(),standing_train_data4['avg_rss13'].std(),standing_train_data5['avg_rss13'].std(),standing_train_data6['avg_rss13'].std(),standing_train_data7['avg_rss13'].std(),standing_train_data8['avg_rss13'].std(),standing_train_data9['avg_rss13'].std(),standing_train_data10['avg_rss13'].std(),standing_train_data11['avg_rss13'].std(),standing_train_data12['avg_rss13'].std(),walking_test_data1['avg_rss13'].std(),walking_test_data2['avg_rss13'].std(),walking_test_data3['avg_rss13'].std(),walking_train_data1['avg_rss13'].std(),walking_train_data2['avg_rss13'].std(),walking_train_data3['avg_rss13'].std(),walking_train_data4['avg_rss13'].std(),walking_train_data5['avg_rss13'].std(),walking_train_data6['avg_rss13'].std(),walking_train_data7['avg_rss13'].std(),walking_train_data8['avg_rss13'].std(),walking_train_data9['avg_rss13'].std(),walking_train_data10['avg_rss13'].std(),walking_train_data11['avg_rss13'].std(),walking_train_data12['avg_rss13'].std()]

quart1_3 = [bending1_test_data1['avg_rss13'].quantile(0.25),bending1_test_data2['avg_rss13'].quantile(0.25),bending1_train_data1['avg_rss13'].quantile(0.25),bending1_train_data2['avg_rss13'].quantile(0.25),bending1_train_data3['avg_rss13'].quantile(0.25),bending1_train_data4['avg_rss13'].quantile(0.25),bending1_train_data5['avg_rss13'].quantile(0.25),bending2_test_data1['avg_rss13'].quantile(0.25),bending2_test_data2['avg_rss13'].quantile(0.25),bending2_train_data1['avg_rss13'].quantile(0.25),bending2_train_data2['avg_rss13'].quantile(0.25),bending2_train_data3['avg_rss13'].quantile(0.25),bending2_train_data4['avg_rss13'].quantile(0.25),cycling_test_data1['avg_rss13'].quantile(0.25),cycling_test_data2['avg_rss13'].quantile(0.25),cycling_test_data3['avg_rss13'].quantile(0.25),cycling_train_data1['avg_rss13'].quantile(0.25),cycling_train_data2['avg_rss13'].quantile(0.25),cycling_train_data3['avg_rss13'].quantile(0.25),cycling_train_data4['avg_rss13'].quantile(0.25),cycling_train_data5['avg_rss13'].quantile(0.25),cycling_train_data6['avg_rss13'].quantile(0.25),cycling_train_data7['avg_rss13'].quantile(0.25),cycling_train_data8['avg_rss13'].quantile(0.25),cycling_train_data9['avg_rss13'].quantile(0.25),cycling_train_data10['avg_rss13'].quantile(0.25),cycling_train_data11['avg_rss13'].quantile(0.25),cycling_train_data12['avg_rss13'].quantile(0.25),lying_test_data1['avg_rss13'].quantile(0.25),lying_test_data2['avg_rss13'].quantile(0.25),lying_test_data3['avg_rss13'].quantile(0.25),lying_train_data1['avg_rss13'].quantile(0.25),lying_train_data2['avg_rss13'].quantile(0.25),lying_train_data3['avg_rss13'].quantile(0.25),lying_train_data4['avg_rss13'].quantile(0.25),lying_train_data5['avg_rss13'].quantile(0.25),lying_train_data6['avg_rss13'].quantile(0.25),lying_train_data7['avg_rss13'].quantile(0.25),lying_train_data8['avg_rss13'].quantile(0.25),lying_train_data9['avg_rss13'].quantile(0.25),lying_train_data10['avg_rss13'].quantile(0.25),lying_train_data11['avg_rss13'].quantile(0.25),lying_train_data12['avg_rss13'].quantile(0.25),sitting_test_data1['avg_rss13'].quantile(0.25),sitting_test_data2['avg_rss13'].quantile(0.25),sitting_test_data3['avg_rss13'].quantile(0.25),sitting_train_data1['avg_rss13'].quantile(0.25),sitting_train_data2['avg_rss13'].quantile(0.25),sitting_train_data3['avg_rss13'].quantile(0.25),sitting_train_data4['avg_rss13'].quantile(0.25),sitting_train_data5['avg_rss13'].quantile(0.25),sitting_train_data6['avg_rss13'].quantile(0.25),sitting_train_data7['avg_rss13'].quantile(0.25),sitting_train_data8['avg_rss13'].quantile(0.25),sitting_train_data9['avg_rss13'].quantile(0.25),sitting_train_data10['avg_rss13'].quantile(0.25),sitting_train_data11['avg_rss13'].quantile(0.25),sitting_train_data12['avg_rss13'].quantile(0.25),standing_test_data1['avg_rss13'].quantile(0.25),standing_test_data2['avg_rss13'].quantile(0.25),standing_test_data3['avg_rss13'].quantile(0.25),standing_train_data1['avg_rss13'].quantile(0.25),standing_train_data2['avg_rss13'].quantile(0.25),standing_train_data3['avg_rss13'].quantile(0.25),standing_train_data4['avg_rss13'].quantile(0.25),standing_train_data5['avg_rss13'].quantile(0.25),standing_train_data6['avg_rss13'].quantile(0.25),standing_train_data7['avg_rss13'].quantile(0.25),standing_train_data8['avg_rss13'].quantile(0.25),standing_train_data9['avg_rss13'].quantile(0.25),standing_train_data10['avg_rss13'].quantile(0.25),standing_train_data11['avg_rss13'].quantile(0.25),standing_train_data12['avg_rss13'].quantile(0.25),walking_test_data1['avg_rss13'].quantile(0.25),walking_test_data2['avg_rss13'].quantile(0.25),walking_test_data3['avg_rss13'].quantile(0.25),walking_train_data1['avg_rss13'].quantile(0.25),walking_train_data2['avg_rss13'].quantile(0.25),walking_train_data3['avg_rss13'].quantile(0.25),walking_train_data4['avg_rss13'].quantile(0.25),walking_train_data5['avg_rss13'].quantile(0.25),walking_train_data6['avg_rss13'].quantile(0.25),walking_train_data7['avg_rss13'].quantile(0.25),walking_train_data8['avg_rss13'].quantile(0.25),walking_train_data9['avg_rss13'].quantile(0.25),walking_train_data10['avg_rss13'].quantile(0.25),walking_train_data11['avg_rss13'].quantile(0.25),walking_train_data12['avg_rss13'].quantile(0.25)]

quart3_3 = [bending1_test_data1['avg_rss13'].quantile(0.75),bending1_test_data2['avg_rss13'].quantile(0.75),bending1_train_data1['avg_rss13'].quantile(0.75),bending1_train_data2['avg_rss13'].quantile(0.75),bending1_train_data3['avg_rss13'].quantile(0.75),bending1_train_data4['avg_rss13'].quantile(0.75),bending1_train_data5['avg_rss13'].quantile(0.75),bending2_test_data1['avg_rss13'].quantile(0.75),bending2_test_data2['avg_rss13'].quantile(0.75),bending2_train_data1['avg_rss13'].quantile(0.75),bending2_train_data2['avg_rss13'].quantile(0.75),bending2_train_data3['avg_rss13'].quantile(0.75),bending2_train_data4['avg_rss13'].quantile(0.75),cycling_test_data1['avg_rss13'].quantile(0.75),cycling_test_data2['avg_rss13'].quantile(0.75),cycling_test_data3['avg_rss13'].quantile(0.75),cycling_train_data1['avg_rss13'].quantile(0.75),cycling_train_data2['avg_rss13'].quantile(0.75),cycling_train_data3['avg_rss13'].quantile(0.75),cycling_train_data4['avg_rss13'].quantile(0.75),cycling_train_data5['avg_rss13'].quantile(0.75),cycling_train_data6['avg_rss13'].quantile(0.75),cycling_train_data7['avg_rss13'].quantile(0.75),cycling_train_data8['avg_rss13'].quantile(0.75),cycling_train_data9['avg_rss13'].quantile(0.75),cycling_train_data10['avg_rss13'].quantile(0.75),cycling_train_data11['avg_rss13'].quantile(0.75),cycling_train_data12['avg_rss13'].quantile(0.75),lying_test_data1['avg_rss13'].quantile(0.75),lying_test_data2['avg_rss13'].quantile(0.75),lying_test_data3['avg_rss13'].quantile(0.75),lying_train_data1['avg_rss13'].quantile(0.75),lying_train_data2['avg_rss13'].quantile(0.75),lying_train_data3['avg_rss13'].quantile(0.75),lying_train_data4['avg_rss13'].quantile(0.75),lying_train_data5['avg_rss13'].quantile(0.75),lying_train_data6['avg_rss13'].quantile(0.75),lying_train_data7['avg_rss13'].quantile(0.75),lying_train_data8['avg_rss13'].quantile(0.75),lying_train_data9['avg_rss13'].quantile(0.75),lying_train_data10['avg_rss13'].quantile(0.75),lying_train_data11['avg_rss13'].quantile(0.75),lying_train_data12['avg_rss13'].quantile(0.75),sitting_test_data1['avg_rss13'].quantile(0.75),sitting_test_data2['avg_rss13'].quantile(0.75),sitting_test_data3['avg_rss13'].quantile(0.75),sitting_train_data1['avg_rss13'].quantile(0.75),sitting_train_data2['avg_rss13'].quantile(0.75),sitting_train_data3['avg_rss13'].quantile(0.75),sitting_train_data4['avg_rss13'].quantile(0.75),sitting_train_data5['avg_rss13'].quantile(0.75),sitting_train_data6['avg_rss13'].quantile(0.75),sitting_train_data7['avg_rss13'].quantile(0.75),sitting_train_data8['avg_rss13'].quantile(0.75),sitting_train_data9['avg_rss13'].quantile(0.75),sitting_train_data10['avg_rss13'].quantile(0.75),sitting_train_data11['avg_rss13'].quantile(0.75),sitting_train_data12['avg_rss13'].quantile(0.75),standing_test_data1['avg_rss13'].quantile(0.75),standing_test_data2['avg_rss13'].quantile(0.75),standing_test_data3['avg_rss13'].quantile(0.75),standing_train_data1['avg_rss13'].quantile(0.75),standing_train_data2['avg_rss13'].quantile(0.75),standing_train_data3['avg_rss13'].quantile(0.75),standing_train_data4['avg_rss13'].quantile(0.75),standing_train_data5['avg_rss13'].quantile(0.75),standing_train_data6['avg_rss13'].quantile(0.75),standing_train_data7['avg_rss13'].quantile(0.75),standing_train_data8['avg_rss13'].quantile(0.75),standing_train_data9['avg_rss13'].quantile(0.75),standing_train_data10['avg_rss13'].quantile(0.75),standing_train_data11['avg_rss13'].quantile(0.75),standing_train_data12['avg_rss13'].quantile(0.75),walking_test_data1['avg_rss13'].quantile(0.75),walking_test_data2['avg_rss13'].quantile(0.75),walking_test_data3['avg_rss13'].quantile(0.75),walking_train_data1['avg_rss13'].quantile(0.75),walking_train_data2['avg_rss13'].quantile(0.75),walking_train_data3['avg_rss13'].quantile(0.75),walking_train_data4['avg_rss13'].quantile(0.75),walking_train_data5['avg_rss13'].quantile(0.75),walking_train_data6['avg_rss13'].quantile(0.75),walking_train_data7['avg_rss13'].quantile(0.75),walking_train_data8['avg_rss13'].quantile(0.75),walking_train_data9['avg_rss13'].quantile(0.75),walking_train_data10['avg_rss13'].quantile(0.75),walking_train_data11['avg_rss13'].quantile(0.75),walking_train_data12['avg_rss13'].quantile(0.75)]

min4 = [bending1_test_data1['var_rss13'].min(),bending1_test_data2['var_rss13'].min(),bending1_train_data1['var_rss13'].min(),bending1_train_data2['var_rss13'].min(),bending1_train_data3['var_rss13'].min(),bending1_train_data4['var_rss13'].min(),bending1_train_data5['var_rss13'].min(),bending2_test_data1['var_rss13'].min(),bending2_test_data2['var_rss13'].min(),bending2_train_data1['var_rss13'].min(),bending2_train_data2['var_rss13'].min(),bending2_train_data3['var_rss13'].min(),bending2_train_data4['var_rss13'].min(),cycling_test_data1['var_rss13'].min(),cycling_test_data2['var_rss13'].min(),cycling_test_data3['var_rss13'].min(),cycling_train_data1['var_rss13'].min(),cycling_train_data2['var_rss13'].min(),cycling_train_data3['var_rss13'].min(),cycling_train_data4['var_rss13'].min(),cycling_train_data5['var_rss13'].min(),cycling_train_data6['var_rss13'].min(),cycling_train_data7['var_rss13'].min(),cycling_train_data8['var_rss13'].min(),cycling_train_data9['var_rss13'].min(),cycling_train_data10['var_rss13'].min(),cycling_train_data11['var_rss13'].min(),cycling_train_data12['var_rss13'].min(),lying_test_data1['var_rss13'].min(),lying_test_data2['var_rss13'].min(),lying_test_data3['var_rss13'].min(),lying_train_data1['var_rss13'].min(),lying_train_data2['var_rss13'].min(),lying_train_data3['var_rss13'].min(),lying_train_data4['var_rss13'].min(),lying_train_data5['var_rss13'].min(),lying_train_data6['var_rss13'].min(),lying_train_data7['var_rss13'].min(),lying_train_data8['var_rss13'].min(),lying_train_data9['var_rss13'].min(),lying_train_data10['var_rss13'].min(),lying_train_data11['var_rss13'].min(),lying_train_data12['var_rss13'].min(),sitting_test_data1['var_rss13'].min(),sitting_test_data2['var_rss13'].min(),sitting_test_data3['var_rss13'].min(),sitting_train_data1['var_rss13'].min(),sitting_train_data2['var_rss13'].min(),sitting_train_data3['var_rss13'].min(),sitting_train_data4['var_rss13'].min(),sitting_train_data5['var_rss13'].min(),sitting_train_data6['var_rss13'].min(),sitting_train_data7['var_rss13'].min(),sitting_train_data8['var_rss13'].min(),sitting_train_data9['var_rss13'].min(),sitting_train_data10['var_rss13'].min(),sitting_train_data11['var_rss13'].min(),sitting_train_data12['var_rss13'].min(),standing_test_data1['var_rss13'].min(),standing_test_data2['var_rss13'].min(),standing_test_data3['var_rss13'].min(),standing_train_data1['var_rss13'].min(),standing_train_data2['var_rss13'].min(),standing_train_data3['var_rss13'].min(),standing_train_data4['var_rss13'].min(),standing_train_data5['var_rss13'].min(),standing_train_data6['var_rss13'].min(),standing_train_data7['var_rss13'].min(),standing_train_data8['var_rss13'].min(),standing_train_data9['var_rss13'].min(),standing_train_data10['var_rss13'].min(),standing_train_data11['var_rss13'].min(),standing_train_data12['var_rss13'].min(),walking_test_data1['var_rss13'].min(),walking_test_data2['var_rss13'].min(),walking_test_data3['var_rss13'].min(),walking_train_data1['var_rss13'].min(),walking_train_data2['var_rss13'].min(),walking_train_data3['var_rss13'].min(),walking_train_data4['var_rss13'].min(),walking_train_data5['var_rss13'].min(),walking_train_data6['var_rss13'].min(),walking_train_data7['var_rss13'].min(),walking_train_data8['var_rss13'].min(),walking_train_data9['var_rss13'].min(),walking_train_data10['var_rss13'].min(),walking_train_data11['var_rss13'].min(),walking_train_data12['var_rss13'].min()]

max4 = [bending1_test_data1['var_rss13'].max(),bending1_test_data2['var_rss13'].max(),bending1_train_data1['var_rss13'].max(),bending1_train_data2['var_rss13'].max(),bending1_train_data3['var_rss13'].max(),bending1_train_data4['var_rss13'].max(),bending1_train_data5['var_rss13'].max(),bending2_test_data1['var_rss13'].max(),bending2_test_data2['var_rss13'].max(),bending2_train_data1['var_rss13'].max(),bending2_train_data2['var_rss13'].max(),bending2_train_data3['var_rss13'].max(),bending2_train_data4['var_rss13'].max(),cycling_test_data1['var_rss13'].max(),cycling_test_data2['var_rss13'].max(),cycling_test_data3['var_rss13'].max(),cycling_train_data1['var_rss13'].max(),cycling_train_data2['var_rss13'].max(),cycling_train_data3['var_rss13'].max(),cycling_train_data4['var_rss13'].max(),cycling_train_data5['var_rss13'].max(),cycling_train_data6['var_rss13'].max(),cycling_train_data7['var_rss13'].max(),cycling_train_data8['var_rss13'].max(),cycling_train_data9['var_rss13'].max(),cycling_train_data10['var_rss13'].max(),cycling_train_data11['var_rss13'].max(),cycling_train_data12['var_rss13'].max(),lying_test_data1['var_rss13'].max(),lying_test_data2['var_rss13'].max(),lying_test_data3['var_rss13'].max(),lying_train_data1['var_rss13'].max(),lying_train_data2['var_rss13'].max(),lying_train_data3['var_rss13'].max(),lying_train_data4['var_rss13'].max(),lying_train_data5['var_rss13'].max(),lying_train_data6['var_rss13'].max(),lying_train_data7['var_rss13'].max(),lying_train_data8['var_rss13'].max(),lying_train_data9['var_rss13'].max(),lying_train_data10['var_rss13'].max(),lying_train_data11['var_rss13'].max(),lying_train_data12['var_rss13'].max(),sitting_test_data1['var_rss13'].max(),sitting_test_data2['var_rss13'].max(),sitting_test_data3['var_rss13'].max(),sitting_train_data1['var_rss13'].max(),sitting_train_data2['var_rss13'].max(),sitting_train_data3['var_rss13'].max(),sitting_train_data4['var_rss13'].max(),sitting_train_data5['var_rss13'].max(),sitting_train_data6['var_rss13'].max(),sitting_train_data7['var_rss13'].max(),sitting_train_data8['var_rss13'].max(),sitting_train_data9['var_rss13'].max(),sitting_train_data10['var_rss13'].max(),sitting_train_data11['var_rss13'].max(),sitting_train_data12['var_rss13'].max(),standing_test_data1['var_rss13'].max(),standing_test_data2['var_rss13'].max(),standing_test_data3['var_rss13'].max(),standing_train_data1['var_rss13'].max(),standing_train_data2['var_rss13'].max(),standing_train_data3['var_rss13'].max(),standing_train_data4['var_rss13'].max(),standing_train_data5['var_rss13'].max(),standing_train_data6['var_rss13'].max(),standing_train_data7['var_rss13'].max(),standing_train_data8['var_rss13'].max(),standing_train_data9['var_rss13'].max(),standing_train_data10['var_rss13'].max(),standing_train_data11['var_rss13'].max(),standing_train_data12['var_rss13'].max(),walking_test_data1['var_rss13'].max(),walking_test_data2['var_rss13'].max(),walking_test_data3['var_rss13'].max(),walking_train_data1['var_rss13'].max(),walking_train_data2['var_rss13'].max(),walking_train_data3['var_rss13'].max(),walking_train_data4['var_rss13'].max(),walking_train_data5['var_rss13'].max(),walking_train_data6['var_rss13'].max(),walking_train_data7['var_rss13'].max(),walking_train_data8['var_rss13'].max(),walking_train_data9['var_rss13'].max(),walking_train_data10['var_rss13'].max(),walking_train_data11['var_rss13'].max(),walking_train_data12['var_rss13'].max()]

mean4 = [bending1_test_data1['var_rss13'].mean(),bending1_test_data2['var_rss13'].mean(),bending1_train_data1['var_rss13'].mean(),bending1_train_data2['var_rss13'].mean(),bending1_train_data3['var_rss13'].mean(),bending1_train_data4['var_rss13'].mean(),bending1_train_data5['var_rss13'].mean(),bending2_test_data1['var_rss13'].mean(),bending2_test_data2['var_rss13'].mean(),bending2_train_data1['var_rss13'].mean(),bending2_train_data2['var_rss13'].mean(),bending2_train_data3['var_rss13'].mean(),bending2_train_data4['var_rss13'].mean(),cycling_test_data1['var_rss13'].mean(),cycling_test_data2['var_rss13'].mean(),cycling_test_data3['var_rss13'].mean(),cycling_train_data1['var_rss13'].mean(),cycling_train_data2['var_rss13'].mean(),cycling_train_data3['var_rss13'].mean(),cycling_train_data4['var_rss13'].mean(),cycling_train_data5['var_rss13'].mean(),cycling_train_data6['var_rss13'].mean(),cycling_train_data7['var_rss13'].mean(),cycling_train_data8['var_rss13'].mean(),cycling_train_data9['var_rss13'].mean(),cycling_train_data10['var_rss13'].mean(),cycling_train_data11['var_rss13'].mean(),cycling_train_data12['var_rss13'].mean(),lying_test_data1['var_rss13'].mean(),lying_test_data2['var_rss13'].mean(),lying_test_data3['var_rss13'].mean(),lying_train_data1['var_rss13'].mean(),lying_train_data2['var_rss13'].mean(),lying_train_data3['var_rss13'].mean(),lying_train_data4['var_rss13'].mean(),lying_train_data5['var_rss13'].mean(),lying_train_data6['var_rss13'].mean(),lying_train_data7['var_rss13'].mean(),lying_train_data8['var_rss13'].mean(),lying_train_data9['var_rss13'].mean(),lying_train_data10['var_rss13'].mean(),lying_train_data11['var_rss13'].mean(),lying_train_data12['var_rss13'].mean(),sitting_test_data1['var_rss13'].mean(),sitting_test_data2['var_rss13'].mean(),sitting_test_data3['var_rss13'].mean(),sitting_train_data1['var_rss13'].mean(),sitting_train_data2['var_rss13'].mean(),sitting_train_data3['var_rss13'].mean(),sitting_train_data4['var_rss13'].mean(),sitting_train_data5['var_rss13'].mean(),sitting_train_data6['var_rss13'].mean(),sitting_train_data7['var_rss13'].mean(),sitting_train_data8['var_rss13'].mean(),sitting_train_data9['var_rss13'].mean(),sitting_train_data10['var_rss13'].mean(),sitting_train_data11['var_rss13'].mean(),sitting_train_data12['var_rss13'].mean(),standing_test_data1['var_rss13'].mean(),standing_test_data2['var_rss13'].mean(),standing_test_data3['var_rss13'].mean(),standing_train_data1['var_rss13'].mean(),standing_train_data2['var_rss13'].mean(),standing_train_data3['var_rss13'].mean(),standing_train_data4['var_rss13'].mean(),standing_train_data5['var_rss13'].mean(),standing_train_data6['var_rss13'].mean(),standing_train_data7['var_rss13'].mean(),standing_train_data8['var_rss13'].mean(),standing_train_data9['var_rss13'].mean(),standing_train_data10['var_rss13'].mean(),standing_train_data11['var_rss13'].mean(),standing_train_data12['var_rss13'].mean(),walking_test_data1['var_rss13'].mean(),walking_test_data2['var_rss13'].mean(),walking_test_data3['var_rss13'].mean(),walking_train_data1['var_rss13'].mean(),walking_train_data2['var_rss13'].mean(),walking_train_data3['var_rss13'].mean(),walking_train_data4['var_rss13'].mean(),walking_train_data5['var_rss13'].mean(),walking_train_data6['var_rss13'].mean(),walking_train_data7['var_rss13'].mean(),walking_train_data8['var_rss13'].mean(),walking_train_data9['var_rss13'].mean(),walking_train_data10['var_rss13'].mean(),walking_train_data11['var_rss13'].mean(),walking_train_data12['var_rss13'].mean()]

median4 = [bending1_test_data1['var_rss13'].median(),bending1_test_data2['var_rss13'].median(),bending1_train_data1['var_rss13'].median(),bending1_train_data2['var_rss13'].median(),bending1_train_data3['var_rss13'].median(),bending1_train_data4['var_rss13'].median(),bending1_train_data5['var_rss13'].median(),bending2_test_data1['var_rss13'].median(),bending2_test_data2['var_rss13'].median(),bending2_train_data1['var_rss13'].median(),bending2_train_data2['var_rss13'].median(),bending2_train_data3['var_rss13'].median(),bending2_train_data4['var_rss13'].median(),cycling_test_data1['var_rss13'].median(),cycling_test_data2['var_rss13'].median(),cycling_test_data3['var_rss13'].median(),cycling_train_data1['var_rss13'].median(),cycling_train_data2['var_rss13'].median(),cycling_train_data3['var_rss13'].median(),cycling_train_data4['var_rss13'].median(),cycling_train_data5['var_rss13'].median(),cycling_train_data6['var_rss13'].median(),cycling_train_data7['var_rss13'].median(),cycling_train_data8['var_rss13'].median(),cycling_train_data9['var_rss13'].median(),cycling_train_data10['var_rss13'].median(),cycling_train_data11['var_rss13'].median(),cycling_train_data12['var_rss13'].median(),lying_test_data1['var_rss13'].median(),lying_test_data2['var_rss13'].median(),lying_test_data3['var_rss13'].median(),lying_train_data1['var_rss13'].median(),lying_train_data2['var_rss13'].median(),lying_train_data3['var_rss13'].median(),lying_train_data4['var_rss13'].median(),lying_train_data5['var_rss13'].median(),lying_train_data6['var_rss13'].median(),lying_train_data7['var_rss13'].median(),lying_train_data8['var_rss13'].median(),lying_train_data9['var_rss13'].median(),lying_train_data10['var_rss13'].median(),lying_train_data11['var_rss13'].median(),lying_train_data12['var_rss13'].median(),sitting_test_data1['var_rss13'].median(),sitting_test_data2['var_rss13'].median(),sitting_test_data3['var_rss13'].median(),sitting_train_data1['var_rss13'].median(),sitting_train_data2['var_rss13'].median(),sitting_train_data3['var_rss13'].median(),sitting_train_data4['var_rss13'].median(),sitting_train_data5['var_rss13'].median(),sitting_train_data6['var_rss13'].median(),sitting_train_data7['var_rss13'].median(),sitting_train_data8['var_rss13'].median(),sitting_train_data9['var_rss13'].median(),sitting_train_data10['var_rss13'].median(),sitting_train_data11['var_rss13'].median(),sitting_train_data12['var_rss13'].median(),standing_test_data1['var_rss13'].median(),standing_test_data2['var_rss13'].median(),standing_test_data3['var_rss13'].median(),standing_train_data1['var_rss13'].median(),standing_train_data2['var_rss13'].median(),standing_train_data3['var_rss13'].median(),standing_train_data4['var_rss13'].median(),standing_train_data5['var_rss13'].median(),standing_train_data6['var_rss13'].median(),standing_train_data7['var_rss13'].median(),standing_train_data8['var_rss13'].median(),standing_train_data9['var_rss13'].median(),standing_train_data10['var_rss13'].median(),standing_train_data11['var_rss13'].median(),standing_train_data12['var_rss13'].median(),walking_test_data1['var_rss13'].median(),walking_test_data2['var_rss13'].median(),walking_test_data3['var_rss13'].median(),walking_train_data1['var_rss13'].median(),walking_train_data2['var_rss13'].median(),walking_train_data3['var_rss13'].median(),walking_train_data4['var_rss13'].median(),walking_train_data5['var_rss13'].median(),walking_train_data6['var_rss13'].median(),walking_train_data7['var_rss13'].median(),walking_train_data8['var_rss13'].median(),walking_train_data9['var_rss13'].median(),walking_train_data10['var_rss13'].median(),walking_train_data11['var_rss13'].median(),walking_train_data12['var_rss13'].median()]

sd4 = [bending1_test_data1['var_rss13'].std(),bending1_test_data2['var_rss13'].std(),bending1_train_data1['var_rss13'].std(),bending1_train_data2['var_rss13'].std(),bending1_train_data3['var_rss13'].std(),bending1_train_data4['var_rss13'].std(),bending1_train_data5['var_rss13'].std(),bending2_test_data1['var_rss13'].std(),bending2_test_data2['var_rss13'].std(),bending2_train_data1['var_rss13'].std(),bending2_train_data2['var_rss13'].std(),bending2_train_data3['var_rss13'].std(),bending2_train_data4['var_rss13'].std(),cycling_test_data1['var_rss13'].std(),cycling_test_data2['var_rss13'].std(),cycling_test_data3['var_rss13'].std(),cycling_train_data1['var_rss13'].std(),cycling_train_data2['var_rss13'].std(),cycling_train_data3['var_rss13'].std(),cycling_train_data4['var_rss13'].std(),cycling_train_data5['var_rss13'].std(),cycling_train_data6['var_rss13'].std(),cycling_train_data7['var_rss13'].std(),cycling_train_data8['var_rss13'].std(),cycling_train_data9['var_rss13'].std(),cycling_train_data10['var_rss13'].std(),cycling_train_data11['var_rss13'].std(),cycling_train_data12['var_rss13'].std(),lying_test_data1['var_rss13'].std(),lying_test_data2['var_rss13'].std(),lying_test_data3['var_rss13'].std(),lying_train_data1['var_rss13'].std(),lying_train_data2['var_rss13'].std(),lying_train_data3['var_rss13'].std(),lying_train_data4['var_rss13'].std(),lying_train_data5['var_rss13'].std(),lying_train_data6['var_rss13'].std(),lying_train_data7['var_rss13'].std(),lying_train_data8['var_rss13'].std(),lying_train_data9['var_rss13'].std(),lying_train_data10['var_rss13'].std(),lying_train_data11['var_rss13'].std(),lying_train_data12['var_rss13'].std(),sitting_test_data1['var_rss13'].std(),sitting_test_data2['var_rss13'].std(),sitting_test_data3['var_rss13'].std(),sitting_train_data1['var_rss13'].std(),sitting_train_data2['var_rss13'].std(),sitting_train_data3['var_rss13'].std(),sitting_train_data4['var_rss13'].std(),sitting_train_data5['var_rss13'].std(),sitting_train_data6['var_rss13'].std(),sitting_train_data7['var_rss13'].std(),sitting_train_data8['var_rss13'].std(),sitting_train_data9['var_rss13'].std(),sitting_train_data10['var_rss13'].std(),sitting_train_data11['var_rss13'].std(),sitting_train_data12['var_rss13'].std(),standing_test_data1['var_rss13'].std(),standing_test_data2['var_rss13'].std(),standing_test_data3['var_rss13'].std(),standing_train_data1['var_rss13'].std(),standing_train_data2['var_rss13'].std(),standing_train_data3['var_rss13'].std(),standing_train_data4['var_rss13'].std(),standing_train_data5['var_rss13'].std(),standing_train_data6['var_rss13'].std(),standing_train_data7['var_rss13'].std(),standing_train_data8['var_rss13'].std(),standing_train_data9['var_rss13'].std(),standing_train_data10['var_rss13'].std(),standing_train_data11['var_rss13'].std(),standing_train_data12['var_rss13'].std(),walking_test_data1['var_rss13'].std(),walking_test_data2['var_rss13'].std(),walking_test_data3['var_rss13'].std(),walking_train_data1['var_rss13'].std(),walking_train_data2['var_rss13'].std(),walking_train_data3['var_rss13'].std(),walking_train_data4['var_rss13'].std(),walking_train_data5['var_rss13'].std(),walking_train_data6['var_rss13'].std(),walking_train_data7['var_rss13'].std(),walking_train_data8['var_rss13'].std(),walking_train_data9['var_rss13'].std(),walking_train_data10['var_rss13'].std(),walking_train_data11['var_rss13'].std(),walking_train_data12['var_rss13'].std()]

quart1_4 = [bending1_test_data1['var_rss13'].quantile(0.25),bending1_test_data2['var_rss13'].quantile(0.25),bending1_train_data1['var_rss13'].quantile(0.25),bending1_train_data2['var_rss13'].quantile(0.25),bending1_train_data3['var_rss13'].quantile(0.25),bending1_train_data4['var_rss13'].quantile(0.25),bending1_train_data5['var_rss13'].quantile(0.25),bending2_test_data1['var_rss13'].quantile(0.25),bending2_test_data2['var_rss13'].quantile(0.25),bending2_train_data1['var_rss13'].quantile(0.25),bending2_train_data2['var_rss13'].quantile(0.25),bending2_train_data3['var_rss13'].quantile(0.25),bending2_train_data4['var_rss13'].quantile(0.25),cycling_test_data1['var_rss13'].quantile(0.25),cycling_test_data2['var_rss13'].quantile(0.25),cycling_test_data3['var_rss13'].quantile(0.25),cycling_train_data1['var_rss13'].quantile(0.25),cycling_train_data2['var_rss13'].quantile(0.25),cycling_train_data3['var_rss13'].quantile(0.25),cycling_train_data4['var_rss13'].quantile(0.25),cycling_train_data5['var_rss13'].quantile(0.25),cycling_train_data6['var_rss13'].quantile(0.25),cycling_train_data7['var_rss13'].quantile(0.25),cycling_train_data8['var_rss13'].quantile(0.25),cycling_train_data9['var_rss13'].quantile(0.25),cycling_train_data10['var_rss13'].quantile(0.25),cycling_train_data11['var_rss13'].quantile(0.25),cycling_train_data12['var_rss13'].quantile(0.25),lying_test_data1['var_rss13'].quantile(0.25),lying_test_data2['var_rss13'].quantile(0.25),lying_test_data3['var_rss13'].quantile(0.25),lying_train_data1['var_rss13'].quantile(0.25),lying_train_data2['var_rss13'].quantile(0.25),lying_train_data3['var_rss13'].quantile(0.25),lying_train_data4['var_rss13'].quantile(0.25),lying_train_data5['var_rss13'].quantile(0.25),lying_train_data6['var_rss13'].quantile(0.25),lying_train_data7['var_rss13'].quantile(0.25),lying_train_data8['var_rss13'].quantile(0.25),lying_train_data9['var_rss13'].quantile(0.25),lying_train_data10['var_rss13'].quantile(0.25),lying_train_data11['var_rss13'].quantile(0.25),lying_train_data12['var_rss13'].quantile(0.25),sitting_test_data1['var_rss13'].quantile(0.25),sitting_test_data2['var_rss13'].quantile(0.25),sitting_test_data3['var_rss13'].quantile(0.25),sitting_train_data1['var_rss13'].quantile(0.25),sitting_train_data2['var_rss13'].quantile(0.25),sitting_train_data3['var_rss13'].quantile(0.25),sitting_train_data4['var_rss13'].quantile(0.25),sitting_train_data5['var_rss13'].quantile(0.25),sitting_train_data6['var_rss13'].quantile(0.25),sitting_train_data7['var_rss13'].quantile(0.25),sitting_train_data8['var_rss13'].quantile(0.25),sitting_train_data9['var_rss13'].quantile(0.25),sitting_train_data10['var_rss13'].quantile(0.25),sitting_train_data11['var_rss13'].quantile(0.25),sitting_train_data12['var_rss13'].quantile(0.25),standing_test_data1['var_rss13'].quantile(0.25),standing_test_data2['var_rss13'].quantile(0.25),standing_test_data3['var_rss13'].quantile(0.25),standing_train_data1['var_rss13'].quantile(0.25),standing_train_data2['var_rss13'].quantile(0.25),standing_train_data3['var_rss13'].quantile(0.25),standing_train_data4['var_rss13'].quantile(0.25),standing_train_data5['var_rss13'].quantile(0.25),standing_train_data6['var_rss13'].quantile(0.25),standing_train_data7['var_rss13'].quantile(0.25),standing_train_data8['var_rss13'].quantile(0.25),standing_train_data9['var_rss13'].quantile(0.25),standing_train_data10['var_rss13'].quantile(0.25),standing_train_data11['var_rss13'].quantile(0.25),standing_train_data12['var_rss13'].quantile(0.25),walking_test_data1['var_rss13'].quantile(0.25),walking_test_data2['var_rss13'].quantile(0.25),walking_test_data3['var_rss13'].quantile(0.25),walking_train_data1['var_rss13'].quantile(0.25),walking_train_data2['var_rss13'].quantile(0.25),walking_train_data3['var_rss13'].quantile(0.25),walking_train_data4['var_rss13'].quantile(0.25),walking_train_data5['var_rss13'].quantile(0.25),walking_train_data6['var_rss13'].quantile(0.25),walking_train_data7['var_rss13'].quantile(0.25),walking_train_data8['var_rss13'].quantile(0.25),walking_train_data9['var_rss13'].quantile(0.25),walking_train_data10['var_rss13'].quantile(0.25),walking_train_data11['var_rss13'].quantile(0.25),walking_train_data12['var_rss13'].quantile(0.25)]

quart3_4 = [bending1_test_data1['var_rss13'].quantile(0.75),bending1_test_data2['var_rss13'].quantile(0.75),bending1_train_data1['var_rss13'].quantile(0.75),bending1_train_data2['var_rss13'].quantile(0.75),bending1_train_data3['var_rss13'].quantile(0.75),bending1_train_data4['var_rss13'].quantile(0.75),bending1_train_data5['var_rss13'].quantile(0.75),bending2_test_data1['var_rss13'].quantile(0.75),bending2_test_data2['var_rss13'].quantile(0.75),bending2_train_data1['var_rss13'].quantile(0.75),bending2_train_data2['var_rss13'].quantile(0.75),bending2_train_data3['var_rss13'].quantile(0.75),bending2_train_data4['var_rss13'].quantile(0.75),cycling_test_data1['var_rss13'].quantile(0.75),cycling_test_data2['var_rss13'].quantile(0.75),cycling_test_data3['var_rss13'].quantile(0.75),cycling_train_data1['var_rss13'].quantile(0.75),cycling_train_data2['var_rss13'].quantile(0.75),cycling_train_data3['var_rss13'].quantile(0.75),cycling_train_data4['var_rss13'].quantile(0.75),cycling_train_data5['var_rss13'].quantile(0.75),cycling_train_data6['var_rss13'].quantile(0.75),cycling_train_data7['var_rss13'].quantile(0.75),cycling_train_data8['var_rss13'].quantile(0.75),cycling_train_data9['var_rss13'].quantile(0.75),cycling_train_data10['var_rss13'].quantile(0.75),cycling_train_data11['var_rss13'].quantile(0.75),cycling_train_data12['var_rss13'].quantile(0.75),lying_test_data1['var_rss13'].quantile(0.75),lying_test_data2['var_rss13'].quantile(0.75),lying_test_data3['var_rss13'].quantile(0.75),lying_train_data1['var_rss13'].quantile(0.75),lying_train_data2['var_rss13'].quantile(0.75),lying_train_data3['var_rss13'].quantile(0.75),lying_train_data4['var_rss13'].quantile(0.75),lying_train_data5['var_rss13'].quantile(0.75),lying_train_data6['var_rss13'].quantile(0.75),lying_train_data7['var_rss13'].quantile(0.75),lying_train_data8['var_rss13'].quantile(0.75),lying_train_data9['var_rss13'].quantile(0.75),lying_train_data10['var_rss13'].quantile(0.75),lying_train_data11['var_rss13'].quantile(0.75),lying_train_data12['var_rss13'].quantile(0.75),sitting_test_data1['var_rss13'].quantile(0.75),sitting_test_data2['var_rss13'].quantile(0.75),sitting_test_data3['var_rss13'].quantile(0.75),sitting_train_data1['var_rss13'].quantile(0.75),sitting_train_data2['var_rss13'].quantile(0.75),sitting_train_data3['var_rss13'].quantile(0.75),sitting_train_data4['var_rss13'].quantile(0.75),sitting_train_data5['var_rss13'].quantile(0.75),sitting_train_data6['var_rss13'].quantile(0.75),sitting_train_data7['var_rss13'].quantile(0.75),sitting_train_data8['var_rss13'].quantile(0.75),sitting_train_data9['var_rss13'].quantile(0.75),sitting_train_data10['var_rss13'].quantile(0.75),sitting_train_data11['var_rss13'].quantile(0.75),sitting_train_data12['var_rss13'].quantile(0.75),standing_test_data1['var_rss13'].quantile(0.75),standing_test_data2['var_rss13'].quantile(0.75),standing_test_data3['var_rss13'].quantile(0.75),standing_train_data1['var_rss13'].quantile(0.75),standing_train_data2['var_rss13'].quantile(0.75),standing_train_data3['var_rss13'].quantile(0.75),standing_train_data4['var_rss13'].quantile(0.75),standing_train_data5['var_rss13'].quantile(0.75),standing_train_data6['var_rss13'].quantile(0.75),standing_train_data7['var_rss13'].quantile(0.75),standing_train_data8['var_rss13'].quantile(0.75),standing_train_data9['var_rss13'].quantile(0.75),standing_train_data10['var_rss13'].quantile(0.75),standing_train_data11['var_rss13'].quantile(0.75),standing_train_data12['var_rss13'].quantile(0.75),walking_test_data1['var_rss13'].quantile(0.75),walking_test_data2['var_rss13'].quantile(0.75),walking_test_data3['var_rss13'].quantile(0.75),walking_train_data1['var_rss13'].quantile(0.75),walking_train_data2['var_rss13'].quantile(0.75),walking_train_data3['var_rss13'].quantile(0.75),walking_train_data4['var_rss13'].quantile(0.75),walking_train_data5['var_rss13'].quantile(0.75),walking_train_data6['var_rss13'].quantile(0.75),walking_train_data7['var_rss13'].quantile(0.75),walking_train_data8['var_rss13'].quantile(0.75),walking_train_data9['var_rss13'].quantile(0.75),walking_train_data10['var_rss13'].quantile(0.75),walking_train_data11['var_rss13'].quantile(0.75),walking_train_data12['var_rss13'].quantile(0.75)]

min5 = [bending1_test_data1['avg_rss23'].min(),bending1_test_data2['avg_rss23'].min(),bending1_train_data1['avg_rss23'].min(),bending1_train_data2['avg_rss23'].min(),bending1_train_data3['avg_rss23'].min(),bending1_train_data4['avg_rss23'].min(),bending1_train_data5['avg_rss23'].min(),bending2_test_data1['avg_rss23'].min(),bending2_test_data2['avg_rss23'].min(),bending2_train_data1['avg_rss23'].min(),bending2_train_data2['avg_rss23'].min(),bending2_train_data3['avg_rss23'].min(),bending2_train_data4['avg_rss23'].min(),cycling_test_data1['avg_rss23'].min(),cycling_test_data2['avg_rss23'].min(),cycling_test_data3['avg_rss23'].min(),cycling_train_data1['avg_rss23'].min(),cycling_train_data2['avg_rss23'].min(),cycling_train_data3['avg_rss23'].min(),cycling_train_data4['avg_rss23'].min(),cycling_train_data5['avg_rss23'].min(),cycling_train_data6['avg_rss23'].min(),cycling_train_data7['avg_rss23'].min(),cycling_train_data8['avg_rss23'].min(),cycling_train_data9['avg_rss23'].min(),cycling_train_data10['avg_rss23'].min(),cycling_train_data11['avg_rss23'].min(),cycling_train_data12['avg_rss23'].min(),lying_test_data1['avg_rss23'].min(),lying_test_data2['avg_rss23'].min(),lying_test_data3['avg_rss23'].min(),lying_train_data1['avg_rss23'].min(),lying_train_data2['avg_rss23'].min(),lying_train_data3['avg_rss23'].min(),lying_train_data4['avg_rss23'].min(),lying_train_data5['avg_rss23'].min(),lying_train_data6['avg_rss23'].min(),lying_train_data7['avg_rss23'].min(),lying_train_data8['avg_rss23'].min(),lying_train_data9['avg_rss23'].min(),lying_train_data10['avg_rss23'].min(),lying_train_data11['avg_rss23'].min(),lying_train_data12['avg_rss23'].min(),sitting_test_data1['avg_rss23'].min(),sitting_test_data2['avg_rss23'].min(),sitting_test_data3['avg_rss23'].min(),sitting_train_data1['avg_rss23'].min(),sitting_train_data2['avg_rss23'].min(),sitting_train_data3['avg_rss23'].min(),sitting_train_data4['avg_rss23'].min(),sitting_train_data5['avg_rss23'].min(),sitting_train_data6['avg_rss23'].min(),sitting_train_data7['avg_rss23'].min(),sitting_train_data8['avg_rss23'].min(),sitting_train_data9['avg_rss23'].min(),sitting_train_data10['avg_rss23'].min(),sitting_train_data11['avg_rss23'].min(),sitting_train_data12['avg_rss23'].min(),standing_test_data1['avg_rss23'].min(),standing_test_data2['avg_rss23'].min(),standing_test_data3['avg_rss23'].min(),standing_train_data1['avg_rss23'].min(),standing_train_data2['avg_rss23'].min(),standing_train_data3['avg_rss23'].min(),standing_train_data4['avg_rss23'].min(),standing_train_data5['avg_rss23'].min(),standing_train_data6['avg_rss23'].min(),standing_train_data7['avg_rss23'].min(),standing_train_data8['avg_rss23'].min(),standing_train_data9['avg_rss23'].min(),standing_train_data10['avg_rss23'].min(),standing_train_data11['avg_rss23'].min(),standing_train_data12['avg_rss23'].min(),walking_test_data1['avg_rss23'].min(),walking_test_data2['avg_rss23'].min(),walking_test_data3['avg_rss23'].min(),walking_train_data1['avg_rss23'].min(),walking_train_data2['avg_rss23'].min(),walking_train_data3['avg_rss23'].min(),walking_train_data4['avg_rss23'].min(),walking_train_data5['avg_rss23'].min(),walking_train_data6['avg_rss23'].min(),walking_train_data7['avg_rss23'].min(),walking_train_data8['avg_rss23'].min(),walking_train_data9['avg_rss23'].min(),walking_train_data10['avg_rss23'].min(),walking_train_data11['avg_rss23'].min(),walking_train_data12['avg_rss23'].min()]

max5 = [bending1_test_data1['avg_rss23'].max(),bending1_test_data2['avg_rss23'].max(),bending1_train_data1['avg_rss23'].max(),bending1_train_data2['avg_rss23'].max(),bending1_train_data3['avg_rss23'].max(),bending1_train_data4['avg_rss23'].max(),bending1_train_data5['avg_rss23'].max(),bending2_test_data1['avg_rss23'].max(),bending2_test_data2['avg_rss23'].max(),bending2_train_data1['avg_rss23'].max(),bending2_train_data2['avg_rss23'].max(),bending2_train_data3['avg_rss23'].max(),bending2_train_data4['avg_rss23'].max(),cycling_test_data1['avg_rss23'].max(),cycling_test_data2['avg_rss23'].max(),cycling_test_data3['avg_rss23'].max(),cycling_train_data1['avg_rss23'].max(),cycling_train_data2['avg_rss23'].max(),cycling_train_data3['avg_rss23'].max(),cycling_train_data4['avg_rss23'].max(),cycling_train_data5['avg_rss23'].max(),cycling_train_data6['avg_rss23'].max(),cycling_train_data7['avg_rss23'].max(),cycling_train_data8['avg_rss23'].max(),cycling_train_data9['avg_rss23'].max(),cycling_train_data10['avg_rss23'].max(),cycling_train_data11['avg_rss23'].max(),cycling_train_data12['avg_rss23'].max(),lying_test_data1['avg_rss23'].max(),lying_test_data2['avg_rss23'].max(),lying_test_data3['avg_rss23'].max(),lying_train_data1['avg_rss23'].max(),lying_train_data2['avg_rss23'].max(),lying_train_data3['avg_rss23'].max(),lying_train_data4['avg_rss23'].max(),lying_train_data5['avg_rss23'].max(),lying_train_data6['avg_rss23'].max(),lying_train_data7['avg_rss23'].max(),lying_train_data8['avg_rss23'].max(),lying_train_data9['avg_rss23'].max(),lying_train_data10['avg_rss23'].max(),lying_train_data11['avg_rss23'].max(),lying_train_data12['avg_rss23'].max(),sitting_test_data1['avg_rss23'].max(),sitting_test_data2['avg_rss23'].max(),sitting_test_data3['avg_rss23'].max(),sitting_train_data1['avg_rss23'].max(),sitting_train_data2['avg_rss23'].max(),sitting_train_data3['avg_rss23'].max(),sitting_train_data4['avg_rss23'].max(),sitting_train_data5['avg_rss23'].max(),sitting_train_data6['avg_rss23'].max(),sitting_train_data7['avg_rss23'].max(),sitting_train_data8['avg_rss23'].max(),sitting_train_data9['avg_rss23'].max(),sitting_train_data10['avg_rss23'].max(),sitting_train_data11['avg_rss23'].max(),sitting_train_data12['avg_rss23'].max(),standing_test_data1['avg_rss23'].max(),standing_test_data2['avg_rss23'].max(),standing_test_data3['avg_rss23'].max(),standing_train_data1['avg_rss23'].max(),standing_train_data2['avg_rss23'].max(),standing_train_data3['avg_rss23'].max(),standing_train_data4['avg_rss23'].max(),standing_train_data5['avg_rss23'].max(),standing_train_data6['avg_rss23'].max(),standing_train_data7['avg_rss23'].max(),standing_train_data8['avg_rss23'].max(),standing_train_data9['avg_rss23'].max(),standing_train_data10['avg_rss23'].max(),standing_train_data11['avg_rss23'].max(),standing_train_data12['avg_rss23'].max(),walking_test_data1['avg_rss23'].max(),walking_test_data2['avg_rss23'].max(),walking_test_data3['avg_rss23'].max(),walking_train_data1['avg_rss23'].max(),walking_train_data2['avg_rss23'].max(),walking_train_data3['avg_rss23'].max(),walking_train_data4['avg_rss23'].max(),walking_train_data5['avg_rss23'].max(),walking_train_data6['avg_rss23'].max(),walking_train_data7['avg_rss23'].max(),walking_train_data8['avg_rss23'].max(),walking_train_data9['avg_rss23'].max(),walking_train_data10['avg_rss23'].max(),walking_train_data11['avg_rss23'].max(),walking_train_data12['avg_rss23'].max()]

mean5 = [bending1_test_data1['avg_rss23'].mean(),bending1_test_data2['avg_rss23'].mean(),bending1_train_data1['avg_rss23'].mean(),bending1_train_data2['avg_rss23'].mean(),bending1_train_data3['avg_rss23'].mean(),bending1_train_data4['avg_rss23'].mean(),bending1_train_data5['avg_rss23'].mean(),bending2_test_data1['avg_rss23'].mean(),bending2_test_data2['avg_rss23'].mean(),bending2_train_data1['avg_rss23'].mean(),bending2_train_data2['avg_rss23'].mean(),bending2_train_data3['avg_rss23'].mean(),bending2_train_data4['avg_rss23'].mean(),cycling_test_data1['avg_rss23'].mean(),cycling_test_data2['avg_rss23'].mean(),cycling_test_data3['avg_rss23'].mean(),cycling_train_data1['avg_rss23'].mean(),cycling_train_data2['avg_rss23'].mean(),cycling_train_data3['avg_rss23'].mean(),cycling_train_data4['avg_rss23'].mean(),cycling_train_data5['avg_rss23'].mean(),cycling_train_data6['avg_rss23'].mean(),cycling_train_data7['avg_rss23'].mean(),cycling_train_data8['avg_rss23'].mean(),cycling_train_data9['avg_rss23'].mean(),cycling_train_data10['avg_rss23'].mean(),cycling_train_data11['avg_rss23'].mean(),cycling_train_data12['avg_rss23'].mean(),lying_test_data1['avg_rss23'].mean(),lying_test_data2['avg_rss23'].mean(),lying_test_data3['avg_rss23'].mean(),lying_train_data1['avg_rss23'].mean(),lying_train_data2['avg_rss23'].mean(),lying_train_data3['avg_rss23'].mean(),lying_train_data4['avg_rss23'].mean(),lying_train_data5['avg_rss23'].mean(),lying_train_data6['avg_rss23'].mean(),lying_train_data7['avg_rss23'].mean(),lying_train_data8['avg_rss23'].mean(),lying_train_data9['avg_rss23'].mean(),lying_train_data10['avg_rss23'].mean(),lying_train_data11['avg_rss23'].mean(),lying_train_data12['avg_rss23'].mean(),sitting_test_data1['avg_rss23'].mean(),sitting_test_data2['avg_rss23'].mean(),sitting_test_data3['avg_rss23'].mean(),sitting_train_data1['avg_rss23'].mean(),sitting_train_data2['avg_rss23'].mean(),sitting_train_data3['avg_rss23'].mean(),sitting_train_data4['avg_rss23'].mean(),sitting_train_data5['avg_rss23'].mean(),sitting_train_data6['avg_rss23'].mean(),sitting_train_data7['avg_rss23'].mean(),sitting_train_data8['avg_rss23'].mean(),sitting_train_data9['avg_rss23'].mean(),sitting_train_data10['avg_rss23'].mean(),sitting_train_data11['avg_rss23'].mean(),sitting_train_data12['avg_rss23'].mean(),standing_test_data1['avg_rss23'].mean(),standing_test_data2['avg_rss23'].mean(),standing_test_data3['avg_rss23'].mean(),standing_train_data1['avg_rss23'].mean(),standing_train_data2['avg_rss23'].mean(),standing_train_data3['avg_rss23'].mean(),standing_train_data4['avg_rss23'].mean(),standing_train_data5['avg_rss23'].mean(),standing_train_data6['avg_rss23'].mean(),standing_train_data7['avg_rss23'].mean(),standing_train_data8['avg_rss23'].mean(),standing_train_data9['avg_rss23'].mean(),standing_train_data10['avg_rss23'].mean(),standing_train_data11['avg_rss23'].mean(),standing_train_data12['avg_rss23'].mean(),walking_test_data1['avg_rss23'].mean(),walking_test_data2['avg_rss23'].mean(),walking_test_data3['avg_rss23'].mean(),walking_train_data1['avg_rss23'].mean(),walking_train_data2['avg_rss23'].mean(),walking_train_data3['avg_rss23'].mean(),walking_train_data4['avg_rss23'].mean(),walking_train_data5['avg_rss23'].mean(),walking_train_data6['avg_rss23'].mean(),walking_train_data7['avg_rss23'].mean(),walking_train_data8['avg_rss23'].mean(),walking_train_data9['avg_rss23'].mean(),walking_train_data10['avg_rss23'].mean(),walking_train_data11['avg_rss23'].mean(),walking_train_data12['avg_rss23'].mean()]

median5 = [bending1_test_data1['avg_rss23'].median(),bending1_test_data2['avg_rss23'].median(),bending1_train_data1['avg_rss23'].median(),bending1_train_data2['avg_rss23'].median(),bending1_train_data3['avg_rss23'].median(),bending1_train_data4['avg_rss23'].median(),bending1_train_data5['avg_rss23'].median(),bending2_test_data1['avg_rss23'].median(),bending2_test_data2['avg_rss23'].median(),bending2_train_data1['avg_rss23'].median(),bending2_train_data2['avg_rss23'].median(),bending2_train_data3['avg_rss23'].median(),bending2_train_data4['avg_rss23'].median(),cycling_test_data1['avg_rss23'].median(),cycling_test_data2['avg_rss23'].median(),cycling_test_data3['avg_rss23'].median(),cycling_train_data1['avg_rss23'].median(),cycling_train_data2['avg_rss23'].median(),cycling_train_data3['avg_rss23'].median(),cycling_train_data4['avg_rss23'].median(),cycling_train_data5['avg_rss23'].median(),cycling_train_data6['avg_rss23'].median(),cycling_train_data7['avg_rss23'].median(),cycling_train_data8['avg_rss23'].median(),cycling_train_data9['avg_rss23'].median(),cycling_train_data10['avg_rss23'].median(),cycling_train_data11['avg_rss23'].median(),cycling_train_data12['avg_rss23'].median(),lying_test_data1['avg_rss23'].median(),lying_test_data2['avg_rss23'].median(),lying_test_data3['avg_rss23'].median(),lying_train_data1['avg_rss23'].median(),lying_train_data2['avg_rss23'].median(),lying_train_data3['avg_rss23'].median(),lying_train_data4['avg_rss23'].median(),lying_train_data5['avg_rss23'].median(),lying_train_data6['avg_rss23'].median(),lying_train_data7['avg_rss23'].median(),lying_train_data8['avg_rss23'].median(),lying_train_data9['avg_rss23'].median(),lying_train_data10['avg_rss23'].median(),lying_train_data11['avg_rss23'].median(),lying_train_data12['avg_rss23'].median(),sitting_test_data1['avg_rss23'].median(),sitting_test_data2['avg_rss23'].median(),sitting_test_data3['avg_rss23'].median(),sitting_train_data1['avg_rss23'].median(),sitting_train_data2['avg_rss23'].median(),sitting_train_data3['avg_rss23'].median(),sitting_train_data4['avg_rss23'].median(),sitting_train_data5['avg_rss23'].median(),sitting_train_data6['avg_rss23'].median(),sitting_train_data7['avg_rss23'].median(),sitting_train_data8['avg_rss23'].median(),sitting_train_data9['avg_rss23'].median(),sitting_train_data10['avg_rss23'].median(),sitting_train_data11['avg_rss23'].median(),sitting_train_data12['avg_rss23'].median(),standing_test_data1['avg_rss23'].median(),standing_test_data2['avg_rss23'].median(),standing_test_data3['avg_rss23'].median(),standing_train_data1['avg_rss23'].median(),standing_train_data2['avg_rss23'].median(),standing_train_data3['avg_rss23'].median(),standing_train_data4['avg_rss23'].median(),standing_train_data5['avg_rss23'].median(),standing_train_data6['avg_rss23'].median(),standing_train_data7['avg_rss23'].median(),standing_train_data8['avg_rss23'].median(),standing_train_data9['avg_rss23'].median(),standing_train_data10['avg_rss23'].median(),standing_train_data11['avg_rss23'].median(),standing_train_data12['avg_rss23'].median(),walking_test_data1['avg_rss23'].median(),walking_test_data2['avg_rss23'].median(),walking_test_data3['avg_rss23'].median(),walking_train_data1['avg_rss23'].median(),walking_train_data2['avg_rss23'].median(),walking_train_data3['avg_rss23'].median(),walking_train_data4['avg_rss23'].median(),walking_train_data5['avg_rss23'].median(),walking_train_data6['avg_rss23'].median(),walking_train_data7['avg_rss23'].median(),walking_train_data8['avg_rss23'].median(),walking_train_data9['avg_rss23'].median(),walking_train_data10['avg_rss23'].median(),walking_train_data11['avg_rss23'].median(),walking_train_data12['avg_rss23'].median()]

sd5 = [bending1_test_data1['avg_rss23'].std(),bending1_test_data2['avg_rss23'].std(),bending1_train_data1['avg_rss23'].std(),bending1_train_data2['avg_rss23'].std(),bending1_train_data3['avg_rss23'].std(),bending1_train_data4['avg_rss23'].std(),bending1_train_data5['avg_rss23'].std(),bending2_test_data1['avg_rss23'].std(),bending2_test_data2['avg_rss23'].std(),bending2_train_data1['avg_rss23'].std(),bending2_train_data2['avg_rss23'].std(),bending2_train_data3['avg_rss23'].std(),bending2_train_data4['avg_rss23'].std(),cycling_test_data1['avg_rss23'].std(),cycling_test_data2['avg_rss23'].std(),cycling_test_data3['avg_rss23'].std(),cycling_train_data1['avg_rss23'].std(),cycling_train_data2['avg_rss23'].std(),cycling_train_data3['avg_rss23'].std(),cycling_train_data4['avg_rss23'].std(),cycling_train_data5['avg_rss23'].std(),cycling_train_data6['avg_rss23'].std(),cycling_train_data7['avg_rss23'].std(),cycling_train_data8['avg_rss23'].std(),cycling_train_data9['avg_rss23'].std(),cycling_train_data10['avg_rss23'].std(),cycling_train_data11['avg_rss23'].std(),cycling_train_data12['avg_rss23'].std(),lying_test_data1['avg_rss23'].std(),lying_test_data2['avg_rss23'].std(),lying_test_data3['avg_rss23'].std(),lying_train_data1['avg_rss23'].std(),lying_train_data2['avg_rss23'].std(),lying_train_data3['avg_rss23'].std(),lying_train_data4['avg_rss23'].std(),lying_train_data5['avg_rss23'].std(),lying_train_data6['avg_rss23'].std(),lying_train_data7['avg_rss23'].std(),lying_train_data8['avg_rss23'].std(),lying_train_data9['avg_rss23'].std(),lying_train_data10['avg_rss23'].std(),lying_train_data11['avg_rss23'].std(),lying_train_data12['avg_rss23'].std(),sitting_test_data1['avg_rss23'].std(),sitting_test_data2['avg_rss23'].std(),sitting_test_data3['avg_rss23'].std(),sitting_train_data1['avg_rss23'].std(),sitting_train_data2['avg_rss23'].std(),sitting_train_data3['avg_rss23'].std(),sitting_train_data4['avg_rss23'].std(),sitting_train_data5['avg_rss23'].std(),sitting_train_data6['avg_rss23'].std(),sitting_train_data7['avg_rss23'].std(),sitting_train_data8['avg_rss23'].std(),sitting_train_data9['avg_rss23'].std(),sitting_train_data10['avg_rss23'].std(),sitting_train_data11['avg_rss23'].std(),sitting_train_data12['avg_rss23'].std(),standing_test_data1['avg_rss23'].std(),standing_test_data2['avg_rss23'].std(),standing_test_data3['avg_rss23'].std(),standing_train_data1['avg_rss23'].std(),standing_train_data2['avg_rss23'].std(),standing_train_data3['avg_rss23'].std(),standing_train_data4['avg_rss23'].std(),standing_train_data5['avg_rss23'].std(),standing_train_data6['avg_rss23'].std(),standing_train_data7['avg_rss23'].std(),standing_train_data8['avg_rss23'].std(),standing_train_data9['avg_rss23'].std(),standing_train_data10['avg_rss23'].std(),standing_train_data11['avg_rss23'].std(),standing_train_data12['avg_rss23'].std(),walking_test_data1['avg_rss23'].std(),walking_test_data2['avg_rss23'].std(),walking_test_data3['avg_rss23'].std(),walking_train_data1['avg_rss23'].std(),walking_train_data2['avg_rss23'].std(),walking_train_data3['avg_rss23'].std(),walking_train_data4['avg_rss23'].std(),walking_train_data5['avg_rss23'].std(),walking_train_data6['avg_rss23'].std(),walking_train_data7['avg_rss23'].std(),walking_train_data8['avg_rss23'].std(),walking_train_data9['avg_rss23'].std(),walking_train_data10['avg_rss23'].std(),walking_train_data11['avg_rss23'].std(),walking_train_data12['avg_rss23'].std()]

quart1_5 = [bending1_test_data1['avg_rss23'].quantile(0.25),bending1_test_data2['avg_rss23'].quantile(0.25),bending1_train_data1['avg_rss23'].quantile(0.25),bending1_train_data2['avg_rss23'].quantile(0.25),bending1_train_data3['avg_rss23'].quantile(0.25),bending1_train_data4['avg_rss23'].quantile(0.25),bending1_train_data5['avg_rss23'].quantile(0.25),bending2_test_data1['avg_rss23'].quantile(0.25),bending2_test_data2['avg_rss23'].quantile(0.25),bending2_train_data1['avg_rss23'].quantile(0.25),bending2_train_data2['avg_rss23'].quantile(0.25),bending2_train_data3['avg_rss23'].quantile(0.25),bending2_train_data4['avg_rss23'].quantile(0.25),cycling_test_data1['avg_rss23'].quantile(0.25),cycling_test_data2['avg_rss23'].quantile(0.25),cycling_test_data3['avg_rss23'].quantile(0.25),cycling_train_data1['avg_rss23'].quantile(0.25),cycling_train_data2['avg_rss23'].quantile(0.25),cycling_train_data3['avg_rss23'].quantile(0.25),cycling_train_data4['avg_rss23'].quantile(0.25),cycling_train_data5['avg_rss23'].quantile(0.25),cycling_train_data6['avg_rss23'].quantile(0.25),cycling_train_data7['avg_rss23'].quantile(0.25),cycling_train_data8['avg_rss23'].quantile(0.25),cycling_train_data9['avg_rss23'].quantile(0.25),cycling_train_data10['avg_rss23'].quantile(0.25),cycling_train_data11['avg_rss23'].quantile(0.25),cycling_train_data12['avg_rss23'].quantile(0.25),lying_test_data1['avg_rss23'].quantile(0.25),lying_test_data2['avg_rss23'].quantile(0.25),lying_test_data3['avg_rss23'].quantile(0.25),lying_train_data1['avg_rss23'].quantile(0.25),lying_train_data2['avg_rss23'].quantile(0.25),lying_train_data3['avg_rss23'].quantile(0.25),lying_train_data4['avg_rss23'].quantile(0.25),lying_train_data5['avg_rss23'].quantile(0.25),lying_train_data6['avg_rss23'].quantile(0.25),lying_train_data7['avg_rss23'].quantile(0.25),lying_train_data8['avg_rss23'].quantile(0.25),lying_train_data9['avg_rss23'].quantile(0.25),lying_train_data10['avg_rss23'].quantile(0.25),lying_train_data11['avg_rss23'].quantile(0.25),lying_train_data12['avg_rss23'].quantile(0.25),sitting_test_data1['avg_rss23'].quantile(0.25),sitting_test_data2['avg_rss23'].quantile(0.25),sitting_test_data3['avg_rss23'].quantile(0.25),sitting_train_data1['avg_rss23'].quantile(0.25),sitting_train_data2['avg_rss23'].quantile(0.25),sitting_train_data3['avg_rss23'].quantile(0.25),sitting_train_data4['avg_rss23'].quantile(0.25),sitting_train_data5['avg_rss23'].quantile(0.25),sitting_train_data6['avg_rss23'].quantile(0.25),sitting_train_data7['avg_rss23'].quantile(0.25),sitting_train_data8['avg_rss23'].quantile(0.25),sitting_train_data9['avg_rss23'].quantile(0.25),sitting_train_data10['avg_rss23'].quantile(0.25),sitting_train_data11['avg_rss23'].quantile(0.25),sitting_train_data12['avg_rss23'].quantile(0.25),standing_test_data1['avg_rss23'].quantile(0.25),standing_test_data2['avg_rss23'].quantile(0.25),standing_test_data3['avg_rss23'].quantile(0.25),standing_train_data1['avg_rss23'].quantile(0.25),standing_train_data2['avg_rss23'].quantile(0.25),standing_train_data3['avg_rss23'].quantile(0.25),standing_train_data4['avg_rss23'].quantile(0.25),standing_train_data5['avg_rss23'].quantile(0.25),standing_train_data6['avg_rss23'].quantile(0.25),standing_train_data7['avg_rss23'].quantile(0.25),standing_train_data8['avg_rss23'].quantile(0.25),standing_train_data9['avg_rss23'].quantile(0.25),standing_train_data10['avg_rss23'].quantile(0.25),standing_train_data11['avg_rss23'].quantile(0.25),standing_train_data12['avg_rss23'].quantile(0.25),walking_test_data1['avg_rss23'].quantile(0.25),walking_test_data2['avg_rss23'].quantile(0.25),walking_test_data3['avg_rss23'].quantile(0.25),walking_train_data1['avg_rss23'].quantile(0.25),walking_train_data2['avg_rss23'].quantile(0.25),walking_train_data3['avg_rss23'].quantile(0.25),walking_train_data4['avg_rss23'].quantile(0.25),walking_train_data5['avg_rss23'].quantile(0.25),walking_train_data6['avg_rss23'].quantile(0.25),walking_train_data7['avg_rss23'].quantile(0.25),walking_train_data8['avg_rss23'].quantile(0.25),walking_train_data9['avg_rss23'].quantile(0.25),walking_train_data10['avg_rss23'].quantile(0.25),walking_train_data11['avg_rss23'].quantile(0.25),walking_train_data12['avg_rss23'].quantile(0.25)]

quart3_5 = [bending1_test_data1['avg_rss23'].quantile(0.75),bending1_test_data2['avg_rss23'].quantile(0.75),bending1_train_data1['avg_rss23'].quantile(0.75),bending1_train_data2['avg_rss23'].quantile(0.75),bending1_train_data3['avg_rss23'].quantile(0.75),bending1_train_data4['avg_rss23'].quantile(0.75),bending1_train_data5['avg_rss23'].quantile(0.75),bending2_test_data1['avg_rss23'].quantile(0.75),bending2_test_data2['avg_rss23'].quantile(0.75),bending2_train_data1['avg_rss23'].quantile(0.75),bending2_train_data2['avg_rss23'].quantile(0.75),bending2_train_data3['avg_rss23'].quantile(0.75),bending2_train_data4['avg_rss23'].quantile(0.75),cycling_test_data1['avg_rss23'].quantile(0.75),cycling_test_data2['avg_rss23'].quantile(0.75),cycling_test_data3['avg_rss23'].quantile(0.75),cycling_train_data1['avg_rss23'].quantile(0.75),cycling_train_data2['avg_rss23'].quantile(0.75),cycling_train_data3['avg_rss23'].quantile(0.75),cycling_train_data4['avg_rss23'].quantile(0.75),cycling_train_data5['avg_rss23'].quantile(0.75),cycling_train_data6['avg_rss23'].quantile(0.75),cycling_train_data7['avg_rss23'].quantile(0.75),cycling_train_data8['avg_rss23'].quantile(0.75),cycling_train_data9['avg_rss23'].quantile(0.75),cycling_train_data10['avg_rss23'].quantile(0.75),cycling_train_data11['avg_rss23'].quantile(0.75),cycling_train_data12['avg_rss23'].quantile(0.75),lying_test_data1['avg_rss23'].quantile(0.75),lying_test_data2['avg_rss23'].quantile(0.75),lying_test_data3['avg_rss23'].quantile(0.75),lying_train_data1['avg_rss23'].quantile(0.75),lying_train_data2['avg_rss23'].quantile(0.75),lying_train_data3['avg_rss23'].quantile(0.75),lying_train_data4['avg_rss23'].quantile(0.75),lying_train_data5['avg_rss23'].quantile(0.75),lying_train_data6['avg_rss23'].quantile(0.75),lying_train_data7['avg_rss23'].quantile(0.75),lying_train_data8['avg_rss23'].quantile(0.75),lying_train_data9['avg_rss23'].quantile(0.75),lying_train_data10['avg_rss23'].quantile(0.75),lying_train_data11['avg_rss23'].quantile(0.75),lying_train_data12['avg_rss23'].quantile(0.75),sitting_test_data1['avg_rss23'].quantile(0.75),sitting_test_data2['avg_rss23'].quantile(0.75),sitting_test_data3['avg_rss23'].quantile(0.75),sitting_train_data1['avg_rss23'].quantile(0.75),sitting_train_data2['avg_rss23'].quantile(0.75),sitting_train_data3['avg_rss23'].quantile(0.75),sitting_train_data4['avg_rss23'].quantile(0.75),sitting_train_data5['avg_rss23'].quantile(0.75),sitting_train_data6['avg_rss23'].quantile(0.75),sitting_train_data7['avg_rss23'].quantile(0.75),sitting_train_data8['avg_rss23'].quantile(0.75),sitting_train_data9['avg_rss23'].quantile(0.75),sitting_train_data10['avg_rss23'].quantile(0.75),sitting_train_data11['avg_rss23'].quantile(0.75),sitting_train_data12['avg_rss23'].quantile(0.75),standing_test_data1['avg_rss23'].quantile(0.75),standing_test_data2['avg_rss23'].quantile(0.75),standing_test_data3['avg_rss23'].quantile(0.75),standing_train_data1['avg_rss23'].quantile(0.75),standing_train_data2['avg_rss23'].quantile(0.75),standing_train_data3['avg_rss23'].quantile(0.75),standing_train_data4['avg_rss23'].quantile(0.75),standing_train_data5['avg_rss23'].quantile(0.75),standing_train_data6['avg_rss23'].quantile(0.75),standing_train_data7['avg_rss23'].quantile(0.75),standing_train_data8['avg_rss23'].quantile(0.75),standing_train_data9['avg_rss23'].quantile(0.75),standing_train_data10['avg_rss23'].quantile(0.75),standing_train_data11['avg_rss23'].quantile(0.75),standing_train_data12['avg_rss23'].quantile(0.75),walking_test_data1['avg_rss23'].quantile(0.75),walking_test_data2['avg_rss23'].quantile(0.75),walking_test_data3['avg_rss23'].quantile(0.75),walking_train_data1['avg_rss23'].quantile(0.75),walking_train_data2['avg_rss23'].quantile(0.75),walking_train_data3['avg_rss23'].quantile(0.75),walking_train_data4['avg_rss23'].quantile(0.75),walking_train_data5['avg_rss23'].quantile(0.75),walking_train_data6['avg_rss23'].quantile(0.75),walking_train_data7['avg_rss23'].quantile(0.75),walking_train_data8['avg_rss23'].quantile(0.75),walking_train_data9['avg_rss23'].quantile(0.75),walking_train_data10['avg_rss23'].quantile(0.75),walking_train_data11['avg_rss23'].quantile(0.75),walking_train_data12['avg_rss23'].quantile(0.75)]

min6 = [bending1_test_data1['var_rss23'].min(),bending1_test_data2['var_rss23'].min(),bending1_train_data1['var_rss23'].min(),bending1_train_data2['var_rss23'].min(),bending1_train_data3['var_rss23'].min(),bending1_train_data4['var_rss23'].min(),bending1_train_data5['var_rss23'].min(),bending2_test_data1['var_rss23'].min(),bending2_test_data2['var_rss23'].min(),bending2_train_data1['var_rss23'].min(),bending2_train_data2['var_rss23'].min(),bending2_train_data3['var_rss23'].min(),bending2_train_data4['var_rss23'].min(),cycling_test_data1['var_rss23'].min(),cycling_test_data2['var_rss23'].min(),cycling_test_data3['var_rss23'].min(),cycling_train_data1['var_rss23'].min(),cycling_train_data2['var_rss23'].min(),cycling_train_data3['var_rss23'].min(),cycling_train_data4['var_rss23'].min(),cycling_train_data5['var_rss23'].min(),cycling_train_data6['var_rss23'].min(),cycling_train_data7['var_rss23'].min(),cycling_train_data8['var_rss23'].min(),cycling_train_data9['var_rss23'].min(),cycling_train_data10['var_rss23'].min(),cycling_train_data11['var_rss23'].min(),cycling_train_data12['var_rss23'].min(),lying_test_data1['var_rss23'].min(),lying_test_data2['var_rss23'].min(),lying_test_data3['var_rss23'].min(),lying_train_data1['var_rss23'].min(),lying_train_data2['var_rss23'].min(),lying_train_data3['var_rss23'].min(),lying_train_data4['var_rss23'].min(),lying_train_data5['var_rss23'].min(),lying_train_data6['var_rss23'].min(),lying_train_data7['var_rss23'].min(),lying_train_data8['var_rss23'].min(),lying_train_data9['var_rss23'].min(),lying_train_data10['var_rss23'].min(),lying_train_data11['var_rss23'].min(),lying_train_data12['var_rss23'].min(),sitting_test_data1['var_rss23'].min(),sitting_test_data2['var_rss23'].min(),sitting_test_data3['var_rss23'].min(),sitting_train_data1['var_rss23'].min(),sitting_train_data2['var_rss23'].min(),sitting_train_data3['var_rss23'].min(),sitting_train_data4['var_rss23'].min(),sitting_train_data5['var_rss23'].min(),sitting_train_data6['var_rss23'].min(),sitting_train_data7['var_rss23'].min(),sitting_train_data8['var_rss23'].min(),sitting_train_data9['var_rss23'].min(),sitting_train_data10['var_rss23'].min(),sitting_train_data11['var_rss23'].min(),sitting_train_data12['var_rss23'].min(),standing_test_data1['var_rss23'].min(),standing_test_data2['var_rss23'].min(),standing_test_data3['var_rss23'].min(),standing_train_data1['var_rss23'].min(),standing_train_data2['var_rss23'].min(),standing_train_data3['var_rss23'].min(),standing_train_data4['var_rss23'].min(),standing_train_data5['var_rss23'].min(),standing_train_data6['var_rss23'].min(),standing_train_data7['var_rss23'].min(),standing_train_data8['var_rss23'].min(),standing_train_data9['var_rss23'].min(),standing_train_data10['var_rss23'].min(),standing_train_data11['var_rss23'].min(),standing_train_data12['var_rss23'].min(),walking_test_data1['var_rss23'].min(),walking_test_data2['var_rss23'].min(),walking_test_data3['var_rss23'].min(),walking_train_data1['var_rss23'].min(),walking_train_data2['var_rss23'].min(),walking_train_data3['var_rss23'].min(),walking_train_data4['var_rss23'].min(),walking_train_data5['var_rss23'].min(),walking_train_data6['var_rss23'].min(),walking_train_data7['var_rss23'].min(),walking_train_data8['var_rss23'].min(),walking_train_data9['var_rss23'].min(),walking_train_data10['var_rss23'].min(),walking_train_data11['var_rss23'].min(),walking_train_data12['var_rss23'].min()]

max6 = [bending1_test_data1['var_rss23'].max(),bending1_test_data2['var_rss23'].max(),bending1_train_data1['var_rss23'].max(),bending1_train_data2['var_rss23'].max(),bending1_train_data3['var_rss23'].max(),bending1_train_data4['var_rss23'].max(),bending1_train_data5['var_rss23'].max(),bending2_test_data1['var_rss23'].max(),bending2_test_data2['var_rss23'].max(),bending2_train_data1['var_rss23'].max(),bending2_train_data2['var_rss23'].max(),bending2_train_data3['var_rss23'].max(),bending2_train_data4['var_rss23'].max(),cycling_test_data1['var_rss23'].max(),cycling_test_data2['var_rss23'].max(),cycling_test_data3['var_rss23'].max(),cycling_train_data1['var_rss23'].max(),cycling_train_data2['var_rss23'].max(),cycling_train_data3['var_rss23'].max(),cycling_train_data4['var_rss23'].max(),cycling_train_data5['var_rss23'].max(),cycling_train_data6['var_rss23'].max(),cycling_train_data7['var_rss23'].max(),cycling_train_data8['var_rss23'].max(),cycling_train_data9['var_rss23'].max(),cycling_train_data10['var_rss23'].max(),cycling_train_data11['var_rss23'].max(),cycling_train_data12['var_rss23'].max(),lying_test_data1['var_rss23'].max(),lying_test_data2['var_rss23'].max(),lying_test_data3['var_rss23'].max(),lying_train_data1['var_rss23'].max(),lying_train_data2['var_rss23'].max(),lying_train_data3['var_rss23'].max(),lying_train_data4['var_rss23'].max(),lying_train_data5['var_rss23'].max(),lying_train_data6['var_rss23'].max(),lying_train_data7['var_rss23'].max(),lying_train_data8['var_rss23'].max(),lying_train_data9['var_rss23'].max(),lying_train_data10['var_rss23'].max(),lying_train_data11['var_rss23'].max(),lying_train_data12['var_rss23'].max(),sitting_test_data1['var_rss23'].max(),sitting_test_data2['var_rss23'].max(),sitting_test_data3['var_rss23'].max(),sitting_train_data1['var_rss23'].max(),sitting_train_data2['var_rss23'].max(),sitting_train_data3['var_rss23'].max(),sitting_train_data4['var_rss23'].max(),sitting_train_data5['var_rss23'].max(),sitting_train_data6['var_rss23'].max(),sitting_train_data7['var_rss23'].max(),sitting_train_data8['var_rss23'].max(),sitting_train_data9['var_rss23'].max(),sitting_train_data10['var_rss23'].max(),sitting_train_data11['var_rss23'].max(),sitting_train_data12['var_rss23'].max(),standing_test_data1['var_rss23'].max(),standing_test_data2['var_rss23'].max(),standing_test_data3['var_rss23'].max(),standing_train_data1['var_rss23'].max(),standing_train_data2['var_rss23'].max(),standing_train_data3['var_rss23'].max(),standing_train_data4['var_rss23'].max(),standing_train_data5['var_rss23'].max(),standing_train_data6['var_rss23'].max(),standing_train_data7['var_rss23'].max(),standing_train_data8['var_rss23'].max(),standing_train_data9['var_rss23'].max(),standing_train_data10['var_rss23'].max(),standing_train_data11['var_rss23'].max(),standing_train_data12['var_rss23'].max(),walking_test_data1['var_rss23'].max(),walking_test_data2['var_rss23'].max(),walking_test_data3['var_rss23'].max(),walking_train_data1['var_rss23'].max(),walking_train_data2['var_rss23'].max(),walking_train_data3['var_rss23'].max(),walking_train_data4['var_rss23'].max(),walking_train_data5['var_rss23'].max(),walking_train_data6['var_rss23'].max(),walking_train_data7['var_rss23'].max(),walking_train_data8['var_rss23'].max(),walking_train_data9['var_rss23'].max(),walking_train_data10['var_rss23'].max(),walking_train_data11['var_rss23'].max(),walking_train_data12['var_rss23'].max()]

mean6 = [bending1_test_data1['var_rss23'].mean(),bending1_test_data2['var_rss23'].mean(),bending1_train_data1['var_rss23'].mean(),bending1_train_data2['var_rss23'].mean(),bending1_train_data3['var_rss23'].mean(),bending1_train_data4['var_rss23'].mean(),bending1_train_data5['var_rss23'].mean(),bending2_test_data1['var_rss23'].mean(),bending2_test_data2['var_rss23'].mean(),bending2_train_data1['var_rss23'].mean(),bending2_train_data2['var_rss23'].mean(),bending2_train_data3['var_rss23'].mean(),bending2_train_data4['var_rss23'].mean(),cycling_test_data1['var_rss23'].mean(),cycling_test_data2['var_rss23'].mean(),cycling_test_data3['var_rss23'].mean(),cycling_train_data1['var_rss23'].mean(),cycling_train_data2['var_rss23'].mean(),cycling_train_data3['var_rss23'].mean(),cycling_train_data4['var_rss23'].mean(),cycling_train_data5['var_rss23'].mean(),cycling_train_data6['var_rss23'].mean(),cycling_train_data7['var_rss23'].mean(),cycling_train_data8['var_rss23'].mean(),cycling_train_data9['var_rss23'].mean(),cycling_train_data10['var_rss23'].mean(),cycling_train_data11['var_rss23'].mean(),cycling_train_data12['var_rss23'].mean(),lying_test_data1['var_rss23'].mean(),lying_test_data2['var_rss23'].mean(),lying_test_data3['var_rss23'].mean(),lying_train_data1['var_rss23'].mean(),lying_train_data2['var_rss23'].mean(),lying_train_data3['var_rss23'].mean(),lying_train_data4['var_rss23'].mean(),lying_train_data5['var_rss23'].mean(),lying_train_data6['var_rss23'].mean(),lying_train_data7['var_rss23'].mean(),lying_train_data8['var_rss23'].mean(),lying_train_data9['var_rss23'].mean(),lying_train_data10['var_rss23'].mean(),lying_train_data11['var_rss23'].mean(),lying_train_data12['var_rss23'].mean(),sitting_test_data1['var_rss23'].mean(),sitting_test_data2['var_rss23'].mean(),sitting_test_data3['var_rss23'].mean(),sitting_train_data1['var_rss23'].mean(),sitting_train_data2['var_rss23'].mean(),sitting_train_data3['var_rss23'].mean(),sitting_train_data4['var_rss23'].mean(),sitting_train_data5['var_rss23'].mean(),sitting_train_data6['var_rss23'].mean(),sitting_train_data7['var_rss23'].mean(),sitting_train_data8['var_rss23'].mean(),sitting_train_data9['var_rss23'].mean(),sitting_train_data10['var_rss23'].mean(),sitting_train_data11['var_rss23'].mean(),sitting_train_data12['var_rss23'].mean(),standing_test_data1['var_rss23'].mean(),standing_test_data2['var_rss23'].mean(),standing_test_data3['var_rss23'].mean(),standing_train_data1['var_rss23'].mean(),standing_train_data2['var_rss23'].mean(),standing_train_data3['var_rss23'].mean(),standing_train_data4['var_rss23'].mean(),standing_train_data5['var_rss23'].mean(),standing_train_data6['var_rss23'].mean(),standing_train_data7['var_rss23'].mean(),standing_train_data8['var_rss23'].mean(),standing_train_data9['var_rss23'].mean(),standing_train_data10['var_rss23'].mean(),standing_train_data11['var_rss23'].mean(),standing_train_data12['var_rss23'].mean(),walking_test_data1['var_rss23'].mean(),walking_test_data2['var_rss23'].mean(),walking_test_data3['var_rss23'].mean(),walking_train_data1['var_rss23'].mean(),walking_train_data2['var_rss23'].mean(),walking_train_data3['var_rss23'].mean(),walking_train_data4['var_rss23'].mean(),walking_train_data5['var_rss23'].mean(),walking_train_data6['var_rss23'].mean(),walking_train_data7['var_rss23'].mean(),walking_train_data8['var_rss23'].mean(),walking_train_data9['var_rss23'].mean(),walking_train_data10['var_rss23'].mean(),walking_train_data11['var_rss23'].mean(),walking_train_data12['var_rss23'].mean()]

median6 = [bending1_test_data1['var_rss23'].median(),bending1_test_data2['var_rss23'].median(),bending1_train_data1['var_rss23'].median(),bending1_train_data2['var_rss23'].median(),bending1_train_data3['var_rss23'].median(),bending1_train_data4['var_rss23'].median(),bending1_train_data5['var_rss23'].median(),bending2_test_data1['var_rss23'].median(),bending2_test_data2['var_rss23'].median(),bending2_train_data1['var_rss23'].median(),bending2_train_data2['var_rss23'].median(),bending2_train_data3['var_rss23'].median(),bending2_train_data4['var_rss23'].median(),cycling_test_data1['var_rss23'].median(),cycling_test_data2['var_rss23'].median(),cycling_test_data3['var_rss23'].median(),cycling_train_data1['var_rss23'].median(),cycling_train_data2['var_rss23'].median(),cycling_train_data3['var_rss23'].median(),cycling_train_data4['var_rss23'].median(),cycling_train_data5['var_rss23'].median(),cycling_train_data6['var_rss23'].median(),cycling_train_data7['var_rss23'].median(),cycling_train_data8['var_rss23'].median(),cycling_train_data9['var_rss23'].median(),cycling_train_data10['var_rss23'].median(),cycling_train_data11['var_rss23'].median(),cycling_train_data12['var_rss23'].median(),lying_test_data1['var_rss23'].median(),lying_test_data2['var_rss23'].median(),lying_test_data3['var_rss23'].median(),lying_train_data1['var_rss23'].median(),lying_train_data2['var_rss23'].median(),lying_train_data3['var_rss23'].median(),lying_train_data4['var_rss23'].median(),lying_train_data5['var_rss23'].median(),lying_train_data6['var_rss23'].median(),lying_train_data7['var_rss23'].median(),lying_train_data8['var_rss23'].median(),lying_train_data9['var_rss23'].median(),lying_train_data10['var_rss23'].median(),lying_train_data11['var_rss23'].median(),lying_train_data12['var_rss23'].median(),sitting_test_data1['var_rss23'].median(),sitting_test_data2['var_rss23'].median(),sitting_test_data3['var_rss23'].median(),sitting_train_data1['var_rss23'].median(),sitting_train_data2['var_rss23'].median(),sitting_train_data3['var_rss23'].median(),sitting_train_data4['var_rss23'].median(),sitting_train_data5['var_rss23'].median(),sitting_train_data6['var_rss23'].median(),sitting_train_data7['var_rss23'].median(),sitting_train_data8['var_rss23'].median(),sitting_train_data9['var_rss23'].median(),sitting_train_data10['var_rss23'].median(),sitting_train_data11['var_rss23'].median(),sitting_train_data12['var_rss23'].median(),standing_test_data1['var_rss23'].median(),standing_test_data2['var_rss23'].median(),standing_test_data3['var_rss23'].median(),standing_train_data1['var_rss23'].median(),standing_train_data2['var_rss23'].median(),standing_train_data3['var_rss23'].median(),standing_train_data4['var_rss23'].median(),standing_train_data5['var_rss23'].median(),standing_train_data6['var_rss23'].median(),standing_train_data7['var_rss23'].median(),standing_train_data8['var_rss23'].median(),standing_train_data9['var_rss23'].median(),standing_train_data10['var_rss23'].median(),standing_train_data11['var_rss23'].median(),standing_train_data12['var_rss23'].median(),walking_test_data1['var_rss23'].median(),walking_test_data2['var_rss23'].median(),walking_test_data3['var_rss23'].median(),walking_train_data1['var_rss23'].median(),walking_train_data2['var_rss23'].median(),walking_train_data3['var_rss23'].median(),walking_train_data4['var_rss23'].median(),walking_train_data5['var_rss23'].median(),walking_train_data6['var_rss23'].median(),walking_train_data7['var_rss23'].median(),walking_train_data8['var_rss23'].median(),walking_train_data9['var_rss23'].median(),walking_train_data10['var_rss23'].median(),walking_train_data11['var_rss23'].median(),walking_train_data12['var_rss23'].median()]

sd6 = [bending1_test_data1['var_rss23'].std(),bending1_test_data2['var_rss23'].std(),bending1_train_data1['var_rss23'].std(),bending1_train_data2['var_rss23'].std(),bending1_train_data3['var_rss23'].std(),bending1_train_data4['var_rss23'].std(),bending1_train_data5['var_rss23'].std(),bending2_test_data1['var_rss23'].std(),bending2_test_data2['var_rss23'].std(),bending2_train_data1['var_rss23'].std(),bending2_train_data2['var_rss23'].std(),bending2_train_data3['var_rss23'].std(),bending2_train_data4['var_rss23'].std(),cycling_test_data1['var_rss23'].std(),cycling_test_data2['var_rss23'].std(),cycling_test_data3['var_rss23'].std(),cycling_train_data1['var_rss23'].std(),cycling_train_data2['var_rss23'].std(),cycling_train_data3['var_rss23'].std(),cycling_train_data4['var_rss23'].std(),cycling_train_data5['var_rss23'].std(),cycling_train_data6['var_rss23'].std(),cycling_train_data7['var_rss23'].std(),cycling_train_data8['var_rss23'].std(),cycling_train_data9['var_rss23'].std(),cycling_train_data10['var_rss23'].std(),cycling_train_data11['var_rss23'].std(),cycling_train_data12['var_rss23'].std(),lying_test_data1['var_rss23'].std(),lying_test_data2['var_rss23'].std(),lying_test_data3['var_rss23'].std(),lying_train_data1['var_rss23'].std(),lying_train_data2['var_rss23'].std(),lying_train_data3['var_rss23'].std(),lying_train_data4['var_rss23'].std(),lying_train_data5['var_rss23'].std(),lying_train_data6['var_rss23'].std(),lying_train_data7['var_rss23'].std(),lying_train_data8['var_rss23'].std(),lying_train_data9['var_rss23'].std(),lying_train_data10['var_rss23'].std(),lying_train_data11['var_rss23'].std(),lying_train_data12['var_rss23'].std(),sitting_test_data1['var_rss23'].std(),sitting_test_data2['var_rss23'].std(),sitting_test_data3['var_rss23'].std(),sitting_train_data1['var_rss23'].std(),sitting_train_data2['var_rss23'].std(),sitting_train_data3['var_rss23'].std(),sitting_train_data4['var_rss23'].std(),sitting_train_data5['var_rss23'].std(),sitting_train_data6['var_rss23'].std(),sitting_train_data7['var_rss23'].std(),sitting_train_data8['var_rss23'].std(),sitting_train_data9['var_rss23'].std(),sitting_train_data10['var_rss23'].std(),sitting_train_data11['var_rss23'].std(),sitting_train_data12['var_rss23'].std(),standing_test_data1['var_rss23'].std(),standing_test_data2['var_rss23'].std(),standing_test_data3['var_rss23'].std(),standing_train_data1['var_rss23'].std(),standing_train_data2['var_rss23'].std(),standing_train_data3['var_rss23'].std(),standing_train_data4['var_rss23'].std(),standing_train_data5['var_rss23'].std(),standing_train_data6['var_rss23'].std(),standing_train_data7['var_rss23'].std(),standing_train_data8['var_rss23'].std(),standing_train_data9['var_rss23'].std(),standing_train_data10['var_rss23'].std(),standing_train_data11['var_rss23'].std(),standing_train_data12['var_rss23'].std(),walking_test_data1['var_rss23'].std(),walking_test_data2['var_rss23'].std(),walking_test_data3['var_rss23'].std(),walking_train_data1['var_rss23'].std(),walking_train_data2['var_rss23'].std(),walking_train_data3['var_rss23'].std(),walking_train_data4['var_rss23'].std(),walking_train_data5['var_rss23'].std(),walking_train_data6['var_rss23'].std(),walking_train_data7['var_rss23'].std(),walking_train_data8['var_rss23'].std(),walking_train_data9['var_rss23'].std(),walking_train_data10['var_rss23'].std(),walking_train_data11['var_rss23'].std(),walking_train_data12['var_rss23'].std()]

quart1_6 = [bending1_test_data1['var_rss23'].quantile(0.25),bending1_test_data2['var_rss23'].quantile(0.25),bending1_train_data1['var_rss23'].quantile(0.25),bending1_train_data2['var_rss23'].quantile(0.25),bending1_train_data3['var_rss23'].quantile(0.25),bending1_train_data4['var_rss23'].quantile(0.25),bending1_train_data5['var_rss23'].quantile(0.25),bending2_test_data1['var_rss23'].quantile(0.25),bending2_test_data2['var_rss23'].quantile(0.25),bending2_train_data1['var_rss23'].quantile(0.25),bending2_train_data2['var_rss23'].quantile(0.25),bending2_train_data3['var_rss23'].quantile(0.25),bending2_train_data4['var_rss23'].quantile(0.25),cycling_test_data1['var_rss23'].quantile(0.25),cycling_test_data2['var_rss23'].quantile(0.25),cycling_test_data3['var_rss23'].quantile(0.25),cycling_train_data1['var_rss23'].quantile(0.25),cycling_train_data2['var_rss23'].quantile(0.25),cycling_train_data3['var_rss23'].quantile(0.25),cycling_train_data4['var_rss23'].quantile(0.25),cycling_train_data5['var_rss23'].quantile(0.25),cycling_train_data6['var_rss23'].quantile(0.25),cycling_train_data7['var_rss23'].quantile(0.25),cycling_train_data8['var_rss23'].quantile(0.25),cycling_train_data9['var_rss23'].quantile(0.25),cycling_train_data10['var_rss23'].quantile(0.25),cycling_train_data11['var_rss23'].quantile(0.25),cycling_train_data12['var_rss23'].quantile(0.25),lying_test_data1['var_rss23'].quantile(0.25),lying_test_data2['var_rss23'].quantile(0.25),lying_test_data3['var_rss23'].quantile(0.25),lying_train_data1['var_rss23'].quantile(0.25),lying_train_data2['var_rss23'].quantile(0.25),lying_train_data3['var_rss23'].quantile(0.25),lying_train_data4['var_rss23'].quantile(0.25),lying_train_data5['var_rss23'].quantile(0.25),lying_train_data6['var_rss23'].quantile(0.25),lying_train_data7['var_rss23'].quantile(0.25),lying_train_data8['var_rss23'].quantile(0.25),lying_train_data9['var_rss23'].quantile(0.25),lying_train_data10['var_rss23'].quantile(0.25),lying_train_data11['var_rss23'].quantile(0.25),lying_train_data12['var_rss23'].quantile(0.25),sitting_test_data1['var_rss23'].quantile(0.25),sitting_test_data2['var_rss23'].quantile(0.25),sitting_test_data3['var_rss23'].quantile(0.25),sitting_train_data1['var_rss23'].quantile(0.25),sitting_train_data2['var_rss23'].quantile(0.25),sitting_train_data3['var_rss23'].quantile(0.25),sitting_train_data4['var_rss23'].quantile(0.25),sitting_train_data5['var_rss23'].quantile(0.25),sitting_train_data6['var_rss23'].quantile(0.25),sitting_train_data7['var_rss23'].quantile(0.25),sitting_train_data8['var_rss23'].quantile(0.25),sitting_train_data9['var_rss23'].quantile(0.25),sitting_train_data10['var_rss23'].quantile(0.25),sitting_train_data11['var_rss23'].quantile(0.25),sitting_train_data12['var_rss23'].quantile(0.25),standing_test_data1['var_rss23'].quantile(0.25),standing_test_data2['var_rss23'].quantile(0.25),standing_test_data3['var_rss23'].quantile(0.25),standing_train_data1['var_rss23'].quantile(0.25),standing_train_data2['var_rss23'].quantile(0.25),standing_train_data3['var_rss23'].quantile(0.25),standing_train_data4['var_rss23'].quantile(0.25),standing_train_data5['var_rss23'].quantile(0.25),standing_train_data6['var_rss23'].quantile(0.25),standing_train_data7['var_rss23'].quantile(0.25),standing_train_data8['var_rss23'].quantile(0.25),standing_train_data9['var_rss23'].quantile(0.25),standing_train_data10['var_rss23'].quantile(0.25),standing_train_data11['var_rss23'].quantile(0.25),standing_train_data12['var_rss23'].quantile(0.25),walking_test_data1['var_rss23'].quantile(0.25),walking_test_data2['var_rss23'].quantile(0.25),walking_test_data3['var_rss23'].quantile(0.25),walking_train_data1['var_rss23'].quantile(0.25),walking_train_data2['var_rss23'].quantile(0.25),walking_train_data3['var_rss23'].quantile(0.25),walking_train_data4['var_rss23'].quantile(0.25),walking_train_data5['var_rss23'].quantile(0.25),walking_train_data6['var_rss23'].quantile(0.25),walking_train_data7['var_rss23'].quantile(0.25),walking_train_data8['var_rss23'].quantile(0.25),walking_train_data9['var_rss23'].quantile(0.25),walking_train_data10['var_rss23'].quantile(0.25),walking_train_data11['var_rss23'].quantile(0.25),walking_train_data12['var_rss23'].quantile(0.25)]

quart3_6 = [bending1_test_data1['var_rss23'].quantile(0.75),bending1_test_data2['var_rss23'].quantile(0.75),bending1_train_data1['var_rss23'].quantile(0.75),bending1_train_data2['var_rss23'].quantile(0.75),bending1_train_data3['var_rss23'].quantile(0.75),bending1_train_data4['var_rss23'].quantile(0.75),bending1_train_data5['var_rss23'].quantile(0.75),bending2_test_data1['var_rss23'].quantile(0.75),bending2_test_data2['var_rss23'].quantile(0.75),bending2_train_data1['var_rss23'].quantile(0.75),bending2_train_data2['var_rss23'].quantile(0.75),bending2_train_data3['var_rss23'].quantile(0.75),bending2_train_data4['var_rss23'].quantile(0.75),cycling_test_data1['var_rss23'].quantile(0.75),cycling_test_data2['var_rss23'].quantile(0.75),cycling_test_data3['var_rss23'].quantile(0.75),cycling_train_data1['var_rss23'].quantile(0.75),cycling_train_data2['var_rss23'].quantile(0.75),cycling_train_data3['var_rss23'].quantile(0.75),cycling_train_data4['var_rss23'].quantile(0.75),cycling_train_data5['var_rss23'].quantile(0.75),cycling_train_data6['var_rss23'].quantile(0.75),cycling_train_data7['var_rss23'].quantile(0.75),cycling_train_data8['var_rss23'].quantile(0.75),cycling_train_data9['var_rss23'].quantile(0.75),cycling_train_data10['var_rss23'].quantile(0.75),cycling_train_data11['var_rss23'].quantile(0.75),cycling_train_data12['var_rss23'].quantile(0.75),lying_test_data1['var_rss23'].quantile(0.75),lying_test_data2['var_rss23'].quantile(0.75),lying_test_data3['var_rss23'].quantile(0.75),lying_train_data1['var_rss23'].quantile(0.75),lying_train_data2['var_rss23'].quantile(0.75),lying_train_data3['var_rss23'].quantile(0.75),lying_train_data4['var_rss23'].quantile(0.75),lying_train_data5['var_rss23'].quantile(0.75),lying_train_data6['var_rss23'].quantile(0.75),lying_train_data7['var_rss23'].quantile(0.75),lying_train_data8['var_rss23'].quantile(0.75),lying_train_data9['var_rss23'].quantile(0.75),lying_train_data10['var_rss23'].quantile(0.75),lying_train_data11['var_rss23'].quantile(0.75),lying_train_data12['var_rss23'].quantile(0.75),sitting_test_data1['var_rss23'].quantile(0.75),sitting_test_data2['var_rss23'].quantile(0.75),sitting_test_data3['var_rss23'].quantile(0.75),sitting_train_data1['var_rss23'].quantile(0.75),sitting_train_data2['var_rss23'].quantile(0.75),sitting_train_data3['var_rss23'].quantile(0.75),sitting_train_data4['var_rss23'].quantile(0.75),sitting_train_data5['var_rss23'].quantile(0.75),sitting_train_data6['var_rss23'].quantile(0.75),sitting_train_data7['var_rss23'].quantile(0.75),sitting_train_data8['var_rss23'].quantile(0.75),sitting_train_data9['var_rss23'].quantile(0.75),sitting_train_data10['var_rss23'].quantile(0.75),sitting_train_data11['var_rss23'].quantile(0.75),sitting_train_data12['var_rss23'].quantile(0.75),standing_test_data1['var_rss23'].quantile(0.75),standing_test_data2['var_rss23'].quantile(0.75),standing_test_data3['var_rss23'].quantile(0.75),standing_train_data1['var_rss23'].quantile(0.75),standing_train_data2['var_rss23'].quantile(0.75),standing_train_data3['var_rss23'].quantile(0.75),standing_train_data4['var_rss23'].quantile(0.75),standing_train_data5['var_rss23'].quantile(0.75),standing_train_data6['var_rss23'].quantile(0.75),standing_train_data7['var_rss23'].quantile(0.75),standing_train_data8['var_rss23'].quantile(0.75),standing_train_data9['var_rss23'].quantile(0.75),standing_train_data10['var_rss23'].quantile(0.75),standing_train_data11['var_rss23'].quantile(0.75),standing_train_data12['var_rss23'].quantile(0.75),walking_test_data1['var_rss23'].quantile(0.75),walking_test_data2['var_rss23'].quantile(0.75),walking_test_data3['var_rss23'].quantile(0.75),walking_train_data1['var_rss23'].quantile(0.75),walking_train_data2['var_rss23'].quantile(0.75),walking_train_data3['var_rss23'].quantile(0.75),walking_train_data4['var_rss23'].quantile(0.75),walking_train_data5['var_rss23'].quantile(0.75),walking_train_data6['var_rss23'].quantile(0.75),walking_train_data7['var_rss23'].quantile(0.75),walking_train_data8['var_rss23'].quantile(0.75),walking_train_data9['var_rss23'].quantile(0.75),walking_train_data10['var_rss23'].quantile(0.75),walking_train_data11['var_rss23'].quantile(0.75),walking_train_data12['var_rss23'].quantile(0.75)]

# %%
table = pd.DataFrame()
table.insert(0,"Instance",instance)
table.insert(1,"Min1",min1)
table.insert(2,"Max1",max1)
table.insert(3,"Mean1",mean1)
table.insert(4,"Median1",median1)
table.insert(5,"SD1",sd1)
table.insert(6,"1st quart1",quart1_1)
table.insert(7,"3rd quart1",quart3_1)
table.insert(8,"Min2",min2)
table.insert(9,"Max2",max2)
table.insert(10,"Mean2",mean2)
table.insert(11,"Median2",median2)
table.insert(12,"SD2",sd2)
table.insert(13,"1st quart2",quart1_2)
table.insert(14,"3rd quart2",quart3_2)
table.insert(15,"Min3",min3)
table.insert(16,"Max3",max3)
table.insert(17,"Mean3",mean3)
table.insert(18,"Median3",median3)
table.insert(19,"SD3",sd3)
table.insert(20,"1st quart3",quart1_3)
table.insert(21,"3rd quart3",quart3_3)
table.insert(22,"Min4",min4)
table.insert(23,"Max4",max4)
table.insert(24,"Mean4",mean4)
table.insert(25,"Median4",median4)
table.insert(26,"SD4",sd4)
table.insert(27,"1st quart4",quart1_4)
table.insert(28,"3rd quart4",quart3_4)
table.insert(29,"Min5",min5)
table.insert(30,"Max5",max5)
table.insert(31,"Mean5",mean5)
table.insert(32,"Median5",median5)
table.insert(33,"SD5",sd5)
table.insert(34,"1st quart5",quart1_5)
table.insert(35,"3rd quart5",quart3_5)
table.insert(36,"Min6",min6)
table.insert(37,"Max6",max6)
table.insert(38,"Mean6",mean6)
table.insert(39,"Median6",median6)
table.insert(40,"SD6",sd6)
table.insert(41,"1st quart6",quart1_6)
table.insert(42,"3rd quart6",quart3_6)

# %% [markdown]
# __1) c) ii) Extracting the time-domain features minimum, maximum, mean, median, standard
# deviation, first quartile, and third quartile for all of the 6 time series
# in each instance.__

# %%
table
# Out:
#     Instance   Min1   Max1      Mean1  Median1       SD1  1st quart1  \
# 0        1.0  37.25  45.00  40.624792   40.500  1.476967     39.2500
# 1        2.0  38.00  45.67  42.812812   42.500  1.435550     42.0000
# 2        3.0  35.00  47.40  43.954500   44.330  1.558835     43.0000
# 3        4.0  33.00  47.75  42.179813   43.500  3.670666     39.1500
# 4        5.0  33.00  45.75  41.678063   41.750  2.243490     41.3300
# 5        6.0  37.00  48.00  43.454958   43.250  1.386098     42.5000
# 6        7.0  36.25  48.00  43.969125   44.500  1.618364     43.3100
# 7        8.0  12.75  51.00  24.562958   24.250  3.737514     23.1875
# 8        9.0   0.00  42.75  27.464604   28.000  3.583582     25.5000
# 9       10.0  21.00  50.00  32.586208   33.000  6.238143     26.1875
# 10      11.0  27.50  33.00  29.881938   30.000  1.153837     29.0000
# 11      12.0  19.00  45.50  30.938104   29.000  7.684146     26.7500
# 12      13.0  25.00  47.50  31.058250   29.710  4.829794     27.5000
# ...

# %% [markdown]
# __1) c) iii) Estimating Standard deviation for all 7 features and building a 90% bootsrap confidence interval for the standard deviation of each feature.__

# %%
SD_df = pd.DataFrame()
min_std = []
max_std = []
mean_std = []
median_std = []
SD_std = []
std_1st = []
std_3rd = []
for i in table:
    if "Min" in i:
        min_std = np.append(min_std,table[i].std())
    elif "Max" in i:
        max_std = np.append(max_std,table[i].std())
    elif "Mean" in i:
        mean_std = np.append(mean_std,table[i].std())
    elif "Median" in i:
        median_std = np.append(median_std,table[i].std())
    elif "SD" in i:
        SD_std = np.append(SD_std,table[i].std())
    elif "1st quart" in i:
        std_1st = np.append(std_1st,table[i].std())
    elif "3rd quart" in i:
        std_3rd = np.append(std_3rd,table[i].std())

SD_df.insert(0,"Min SD", min_std)
SD_df.insert(1,"Max SD",max_std)
SD_df.insert(2,"Mean SD",mean_std)
SD_df.insert(3,"Median SD",median_std)
SD_df.insert(4,"Std Devi SD", SD_std)
SD_df.insert(5,"1st quart SD",std_1st)
SD_df.insert(6,"3rd quart SD",std_3rd)
print("Standard Deviation of all the features:")
SD_df
# Out:
# Standard Deviation of all the features:
#      Min SD    Max SD   Mean SD  Median SD  Std Devi SD  1st quart SD  \
# 0  9.569975  4.394362  5.335686   5.440054     1.772187      6.153874
# 1  0.000000  5.062729  1.574203   1.412293     0.884135      0.946386
# 2  2.956462  4.875137  4.008235   4.036396     0.946654      4.220658
# 3  0.000000  2.183625  1.166135   1.145985     0.458241      0.843405
# 4  6.124001  5.741238  5.675543   5.813782     1.024893      6.096465
# 5  0.045838  2.518921  1.154848   1.086474     0.517601      0.758687
#
#    3rd quart SD
# 0      5.138925
# 1      2.125399
# 2      4.171628
# 3      1.552504
# 4      5.531720
# 5      1.523739

# %% [markdown]
# <br>__90% bootsrap confidence interval for the standard deviation of each feature__

# %%
def bootstrap(data, n=1000, func=np.mean):
    simulations = list()
    sample_size = len(data)
    xbar_init = np.mean(data)
    for c in range(n):
        itersample = np.random.choice(data, size=sample_size, replace=True)
        simulations.append(func(itersample))
    simulations.sort()
    def ci(p):
        u_pval = (1+p)/2.
        l_pval = (1-u_pval)
        l_indx = int(np.floor(n*l_pval))
        u_indx = int(np.floor(n*u_pval))
        return(simulations[l_indx],simulations[u_indx])
    return(ci)

# %%
for i in SD_df:
    boot = bootstrap(SD_df[i].values)
    cintervals = boot(.90)
    print("90% Confidence Interval of ",i,":",cintervals)
# Out:
# 90% Confidence Interval of  Min SD : (0.5156627535425311, 5.731708940559142)
# 90% Confidence Interval of  Max SD : (3.223826499015195, 5.033154134006968)
# 90% Confidence Interval of  Mean SD : (1.9215468922698242, 4.474280511825911)
# 90% Confidence Interval of  Median SD : (1.7608742344573407, 4.659393701655773)
# 90% Confidence Interval of  Std Devi SD : (0.6637650484357285, 1.257178810125851)
# 90% Confidence Interval of  1st quart SD : (1.6861244607096575, 4.927457002221202)
# 90% Confidence Interval of  3rd quart SD : (2.2265468288040777, 4.506109541795211)

# %% [markdown]
# <br>__1) c) iv) 3 most important time-domain features according to me is Min, Max and Mean because these are the 3 most basic features and it can be used in almost all the scenarios to obtain accurate results. These features can be used to fit our model.__<br><br>

# %% [markdown]
# __1) (d)Binary Classification using logistic regression.__

# %% [markdown]
# __1) (d) i)__

# %%
bending_min = pd.DataFrame(columns=["avg_rss12","var_rss12","var_rss23"])
bending_max = pd.DataFrame(columns=["avg_rss12","var_rss12","var_rss23"])
bending_mean = pd.DataFrame(columns=["avg_rss12","var_rss12","var_rss23"])
activities_min = pd.DataFrame(columns=["avg_rss12","var_rss12","var_rss23"])
activities_max = pd.DataFrame(columns=["avg_rss12","var_rss12","var_rss23"])
activities_mean = pd.DataFrame(columns=["avg_rss12","var_rss12","var_rss23"])

# %%
bending_min = bending_min.append({'avg_rss12' : bending1_train_data1['avg_rss12'].min(),'var_rss12' : bending1_train_data1['var_rss12'].min(),'var_rss23' : bending1_train_data1['var_rss23'].min()}, ignore_index = True)
bending_min = bending_min.append({'avg_rss12' : bending1_train_data2['avg_rss12'].min(),'var_rss12' : bending1_train_data2['var_rss12'].min(),'var_rss23' : bending1_train_data2['var_rss23'].min()}, ignore_index = True)
bending_min = bending_min.append({'avg_rss12' : bending1_train_data3['avg_rss12'].min(),'var_rss12' : bending1_train_data3['var_rss12'].min(),'var_rss23' : bending1_train_data3['var_rss23'].min()}, ignore_index = True)
bending_min = bending_min.append({'avg_rss12' : bending1_train_data4['avg_rss12'].min(),'var_rss12' : bending1_train_data4['var_rss12'].min(),'var_rss23' : bending1_train_data4['var_rss23'].min()}, ignore_index = True)
bending_min = bending_min.append({'avg_rss12' : bending1_train_data5['avg_rss12'].min(),'var_rss12' : bending1_train_data5['var_rss12'].min(),'var_rss23' : bending1_train_data5['var_rss23'].min()}, ignore_index = True)
bending_min = bending_min.append({'avg_rss12' : bending2_train_data1['avg_rss12'].min(),'var_rss12' : bending2_train_data1['var_rss12'].min(),'var_rss23' : bending2_train_data1['var_rss23'].min()}, ignore_index = True)
bending_min = bending_min.append({'avg_rss12' : bending2_train_data2['avg_rss12'].min(),'var_rss12' : bending2_train_data2['var_rss12'].min(),'var_rss23' : bending2_train_data2['var_rss23'].min()}, ignore_index = True)
bending_min = bending_min.append({'avg_rss12' : bending2_train_data3['avg_rss12'].min(),'var_rss12' : bending2_train_data3['var_rss12'].min(),'var_rss23' : bending2_train_data3['var_rss23'].min()}, ignore_index = True)
bending_min = bending_min.append({'avg_rss12' : bending2_train_data4['avg_rss12'].min(),'var_rss12' : bending2_train_data4['var_rss12'].min(),'var_rss23' : bending2_train_data4['var_rss23'].min()}, ignore_index = True)

bending_max = bending_max.append({'avg_rss12' : bending1_train_data1['avg_rss12'].max(),'var_rss12' : bending1_train_data1['var_rss12'].max(),'var_rss23' : bending1_train_data1['var_rss23'].max()}, ignore_index = True)
bending_max = bending_max.append({'avg_rss12' : bending1_train_data2['avg_rss12'].max(),'var_rss12' : bending1_train_data2['var_rss12'].max(),'var_rss23' : bending1_train_data2['var_rss23'].max()}, ignore_index = True)
bending_max = bending_max.append({'avg_rss12' : bending1_train_data3['avg_rss12'].max(),'var_rss12' : bending1_train_data3['var_rss12'].max(),'var_rss23' : bending1_train_data3['var_rss23'].max()}, ignore_index = True)
bending_max = bending_max.append({'avg_rss12' : bending1_train_data4['avg_rss12'].max(),'var_rss12' : bending1_train_data4['var_rss12'].max(),'var_rss23' : bending1_train_data4['var_rss23'].max()}, ignore_index = True)
bending_max = bending_max.append({'avg_rss12' : bending1_train_data5['avg_rss12'].max(),'var_rss12' : bending1_train_data5['var_rss12'].max(),'var_rss23' : bending1_train_data5['var_rss23'].max()}, ignore_index = True)
bending_max = bending_max.append({'avg_rss12' : bending2_train_data1['avg_rss12'].max(),'var_rss12' : bending2_train_data1['var_rss12'].max(),'var_rss23' : bending2_train_data1['var_rss23'].max()}, ignore_index = True)
bending_max = bending_max.append({'avg_rss12' : bending2_train_data2['avg_rss12'].max(),'var_rss12' : bending2_train_data2['var_rss12'].max(),'var_rss23' : bending2_train_data2['var_rss23'].max()}, ignore_index = True)
bending_max = bending_max.append({'avg_rss12' : bending2_train_data3['avg_rss12'].max(),'var_rss12' : bending2_train_data3['var_rss12'].max(),'var_rss23' : bending2_train_data3['var_rss23'].max()}, ignore_index = True)
bending_max = bending_max.append({'avg_rss12' : bending2_train_data4['avg_rss12'].max(),'var_rss12' : bending2_train_data4['var_rss12'].max(),'var_rss23' : bending2_train_data4['var_rss23'].max()}, ignore_index = True)

bending_mean = bending_mean.append({'avg_rss12' : bending1_train_data1['avg_rss12'].mean(),'var_rss12' : bending1_train_data1['var_rss12'].mean(),'var_rss23' : bending1_train_data1['var_rss23'].mean()}, ignore_index = True)
bending_mean = bending_mean.append({'avg_rss12' : bending1_train_data2['avg_rss12'].mean(),'var_rss12' : bending1_train_data2['var_rss12'].mean(),'var_rss23' : bending1_train_data2['var_rss23'].mean()}, ignore_index = True)
bending_mean = bending_mean.append({'avg_rss12' : bending1_train_data3['avg_rss12'].mean(),'var_rss12' : bending1_train_data3['var_rss12'].mean(),'var_rss23' : bending1_train_data3['var_rss23'].mean()}, ignore_index = True)
bending_mean = bending_mean.append({'avg_rss12' : bending1_train_data4['avg_rss12'].mean(),'var_rss12' : bending1_train_data4['var_rss12'].mean(),'var_rss23' : bending1_train_data4['var_rss23'].mean()}, ignore_index = True)
bending_mean = bending_mean.append({'avg_rss12' : bending1_train_data5['avg_rss12'].mean(),'var_rss12' : bending1_train_data5['var_rss12'].mean(),'var_rss23' : bending1_train_data5['var_rss23'].mean()}, ignore_index = True)
bending_mean = bending_mean.append({'avg_rss12' : bending2_train_data1['avg_rss12'].mean(),'var_rss12' : bending2_train_data1['var_rss12'].mean(),'var_rss23' : bending2_train_data1['var_rss23'].mean()}, ignore_index = True)
bending_mean = bending_mean.append({'avg_rss12' : bending2_train_data2['avg_rss12'].mean(),'var_rss12' : bending2_train_data2['var_rss12'].mean(),'var_rss23' : bending2_train_data2['var_rss23'].mean()}, ignore_index = True)
bending_mean = bending_mean.append({'avg_rss12' : bending2_train_data3['avg_rss12'].mean(),'var_rss12' : bending2_train_data3['var_rss12'].mean(),'var_rss23' : bending2_train_data3['var_rss23'].mean()}, ignore_index = True)
bending_mean = bending_mean.append({'avg_rss12' : bending2_train_data4['avg_rss12'].mean(),'var_rss12' : bending2_train_data4['var_rss12'].mean(),'var_rss23' : bending2_train_data4['var_rss23'].mean()}, ignore_index = True)

# %%
activities_min = activities_min.append({'avg_rss12' : cycling_train_data1['avg_rss12'].min(),'var_rss12' : cycling_train_data1['var_rss12'].min(),'var_rss23' : cycling_train_data1['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : cycling_train_data2['avg_rss12'].min(),'var_rss12' : cycling_train_data2['var_rss12'].min(),'var_rss23' : cycling_train_data2['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : cycling_train_data3['avg_rss12'].min(),'var_rss12' : cycling_train_data3['var_rss12'].min(),'var_rss23' : cycling_train_data3['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : cycling_train_data4['avg_rss12'].min(),'var_rss12' : cycling_train_data4['var_rss12'].min(),'var_rss23' : cycling_train_data4['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : cycling_train_data5['avg_rss12'].min(),'var_rss12' : cycling_train_data5['var_rss12'].min(),'var_rss23' : cycling_train_data5['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : cycling_train_data6['avg_rss12'].min(),'var_rss12' : cycling_train_data6['var_rss12'].min(),'var_rss23' : cycling_train_data6['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : cycling_train_data7['avg_rss12'].min(),'var_rss12' : cycling_train_data7['var_rss12'].min(),'var_rss23' : cycling_train_data7['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : cycling_train_data8['avg_rss12'].min(),'var_rss12' : cycling_train_data8['var_rss12'].min(),'var_rss23' : cycling_train_data8['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : cycling_train_data9['avg_rss12'].min(),'var_rss12' : cycling_train_data9['var_rss12'].min(),'var_rss23' : cycling_train_data9['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : cycling_train_data10['avg_rss12'].min(),'var_rss12' : cycling_train_data10['var_rss12'].min(),'var_rss23' : cycling_train_data10['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : cycling_train_data11['avg_rss12'].min(),'var_rss12' : cycling_train_data11['var_rss12'].min(),'var_rss23' : cycling_train_data11['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : cycling_train_data12['avg_rss12'].min(),'var_rss12' : cycling_train_data12['var_rss12'].min(),'var_rss23' : cycling_train_data12['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : lying_train_data1['avg_rss12'].min(),'var_rss12' : lying_train_data1['var_rss12'].min(),'var_rss23' : lying_train_data1['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : lying_train_data2['avg_rss12'].min(),'var_rss12' : lying_train_data2['var_rss12'].min(),'var_rss23' : lying_train_data2['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : lying_train_data3['avg_rss12'].min(),'var_rss12' : lying_train_data3['var_rss12'].min(),'var_rss23' : lying_train_data3['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : lying_train_data4['avg_rss12'].min(),'var_rss12' : lying_train_data4['var_rss12'].min(),'var_rss23' : lying_train_data4['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : lying_train_data5['avg_rss12'].min(),'var_rss12' : lying_train_data5['var_rss12'].min(),'var_rss23' : lying_train_data5['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : lying_train_data6['avg_rss12'].min(),'var_rss12' : lying_train_data6['var_rss12'].min(),'var_rss23' : lying_train_data6['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : lying_train_data7['avg_rss12'].min(),'var_rss12' : lying_train_data7['var_rss12'].min(),'var_rss23' : lying_train_data7['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : lying_train_data8['avg_rss12'].min(),'var_rss12' : lying_train_data8['var_rss12'].min(),'var_rss23' : lying_train_data8['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : lying_train_data9['avg_rss12'].min(),'var_rss12' : lying_train_data9['var_rss12'].min(),'var_rss23' : lying_train_data9['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : lying_train_data10['avg_rss12'].min(),'var_rss12' : lying_train_data10['var_rss12'].min(),'var_rss23' : lying_train_data10['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : lying_train_data11['avg_rss12'].min(),'var_rss12' : lying_train_data11['var_rss12'].min(),'var_rss23' : lying_train_data11['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : lying_train_data12['avg_rss12'].min(),'var_rss12' : lying_train_data12['var_rss12'].min(),'var_rss23' : lying_train_data12['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : sitting_train_data1['avg_rss12'].min(),'var_rss12' : sitting_train_data1['var_rss12'].min(),'var_rss23' : sitting_train_data1['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : sitting_train_data2['avg_rss12'].min(),'var_rss12' : sitting_train_data2['var_rss12'].min(),'var_rss23' : sitting_train_data2['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : sitting_train_data3['avg_rss12'].min(),'var_rss12' : sitting_train_data3['var_rss12'].min(),'var_rss23' : sitting_train_data3['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : sitting_train_data4['avg_rss12'].min(),'var_rss12' : sitting_train_data4['var_rss12'].min(),'var_rss23' : sitting_train_data4['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : sitting_train_data5['avg_rss12'].min(),'var_rss12' : sitting_train_data5['var_rss12'].min(),'var_rss23' : sitting_train_data5['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : sitting_train_data6['avg_rss12'].min(),'var_rss12' : sitting_train_data6['var_rss12'].min(),'var_rss23' : sitting_train_data6['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : sitting_train_data7['avg_rss12'].min(),'var_rss12' : sitting_train_data7['var_rss12'].min(),'var_rss23' : sitting_train_data7['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : sitting_train_data8['avg_rss12'].min(),'var_rss12' : sitting_train_data8['var_rss12'].min(),'var_rss23' : sitting_train_data8['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : sitting_train_data9['avg_rss12'].min(),'var_rss12' : sitting_train_data9['var_rss12'].min(),'var_rss23' : sitting_train_data9['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : sitting_train_data10['avg_rss12'].min(),'var_rss12' : sitting_train_data10['var_rss12'].min(),'var_rss23' : sitting_train_data10['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : sitting_train_data11['avg_rss12'].min(),'var_rss12' : sitting_train_data11['var_rss12'].min(),'var_rss23' : sitting_train_data11['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : sitting_train_data12['avg_rss12'].min(),'var_rss12' : sitting_train_data12['var_rss12'].min(),'var_rss23' : sitting_train_data12['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : standing_train_data1['avg_rss12'].min(),'var_rss12' : standing_train_data1['var_rss12'].min(),'var_rss23' : standing_train_data1['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : standing_train_data2['avg_rss12'].min(),'var_rss12' : standing_train_data2['var_rss12'].min(),'var_rss23' : standing_train_data2['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : standing_train_data3['avg_rss12'].min(),'var_rss12' : standing_train_data3['var_rss12'].min(),'var_rss23' : standing_train_data3['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : standing_train_data4['avg_rss12'].min(),'var_rss12' : standing_train_data4['var_rss12'].min(),'var_rss23' : standing_train_data4['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : standing_train_data5['avg_rss12'].min(),'var_rss12' : standing_train_data5['var_rss12'].min(),'var_rss23' : standing_train_data5['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : standing_train_data6['avg_rss12'].min(),'var_rss12' : standing_train_data6['var_rss12'].min(),'var_rss23' : standing_train_data6['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : standing_train_data7['avg_rss12'].min(),'var_rss12' : standing_train_data7['var_rss12'].min(),'var_rss23' : standing_train_data7['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : standing_train_data8['avg_rss12'].min(),'var_rss12' : standing_train_data8['var_rss12'].min(),'var_rss23' : standing_train_data8['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : standing_train_data9['avg_rss12'].min(),'var_rss12' : standing_train_data9['var_rss12'].min(),'var_rss23' : standing_train_data9['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : standing_train_data10['avg_rss12'].min(),'var_rss12' : standing_train_data10['var_rss12'].min(),'var_rss23' : standing_train_data10['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : standing_train_data11['avg_rss12'].min(),'var_rss12' : standing_train_data11['var_rss12'].min(),'var_rss23' : standing_train_data11['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : standing_train_data12['avg_rss12'].min(),'var_rss12' : standing_train_data12['var_rss12'].min(),'var_rss23' : standing_train_data12['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : walking_train_data1['avg_rss12'].min(),'var_rss12' : walking_train_data1['var_rss12'].min(),'var_rss23' : walking_train_data1['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : walking_train_data2['avg_rss12'].min(),'var_rss12' : walking_train_data2['var_rss12'].min(),'var_rss23' : walking_train_data2['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : walking_train_data3['avg_rss12'].min(),'var_rss12' : walking_train_data3['var_rss12'].min(),'var_rss23' : walking_train_data3['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : walking_train_data4['avg_rss12'].min(),'var_rss12' : walking_train_data4['var_rss12'].min(),'var_rss23' : walking_train_data4['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : walking_train_data5['avg_rss12'].min(),'var_rss12' : walking_train_data5['var_rss12'].min(),'var_rss23' : walking_train_data5['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : walking_train_data6['avg_rss12'].min(),'var_rss12' : walking_train_data6['var_rss12'].min(),'var_rss23' : walking_train_data6['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : walking_train_data7['avg_rss12'].min(),'var_rss12' : walking_train_data7['var_rss12'].min(),'var_rss23' : walking_train_data7['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : walking_train_data8['avg_rss12'].min(),'var_rss12' : walking_train_data8['var_rss12'].min(),'var_rss23' : walking_train_data8['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : walking_train_data9['avg_rss12'].min(),'var_rss12' : walking_train_data9['var_rss12'].min(),'var_rss23' : walking_train_data9['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : walking_train_data10['avg_rss12'].min(),'var_rss12' : walking_train_data10['var_rss12'].min(),'var_rss23' : walking_train_data10['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : walking_train_data11['avg_rss12'].min(),'var_rss12' : walking_train_data11['var_rss12'].min(),'var_rss23' : walking_train_data11['var_rss23'].min()}, ignore_index = True)
activities_min = activities_min.append({'avg_rss12' : walking_train_data12['avg_rss12'].min(),'var_rss12' : walking_train_data12['var_rss12'].min(),'var_rss23' : walking_train_data12['var_rss23'].min()}, ignore_index = True)

# %%
activities_max = activities_max.append({'avg_rss12' : cycling_train_data1['avg_rss12'].max(),'var_rss12' : cycling_train_data1['var_rss12'].max(),'var_rss23' : cycling_train_data1['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : cycling_train_data2['avg_rss12'].max(),'var_rss12' : cycling_train_data2['var_rss12'].max(),'var_rss23' : cycling_train_data2['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : cycling_train_data3['avg_rss12'].max(),'var_rss12' : cycling_train_data3['var_rss12'].max(),'var_rss23' : cycling_train_data3['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : cycling_train_data4['avg_rss12'].max(),'var_rss12' : cycling_train_data4['var_rss12'].max(),'var_rss23' : cycling_train_data4['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : cycling_train_data5['avg_rss12'].max(),'var_rss12' : cycling_train_data5['var_rss12'].max(),'var_rss23' : cycling_train_data5['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : cycling_train_data6['avg_rss12'].max(),'var_rss12' : cycling_train_data6['var_rss12'].max(),'var_rss23' : cycling_train_data6['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : cycling_train_data7['avg_rss12'].max(),'var_rss12' : cycling_train_data7['var_rss12'].max(),'var_rss23' : cycling_train_data7['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : cycling_train_data8['avg_rss12'].max(),'var_rss12' : cycling_train_data8['var_rss12'].max(),'var_rss23' : cycling_train_data8['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : cycling_train_data9['avg_rss12'].max(),'var_rss12' : cycling_train_data9['var_rss12'].max(),'var_rss23' : cycling_train_data9['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : cycling_train_data10['avg_rss12'].max(),'var_rss12' : cycling_train_data10['var_rss12'].max(),'var_rss23' : cycling_train_data10['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : cycling_train_data11['avg_rss12'].max(),'var_rss12' : cycling_train_data11['var_rss12'].max(),'var_rss23' : cycling_train_data11['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : cycling_train_data12['avg_rss12'].max(),'var_rss12' : cycling_train_data12['var_rss12'].max(),'var_rss23' : cycling_train_data12['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : lying_train_data1['avg_rss12'].max(),'var_rss12' : lying_train_data1['var_rss12'].max(),'var_rss23' : lying_train_data1['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : lying_train_data2['avg_rss12'].max(),'var_rss12' : lying_train_data2['var_rss12'].max(),'var_rss23' : lying_train_data2['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : lying_train_data3['avg_rss12'].max(),'var_rss12' : lying_train_data3['var_rss12'].max(),'var_rss23' : lying_train_data3['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : lying_train_data4['avg_rss12'].max(),'var_rss12' : lying_train_data4['var_rss12'].max(),'var_rss23' : lying_train_data4['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : lying_train_data5['avg_rss12'].max(),'var_rss12' : lying_train_data5['var_rss12'].max(),'var_rss23' : lying_train_data5['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : lying_train_data6['avg_rss12'].max(),'var_rss12' : lying_train_data6['var_rss12'].max(),'var_rss23' : lying_train_data6['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : lying_train_data7['avg_rss12'].max(),'var_rss12' : lying_train_data7['var_rss12'].max(),'var_rss23' : lying_train_data7['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : lying_train_data8['avg_rss12'].max(),'var_rss12' : lying_train_data8['var_rss12'].max(),'var_rss23' : lying_train_data8['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : lying_train_data9['avg_rss12'].max(),'var_rss12' : lying_train_data9['var_rss12'].max(),'var_rss23' : lying_train_data9['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : lying_train_data10['avg_rss12'].max(),'var_rss12' : lying_train_data10['var_rss12'].max(),'var_rss23' : lying_train_data10['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : lying_train_data11['avg_rss12'].max(),'var_rss12' : lying_train_data11['var_rss12'].max(),'var_rss23' : lying_train_data11['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : lying_train_data12['avg_rss12'].max(),'var_rss12' : lying_train_data12['var_rss12'].max(),'var_rss23' : lying_train_data12['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : sitting_train_data1['avg_rss12'].max(),'var_rss12' : sitting_train_data1['var_rss12'].max(),'var_rss23' : sitting_train_data1['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : sitting_train_data2['avg_rss12'].max(),'var_rss12' : sitting_train_data2['var_rss12'].max(),'var_rss23' : sitting_train_data2['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : sitting_train_data3['avg_rss12'].max(),'var_rss12' : sitting_train_data3['var_rss12'].max(),'var_rss23' : sitting_train_data3['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : sitting_train_data4['avg_rss12'].max(),'var_rss12' : sitting_train_data4['var_rss12'].max(),'var_rss23' : sitting_train_data4['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : sitting_train_data5['avg_rss12'].max(),'var_rss12' : sitting_train_data5['var_rss12'].max(),'var_rss23' : sitting_train_data5['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : sitting_train_data6['avg_rss12'].max(),'var_rss12' : sitting_train_data6['var_rss12'].max(),'var_rss23' : sitting_train_data6['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : sitting_train_data7['avg_rss12'].max(),'var_rss12' : sitting_train_data7['var_rss12'].max(),'var_rss23' : sitting_train_data7['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : sitting_train_data8['avg_rss12'].max(),'var_rss12' : sitting_train_data8['var_rss12'].max(),'var_rss23' : sitting_train_data8['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : sitting_train_data9['avg_rss12'].max(),'var_rss12' : sitting_train_data9['var_rss12'].max(),'var_rss23' : sitting_train_data9['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : sitting_train_data10['avg_rss12'].max(),'var_rss12' : sitting_train_data10['var_rss12'].max(),'var_rss23' : sitting_train_data10['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : sitting_train_data11['avg_rss12'].max(),'var_rss12' : sitting_train_data11['var_rss12'].max(),'var_rss23' : sitting_train_data11['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : sitting_train_data12['avg_rss12'].max(),'var_rss12' : sitting_train_data12['var_rss12'].max(),'var_rss23' : sitting_train_data12['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : standing_train_data1['avg_rss12'].max(),'var_rss12' : standing_train_data1['var_rss12'].max(),'var_rss23' : standing_train_data1['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : standing_train_data2['avg_rss12'].max(),'var_rss12' : standing_train_data2['var_rss12'].max(),'var_rss23' : standing_train_data2['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : standing_train_data3['avg_rss12'].max(),'var_rss12' : standing_train_data3['var_rss12'].max(),'var_rss23' : standing_train_data3['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : standing_train_data4['avg_rss12'].max(),'var_rss12' : standing_train_data4['var_rss12'].max(),'var_rss23' : standing_train_data4['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : standing_train_data5['avg_rss12'].max(),'var_rss12' : standing_train_data5['var_rss12'].max(),'var_rss23' : standing_train_data5['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : standing_train_data6['avg_rss12'].max(),'var_rss12' : standing_train_data6['var_rss12'].max(),'var_rss23' : standing_train_data6['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : standing_train_data7['avg_rss12'].max(),'var_rss12' : standing_train_data7['var_rss12'].max(),'var_rss23' : standing_train_data7['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : standing_train_data8['avg_rss12'].max(),'var_rss12' : standing_train_data8['var_rss12'].max(),'var_rss23' : standing_train_data8['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : standing_train_data9['avg_rss12'].max(),'var_rss12' : standing_train_data9['var_rss12'].max(),'var_rss23' : standing_train_data9['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : standing_train_data10['avg_rss12'].max(),'var_rss12' : standing_train_data10['var_rss12'].max(),'var_rss23' : standing_train_data10['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : standing_train_data11['avg_rss12'].max(),'var_rss12' : standing_train_data11['var_rss12'].max(),'var_rss23' : standing_train_data11['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : standing_train_data12['avg_rss12'].max(),'var_rss12' : standing_train_data12['var_rss12'].max(),'var_rss23' : standing_train_data12['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : walking_train_data1['avg_rss12'].max(),'var_rss12' : walking_train_data1['var_rss12'].max(),'var_rss23' : walking_train_data1['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : walking_train_data2['avg_rss12'].max(),'var_rss12' : walking_train_data2['var_rss12'].max(),'var_rss23' : walking_train_data2['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : walking_train_data3['avg_rss12'].max(),'var_rss12' : walking_train_data3['var_rss12'].max(),'var_rss23' : walking_train_data3['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : walking_train_data4['avg_rss12'].max(),'var_rss12' : walking_train_data4['var_rss12'].max(),'var_rss23' : walking_train_data4['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : walking_train_data5['avg_rss12'].max(),'var_rss12' : walking_train_data5['var_rss12'].max(),'var_rss23' : walking_train_data5['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : walking_train_data6['avg_rss12'].max(),'var_rss12' : walking_train_data6['var_rss12'].max(),'var_rss23' : walking_train_data6['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : walking_train_data7['avg_rss12'].max(),'var_rss12' : walking_train_data7['var_rss12'].max(),'var_rss23' : walking_train_data7['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : walking_train_data8['avg_rss12'].max(),'var_rss12' : walking_train_data8['var_rss12'].max(),'var_rss23' : walking_train_data8['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : walking_train_data9['avg_rss12'].max(),'var_rss12' : walking_train_data9['var_rss12'].max(),'var_rss23' : walking_train_data9['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : walking_train_data10['avg_rss12'].max(),'var_rss12' : walking_train_data10['var_rss12'].max(),'var_rss23' : walking_train_data10['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : walking_train_data11['avg_rss12'].max(),'var_rss12' : walking_train_data11['var_rss12'].max(),'var_rss23' : walking_train_data11['var_rss23'].max()}, ignore_index = True)
activities_max = activities_max.append({'avg_rss12' : walking_train_data12['avg_rss12'].max(),'var_rss12' : walking_train_data12['var_rss12'].max(),'var_rss23' : walking_train_data12['var_rss23'].max()}, ignore_index = True)

# %%
activities_mean = activities_mean.append({'avg_rss12' : cycling_train_data1['avg_rss12'].mean(),'var_rss12' : cycling_train_data1['var_rss12'].mean(),'var_rss23' : cycling_train_data1['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : cycling_train_data2['avg_rss12'].mean(),'var_rss12' : cycling_train_data2['var_rss12'].mean(),'var_rss23' : cycling_train_data2['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : cycling_train_data3['avg_rss12'].mean(),'var_rss12' : cycling_train_data3['var_rss12'].mean(),'var_rss23' : cycling_train_data3['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : cycling_train_data4['avg_rss12'].mean(),'var_rss12' : cycling_train_data4['var_rss12'].mean(),'var_rss23' : cycling_train_data4['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : cycling_train_data5['avg_rss12'].mean(),'var_rss12' : cycling_train_data5['var_rss12'].mean(),'var_rss23' : cycling_train_data5['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : cycling_train_data6['avg_rss12'].mean(),'var_rss12' : cycling_train_data6['var_rss12'].mean(),'var_rss23' : cycling_train_data6['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : cycling_train_data7['avg_rss12'].mean(),'var_rss12' : cycling_train_data7['var_rss12'].mean(),'var_rss23' : cycling_train_data7['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : cycling_train_data8['avg_rss12'].mean(),'var_rss12' : cycling_train_data8['var_rss12'].mean(),'var_rss23' : cycling_train_data8['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : cycling_train_data9['avg_rss12'].mean(),'var_rss12' : cycling_train_data9['var_rss12'].mean(),'var_rss23' : cycling_train_data9['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : cycling_train_data10['avg_rss12'].mean(),'var_rss12' : cycling_train_data10['var_rss12'].mean(),'var_rss23' : cycling_train_data10['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : cycling_train_data11['avg_rss12'].mean(),'var_rss12' : cycling_train_data11['var_rss12'].mean(),'var_rss23' : cycling_train_data11['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : cycling_train_data12['avg_rss12'].mean(),'var_rss12' : cycling_train_data12['var_rss12'].mean(),'var_rss23' : cycling_train_data12['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : lying_train_data1['avg_rss12'].mean(),'var_rss12' : lying_train_data1['var_rss12'].mean(),'var_rss23' : lying_train_data1['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : lying_train_data2['avg_rss12'].mean(),'var_rss12' : lying_train_data2['var_rss12'].mean(),'var_rss23' : lying_train_data2['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : lying_train_data3['avg_rss12'].mean(),'var_rss12' : lying_train_data3['var_rss12'].mean(),'var_rss23' : lying_train_data3['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : lying_train_data4['avg_rss12'].mean(),'var_rss12' : lying_train_data4['var_rss12'].mean(),'var_rss23' : lying_train_data4['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : lying_train_data5['avg_rss12'].mean(),'var_rss12' : lying_train_data5['var_rss12'].mean(),'var_rss23' : lying_train_data5['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : lying_train_data6['avg_rss12'].mean(),'var_rss12' : lying_train_data6['var_rss12'].mean(),'var_rss23' : lying_train_data6['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : lying_train_data7['avg_rss12'].mean(),'var_rss12' : lying_train_data7['var_rss12'].mean(),'var_rss23' : lying_train_data7['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : lying_train_data8['avg_rss12'].mean(),'var_rss12' : lying_train_data8['var_rss12'].mean(),'var_rss23' : lying_train_data8['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : lying_train_data9['avg_rss12'].mean(),'var_rss12' : lying_train_data9['var_rss12'].mean(),'var_rss23' : lying_train_data9['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : lying_train_data10['avg_rss12'].mean(),'var_rss12' : lying_train_data10['var_rss12'].mean(),'var_rss23' : lying_train_data10['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : lying_train_data11['avg_rss12'].mean(),'var_rss12' : lying_train_data11['var_rss12'].mean(),'var_rss23' : lying_train_data11['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : lying_train_data12['avg_rss12'].mean(),'var_rss12' : lying_train_data12['var_rss12'].mean(),'var_rss23' : lying_train_data12['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : sitting_train_data1['avg_rss12'].mean(),'var_rss12' : sitting_train_data1['var_rss12'].mean(),'var_rss23' : sitting_train_data1['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : sitting_train_data2['avg_rss12'].mean(),'var_rss12' : sitting_train_data2['var_rss12'].mean(),'var_rss23' : sitting_train_data2['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : sitting_train_data3['avg_rss12'].mean(),'var_rss12' : sitting_train_data3['var_rss12'].mean(),'var_rss23' : sitting_train_data3['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : sitting_train_data4['avg_rss12'].mean(),'var_rss12' : sitting_train_data4['var_rss12'].mean(),'var_rss23' : sitting_train_data4['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : sitting_train_data5['avg_rss12'].mean(),'var_rss12' : sitting_train_data5['var_rss12'].mean(),'var_rss23' : sitting_train_data5['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : sitting_train_data6['avg_rss12'].mean(),'var_rss12' : sitting_train_data6['var_rss12'].mean(),'var_rss23' : sitting_train_data6['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : sitting_train_data7['avg_rss12'].mean(),'var_rss12' : sitting_train_data7['var_rss12'].mean(),'var_rss23' : sitting_train_data7['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : sitting_train_data8['avg_rss12'].mean(),'var_rss12' : sitting_train_data8['var_rss12'].mean(),'var_rss23' : sitting_train_data8['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : sitting_train_data9['avg_rss12'].mean(),'var_rss12' : sitting_train_data9['var_rss12'].mean(),'var_rss23' : sitting_train_data9['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : sitting_train_data10['avg_rss12'].mean(),'var_rss12' : sitting_train_data10['var_rss12'].mean(),'var_rss23' : sitting_train_data10['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : sitting_train_data11['avg_rss12'].mean(),'var_rss12' : sitting_train_data11['var_rss12'].mean(),'var_rss23' : sitting_train_data11['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : sitting_train_data12['avg_rss12'].mean(),'var_rss12' : sitting_train_data12['var_rss12'].mean(),'var_rss23' : sitting_train_data12['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : standing_train_data1['avg_rss12'].mean(),'var_rss12' : standing_train_data1['var_rss12'].mean(),'var_rss23' : standing_train_data1['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : standing_train_data2['avg_rss12'].mean(),'var_rss12' : standing_train_data2['var_rss12'].mean(),'var_rss23' : standing_train_data2['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : standing_train_data3['avg_rss12'].mean(),'var_rss12' : standing_train_data3['var_rss12'].mean(),'var_rss23' : standing_train_data3['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : standing_train_data4['avg_rss12'].mean(),'var_rss12' : standing_train_data4['var_rss12'].mean(),'var_rss23' : standing_train_data4['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : standing_train_data5['avg_rss12'].mean(),'var_rss12' : standing_train_data5['var_rss12'].mean(),'var_rss23' : standing_train_data5['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : standing_train_data6['avg_rss12'].mean(),'var_rss12' : standing_train_data6['var_rss12'].mean(),'var_rss23' : standing_train_data6['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : standing_train_data7['avg_rss12'].mean(),'var_rss12' : standing_train_data7['var_rss12'].mean(),'var_rss23' : standing_train_data7['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : standing_train_data8['avg_rss12'].mean(),'var_rss12' : standing_train_data8['var_rss12'].mean(),'var_rss23' : standing_train_data8['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : standing_train_data9['avg_rss12'].mean(),'var_rss12' : standing_train_data9['var_rss12'].mean(),'var_rss23' : standing_train_data9['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : standing_train_data10['avg_rss12'].mean(),'var_rss12' : standing_train_data10['var_rss12'].mean(),'var_rss23' : standing_train_data10['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : standing_train_data11['avg_rss12'].mean(),'var_rss12' : standing_train_data11['var_rss12'].mean(),'var_rss23' : standing_train_data11['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : standing_train_data12['avg_rss12'].mean(),'var_rss12' : standing_train_data12['var_rss12'].mean(),'var_rss23' : standing_train_data12['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : walking_train_data1['avg_rss12'].mean(),'var_rss12' : walking_train_data1['var_rss12'].mean(),'var_rss23' : walking_train_data1['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : walking_train_data2['avg_rss12'].mean(),'var_rss12' : walking_train_data2['var_rss12'].mean(),'var_rss23' : walking_train_data2['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : walking_train_data3['avg_rss12'].mean(),'var_rss12' : walking_train_data3['var_rss12'].mean(),'var_rss23' : walking_train_data3['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : walking_train_data4['avg_rss12'].mean(),'var_rss12' : walking_train_data4['var_rss12'].mean(),'var_rss23' : walking_train_data4['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : walking_train_data5['avg_rss12'].mean(),'var_rss12' : walking_train_data5['var_rss12'].mean(),'var_rss23' : walking_train_data5['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : walking_train_data6['avg_rss12'].mean(),'var_rss12' : walking_train_data6['var_rss12'].mean(),'var_rss23' : walking_train_data6['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : walking_train_data7['avg_rss12'].mean(),'var_rss12' : walking_train_data7['var_rss12'].mean(),'var_rss23' : walking_train_data7['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : walking_train_data8['avg_rss12'].mean(),'var_rss12' : walking_train_data8['var_rss12'].mean(),'var_rss23' : walking_train_data8['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : walking_train_data9['avg_rss12'].mean(),'var_rss12' : walking_train_data9['var_rss12'].mean(),'var_rss23' : walking_train_data9['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : walking_train_data10['avg_rss12'].mean(),'var_rss12' : walking_train_data10['var_rss12'].mean(),'var_rss23' : walking_train_data10['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : walking_train_data11['avg_rss12'].mean(),'var_rss12' : walking_train_data11['var_rss12'].mean(),'var_rss23' : walking_train_data11['var_rss23'].mean()}, ignore_index = True)
activities_mean = activities_mean.append({'avg_rss12' : walking_train_data12['avg_rss12'].mean(),'var_rss12' : walking_train_data12['var_rss12'].mean(),'var_rss23' : walking_train_data12['var_rss23'].mean()}, ignore_index = True)

# %% [markdown]
# __1) d) i) Scatter plot of Minimum feature, Pink denotes Bending & yellow denotes Other activities.__

# %%
axis = bending_min.plot(style='mo', legend=False)
activities_min.plot(style='yo',ax=axis, legend=False)
print("Bending - Pink dots")
print("Other Activities - Yellow dots")
plt.show()
# Out:
# Bending - Pink dots
# Other Activities - Yellow dots

# %% [markdown]
# <br>__Scatter plot of Maximum feature, Pink denotes Bending & yellow denotes Other activities.__

# %%
axis = bending_max.plot(style='mo',legend=False)
activities_max.plot(style='yo',ax=axis,legend=False)
print("Bending - Pink dots")
print("Other Activities - Yellow dots")
plt.show()
# Out:
# Bending - Pink dots
# Other Activities - Yellow dots

# %% [markdown]
# <br>__Scatter plot of Mean feature, Pink denotes Bending & yellow denotes Other activities.__

# %%
axis = bending_mean.plot(style='mo',legend=False)
activities_mean.plot(style='yo',ax=axis,legend=False)
print("Bending - Pink dots")
print("Other Activities - Yellow dots")
plt.show()
# Out:
# Bending - Pink dots
# Other Activities - Yellow dots

# %% [markdown]
# <br><br>__1. (d) ii.__

# %%
data1 = bending1_train_data1.iloc[240:].reset_index()
data2 = bending1_train_data2.iloc[240:].reset_index()
data3 = bending1_train_data3.iloc[240:].reset_index()
data4 = bending1_train_data4.iloc[240:].reset_index()
data5 = bending1_train_data5.iloc[240:].reset_index()
data6 = bending2_train_data1.iloc[240:].reset_index()
data7 = bending2_train_data2.iloc[240:].reset_index()
data8 = bending2_train_data3.iloc[240:].reset_index()
data9 = bending2_train_data4.iloc[240:].reset_index()
data10 = cycling_train_data1.iloc[240:].reset_index()
data11 = cycling_train_data2.iloc[240:].reset_index()
data12 = cycling_train_data3.iloc[240:].reset_index()
data13 = cycling_train_data4.iloc[240:].reset_index()
data14 = cycling_train_data5.iloc[240:].reset_index()
data15 = cycling_train_data6.iloc[240:].reset_index()
data16 = cycling_train_data7.iloc[240:].reset_index()
data17 = cycling_train_data8.iloc[240:].reset_index()
data18 = cycling_train_data9.iloc[240:].reset_index()
data19 = cycling_train_data10.iloc[240:].reset_index()
data20 = cycling_train_data11.iloc[240:].reset_index()
data21 = cycling_train_data12.iloc[240:].reset_index()
data22 = lying_train_data1.iloc[240:].reset_index()
data23 = lying_train_data2.iloc[240:].reset_index()
data24 = lying_train_data3.iloc[240:].reset_index()
data25 = lying_train_data4.iloc[240:].reset_index()
data26 = lying_train_data5.iloc[240:].reset_index()
data27 = lying_train_data6.iloc[240:].reset_index()
data28 = lying_train_data7.iloc[240:].reset_index()
data29 = lying_train_data8.iloc[240:].reset_index()
data30 = lying_train_data9.iloc[240:].reset_index()
data31 = lying_train_data10.iloc[240:].reset_index()
data32 = lying_train_data11.iloc[240:].reset_index()
data33 = lying_train_data12.iloc[240:].reset_index()
data34 = sitting_train_data1.iloc[240:].reset_index()
data35 = sitting_train_data2.iloc[240:].reset_index()
data36 = sitting_train_data3.iloc[240:].reset_index()
data37 = sitting_train_data4.iloc[240:].reset_index()
data38 = sitting_train_data5.iloc[240:].reset_index()
data39 = sitting_train_data6.iloc[240:].reset_index()
data40 = sitting_train_data7.iloc[240:].reset_index()
data41 = sitting_train_data8.iloc[240:].reset_index()
data42 = sitting_train_data9.iloc[240:].reset_index()
data43 = sitting_train_data10.iloc[240:].reset_index()
data44 = sitting_train_data11.iloc[240:].reset_index()
data45 = sitting_train_data12.iloc[240:].reset_index()
data46 = standing_train_data1.iloc[240:].reset_index()
data47 = standing_train_data2.iloc[240:].reset_index()
data48 = standing_train_data3.iloc[240:].reset_index()
data49 = standing_train_data4.iloc[240:].reset_index()
data50 = standing_train_data5.iloc[240:].reset_index()
data51 = standing_train_data6.iloc[240:].reset_index()
data52 = standing_train_data7.iloc[240:].reset_index()
data53 = standing_train_data8.iloc[240:].reset_index()
data54 = standing_train_data9.iloc[240:].reset_index()
data55 = standing_train_data10.iloc[240:].reset_index()
data56 = standing_train_data11.iloc[240:].reset_index()
data57 = standing_train_data12.iloc[240:].reset_index()
data58 = walking_train_data1.iloc[240:].reset_index()
data59 = walking_train_data2.iloc[240:].reset_index()
data60 = walking_train_data3.iloc[240:].reset_index()
data61 = walking_train_data4.iloc[240:].reset_index()
data62 = walking_train_data5.iloc[240:].reset_index()
data63 = walking_train_data6.iloc[240:].reset_index()
data64 = walking_train_data7.iloc[240:].reset_index()
data65 = walking_train_data8.iloc[240:].reset_index()
data66 = walking_train_data9.iloc[240:].reset_index()
data67 = walking_train_data10.iloc[240:].reset_index()
data68 = walking_train_data11.iloc[240:].reset_index()
data69 = walking_train_data12.iloc[240:].reset_index()

bend1_train1 = pd.concat([bending1_train_data1.iloc[0:240,1:7],data1.iloc[:,2:8]],axis=1)
bend1_train2 = pd.concat([bending1_train_data2.iloc[0:240,1:7],data2.iloc[:,2:8]],axis=1)
bend1_train3 = pd.concat([bending1_train_data3.iloc[0:240,1:7],data3.iloc[:,2:8]],axis=1)
bend1_train4 = pd.concat([bending1_train_data4.iloc[0:240,1:7],data4.iloc[:,2:8]],axis=1)
bend1_train5 = pd.concat([bending1_train_data5.iloc[0:240,1:7],data5.iloc[:,2:8]],axis=1)
bend2_train1 = pd.concat([bending2_train_data1.iloc[0:240,1:7],data6.iloc[:,2:8]],axis=1)
bend2_train2 = pd.concat([bending2_train_data2.iloc[0:240,1:7],data7.iloc[:,2:8]],axis=1)
bend2_train3 = pd.concat([bending2_train_data3.iloc[0:240,1:7],data8.iloc[:,2:8]],axis=1)
bend2_train4 = pd.concat([bending2_train_data4.iloc[0:240,1:7],data9.iloc[:,2:8]],axis=1)
cycle_train1 = pd.concat([cycling_train_data1.iloc[0:240,1:7],data10.iloc[:,2:8]],axis=1)
cycle_train2 = pd.concat([cycling_train_data2.iloc[0:240,1:7],data11.iloc[:,2:8]],axis=1)
cycle_train3 = pd.concat([cycling_train_data3.iloc[0:240,1:7],data12.iloc[:,2:8]],axis=1)
cycle_train4 = pd.concat([cycling_train_data4.iloc[0:240,1:7],data13.iloc[:,2:8]],axis=1)
cycle_train5 = pd.concat([cycling_train_data5.iloc[0:240,1:7],data14.iloc[:,2:8]],axis=1)
cycle_train6 = pd.concat([cycling_train_data6.iloc[0:240,1:7],data15.iloc[:,2:8]],axis=1)
cycle_train7 = pd.concat([cycling_train_data7.iloc[0:240,1:7],data16.iloc[:,2:8]],axis=1)
cycle_train8 = pd.concat([cycling_train_data8.iloc[0:240,1:7],data17.iloc[:,2:8]],axis=1)
cycle_train9 = pd.concat([cycling_train_data9.iloc[0:240,1:7],data18.iloc[:,2:8]],axis=1)
cycle_train10 = pd.concat([cycling_train_data10.iloc[0:240,1:7],data19.iloc[:,2:8]],axis=1)
cycle_train11 = pd.concat([cycling_train_data11.iloc[0:240,1:7],data20.iloc[:,2:8]],axis=1)
cycle_train12 = pd.concat([cycling_train_data12.iloc[0:240,1:7],data21.iloc[:,2:8]],axis=1)
lye_train1 = pd.concat([lying_train_data1.iloc[0:240,1:7],data22.iloc[:,2:8]],axis=1)
lye_train2 = pd.concat([lying_train_data2.iloc[0:240,1:7],data23.iloc[:,2:8]],axis=1)
lye_train3 = pd.concat([lying_train_data3.iloc[0:240,1:7],data24.iloc[:,2:8]],axis=1)
lye_train4 = pd.concat([lying_train_data4.iloc[0:240,1:7],data25.iloc[:,2:8]],axis=1)
lye_train5 = pd.concat([lying_train_data5.iloc[0:240,1:7],data26.iloc[:,2:8]],axis=1)
lye_train6 = pd.concat([lying_train_data6.iloc[0:240,1:7],data27.iloc[:,2:8]],axis=1)
lye_train7 = pd.concat([lying_train_data7.iloc[0:240,1:7],data28.iloc[:,2:8]],axis=1)
lye_train8 = pd.concat([lying_train_data8.iloc[0:240,1:7],data29.iloc[:,2:8]],axis=1)
lye_train9 = pd.concat([lying_train_data9.iloc[0:240,1:7],data30.iloc[:,2:8]],axis=1)
lye_train10 = pd.concat([lying_train_data10.iloc[0:240,1:7],data31.iloc[:,2:8]],axis=1)
lye_train11 = pd.concat([lying_train_data11.iloc[0:240,1:7],data32.iloc[:,2:8]],axis=1)
lye_train12 = pd.concat([lying_train_data12.iloc[0:240,1:7],data33.iloc[:,2:8]],axis=1)
sit_train1 = pd.concat([sitting_train_data1.iloc[0:240,1:7],data34.iloc[:,2:8]],axis=1)
sit_train2 = pd.concat([sitting_train_data2.iloc[0:240,1:7],data35.iloc[:,2:8]],axis=1)
sit_train3 = pd.concat([sitting_train_data3.iloc[0:240,1:7],data36.iloc[:,2:8]],axis=1)
sit_train4 = pd.concat([sitting_train_data4.iloc[0:240,1:7],data37.iloc[:,2:8]],axis=1)
sit_train5 = pd.concat([sitting_train_data5.iloc[0:240,1:7],data38.iloc[:,2:8]],axis=1)
sit_train6 = pd.concat([sitting_train_data6.iloc[0:240,1:7],data39.iloc[:,2:8]],axis=1)
sit_train7 = pd.concat([sitting_train_data7.iloc[0:240,1:7],data40.iloc[:,2:8]],axis=1)
sit_train8 = pd.concat([sitting_train_data8.iloc[0:240,1:7],data41.iloc[:,2:8]],axis=1)
sit_train9 = pd.concat([sitting_train_data9.iloc[0:240,1:7],data42.iloc[:,2:8]],axis=1)
sit_train10 = pd.concat([sitting_train_data10.iloc[0:240,1:7],data43.iloc[:,2:8]],axis=1)
sit_train11 = pd.concat([sitting_train_data11.iloc[0:240,1:7],data44.iloc[:,2:8]],axis=1)
sit_train12 = pd.concat([sitting_train_data12.iloc[0:240,1:7],data45.iloc[:,2:8]],axis=1)
stand_train1 = pd.concat([standing_train_data1.iloc[0:240,1:7],data46.iloc[:,2:8]],axis=1)
stand_train2 = pd.concat([standing_train_data2.iloc[0:240,1:7],data47.iloc[:,2:8]],axis=1)
stand_train3 = pd.concat([standing_train_data3.iloc[0:240,1:7],data48.iloc[:,2:8]],axis=1)
stand_train4 = pd.concat([standing_train_data4.iloc[0:240,1:7],data49.iloc[:,2:8]],axis=1)
stand_train5 = pd.concat([standing_train_data5.iloc[0:240,1:7],data50.iloc[:,2:8]],axis=1)
stand_train6 = pd.concat([standing_train_data6.iloc[0:240,1:7],data51.iloc[:,2:8]],axis=1)
stand_train7 = pd.concat([standing_train_data7.iloc[0:240,1:7],data52.iloc[:,2:8]],axis=1)
stand_train8 = pd.concat([standing_train_data8.iloc[0:240,1:7],data53.iloc[:,2:8]],axis=1)
stand_train9 = pd.concat([standing_train_data9.iloc[0:240,1:7],data54.iloc[:,2:8]],axis=1)
stand_train10 = pd.concat([standing_train_data10.iloc[0:240,1:7],data55.iloc[:,2:8]],axis=1)
stand_train11 = pd.concat([standing_train_data11.iloc[0:240,1:7],data56.iloc[:,2:8]],axis=1)
stand_train12 = pd.concat([standing_train_data12.iloc[0:240,1:7],data57.iloc[:,2:8]],axis=1)
walk_train1 = pd.concat([walking_train_data1.iloc[0:240,1:7],data58.iloc[:,2:8]],axis=1)
walk_train2 = pd.concat([walking_train_data2.iloc[0:240,1:7],data59.iloc[:,2:8]],axis=1)
walk_train3 = pd.concat([walking_train_data3.iloc[0:240,1:7],data60.iloc[:,2:8]],axis=1)
walk_train4 = pd.concat([walking_train_data4.iloc[0:240,1:7],data61.iloc[:,2:8]],axis=1)
walk_train5 = pd.concat([walking_train_data5.iloc[0:240,1:7],data62.iloc[:,2:8]],axis=1)
walk_train6 = pd.concat([walking_train_data6.iloc[0:240,1:7],data63.iloc[:,2:8]],axis=1)
walk_train7 = pd.concat([walking_train_data7.iloc[0:240,1:7],data64.iloc[:,2:8]],axis=1)
walk_train8 = pd.concat([walking_train_data8.iloc[0:240,1:7],data65.iloc[:,2:8]],axis=1)
walk_train9 = pd.concat([walking_train_data9.iloc[0:240,1:7],data66.iloc[:,2:8]],axis=1)
walk_train10 = pd.concat([walking_train_data10.iloc[0:240,1:7],data67.iloc[:,2:8]],axis=1)
walk_train11 = pd.concat([walking_train_data11.iloc[0:240,1:7],data68.iloc[:,2:8]],axis=1)
walk_train12 = pd.concat([walking_train_data12.iloc[0:240,1:7],data69.iloc[:,2:8]],axis=1)

# %%
split_min1 = [bend1_train1.iloc[:,0].min(),bend1_train2.iloc[:,0].min(),bend1_train3.iloc[:,0].min(),bend1_train4.iloc[:,0].min(),bend1_train5.iloc[:,0].min(),bend2_train1.iloc[:,0].min(),bend2_train2.iloc[:,0].min(),bend2_train3.iloc[:,0].min(),bend2_train4.iloc[:,0].min(),cycle_train1.iloc[:,0].min(),cycle_train2.iloc[:,0].min(),cycle_train3.iloc[:,0].min(),cycle_train4.iloc[:,0].min(),cycle_train5.iloc[:,0].min(),cycle_train6.iloc[:,0].min(),cycle_train7.iloc[:,0].min(),cycle_train8.iloc[:,0].min(),cycle_train9.iloc[:,0].min(),cycle_train10.iloc[:,0].min(),cycle_train11.iloc[:,0].min(),cycle_train12.iloc[:,0].min(),lye_train1.iloc[:,0].min(),lye_train2.iloc[:,0].min(),lye_train3.iloc[:,0].min(),lye_train4.iloc[:,0].min(),lye_train5.iloc[:,0].min(),lye_train6.iloc[:,0].min(),lye_train7.iloc[:,0].min(),lye_train8.iloc[:,0].min(),lye_train9.iloc[:,0].min(),lye_train10.iloc[:,0].min(),lye_train11.iloc[:,0].min(),lye_train12.iloc[:,0].min(),sit_train1.iloc[:,0].min(),sit_train2.iloc[:,0].min(),sit_train3.iloc[:,0].min(),sit_train4.iloc[:,0].min(),sit_train5.iloc[:,0].min(),sit_train6.iloc[:,0].min(),sit_train7.iloc[:,0].min(),sit_train8.iloc[:,0].min(),sit_train9.iloc[:,0].min(),sit_train10.iloc[:,0].min(),sit_train11.iloc[:,0].min(),sit_train12.iloc[:,0].min(),stand_train1.iloc[:,0].min(),stand_train2.iloc[:,0].min(),stand_train3.iloc[:,0].min(),stand_train4.iloc[:,0].min(),stand_train5.iloc[:,0].min(),stand_train6.iloc[:,0].min(),stand_train7.iloc[:,0].min(),stand_train8.iloc[:,0].min(),stand_train9.iloc[:,0].min(),stand_train10.iloc[:,0].min(),stand_train11.iloc[:,0].min(),stand_train12.iloc[:,0].min(),walk_train1.iloc[:,0].min(),walk_train2.iloc[:,0].min(),walk_train3.iloc[:,0].min(),walk_train4.iloc[:,0].min(),walk_train5.iloc[:,0].min(),walk_train6.iloc[:,0].min(),walk_train7.iloc[:,0].min(),walk_train8.iloc[:,0].min(),walk_train9.iloc[:,0].min(),walk_train10.iloc[:,0].min(),walk_train11.iloc[:,0].min(),walk_train12.iloc[:,0].min()]
split_max1 = [bend1_train1.iloc[:,0].max(),bend1_train2.iloc[:,0].max(),bend1_train3.iloc[:,0].max(),bend1_train4.iloc[:,0].max(),bend1_train5.iloc[:,0].max(),bend2_train1.iloc[:,0].max(),bend2_train2.iloc[:,0].max(),bend2_train3.iloc[:,0].max(),bend2_train4.iloc[:,0].max(),cycle_train1.iloc[:,0].max(),cycle_train2.iloc[:,0].max(),cycle_train3.iloc[:,0].max(),cycle_train4.iloc[:,0].max(),cycle_train5.iloc[:,0].max(),cycle_train6.iloc[:,0].max(),cycle_train7.iloc[:,0].max(),cycle_train8.iloc[:,0].max(),cycle_train9.iloc[:,0].max(),cycle_train10.iloc[:,0].max(),cycle_train11.iloc[:,0].max(),cycle_train12.iloc[:,0].max(),lye_train1.iloc[:,0].max(),lye_train2.iloc[:,0].max(),lye_train3.iloc[:,0].max(),lye_train4.iloc[:,0].max(),lye_train5.iloc[:,0].max(),lye_train6.iloc[:,0].max(),lye_train7.iloc[:,0].max(),lye_train8.iloc[:,0].max(),lye_train9.iloc[:,0].max(),lye_train10.iloc[:,0].max(),lye_train11.iloc[:,0].max(),lye_train12.iloc[:,0].max(),sit_train1.iloc[:,0].max(),sit_train2.iloc[:,0].max(),sit_train3.iloc[:,0].max(),sit_train4.iloc[:,0].max(),sit_train5.iloc[:,0].max(),sit_train6.iloc[:,0].max(),sit_train7.iloc[:,0].max(),sit_train8.iloc[:,0].max(),sit_train9.iloc[:,0].max(),sit_train10.iloc[:,0].max(),sit_train11.iloc[:,0].max(),sit_train12.iloc[:,0].max(),stand_train1.iloc[:,0].max(),stand_train2.iloc[:,0].max(),stand_train3.iloc[:,0].max(),stand_train4.iloc[:,0].max(),stand_train5.iloc[:,0].max(),stand_train6.iloc[:,0].max(),stand_train7.iloc[:,0].max(),stand_train8.iloc[:,0].max(),stand_train9.iloc[:,0].max(),stand_train10.iloc[:,0].max(),stand_train11.iloc[:,0].max(),stand_train12.iloc[:,0].max(),walk_train1.iloc[:,0].max(),walk_train2.iloc[:,0].max(),walk_train3.iloc[:,0].max(),walk_train4.iloc[:,0].max(),walk_train5.iloc[:,0].max(),walk_train6.iloc[:,0].max(),walk_train7.iloc[:,0].max(),walk_train8.iloc[:,0].max(),walk_train9.iloc[:,0].max(),walk_train10.iloc[:,0].max(),walk_train11.iloc[:,0].max(),walk_train12.iloc[:,0].max()]
split_mean1 = [bend1_train1.iloc[:,0].mean(),bend1_train2.iloc[:,0].mean(),bend1_train3.iloc[:,0].mean(),bend1_train4.iloc[:,0].mean(),bend1_train5.iloc[:,0].mean(),bend2_train1.iloc[:,0].mean(),bend2_train2.iloc[:,0].mean(),bend2_train3.iloc[:,0].mean(),bend2_train4.iloc[:,0].mean(),cycle_train1.iloc[:,0].mean(),cycle_train2.iloc[:,0].mean(),cycle_train3.iloc[:,0].mean(),cycle_train4.iloc[:,0].mean(),cycle_train5.iloc[:,0].mean(),cycle_train6.iloc[:,0].mean(),cycle_train7.iloc[:,0].mean(),cycle_train8.iloc[:,0].mean(),cycle_train9.iloc[:,0].mean(),cycle_train10.iloc[:,0].mean(),cycle_train11.iloc[:,0].mean(),cycle_train12.iloc[:,0].mean(),lye_train1.iloc[:,0].mean(),lye_train2.iloc[:,0].mean(),lye_train3.iloc[:,0].mean(),lye_train4.iloc[:,0].mean(),lye_train5.iloc[:,0].mean(),lye_train6.iloc[:,0].mean(),lye_train7.iloc[:,0].mean(),lye_train8.iloc[:,0].mean(),lye_train9.iloc[:,0].mean(),lye_train10.iloc[:,0].mean(),lye_train11.iloc[:,0].mean(),lye_train12.iloc[:,0].mean(),sit_train1.iloc[:,0].mean(),sit_train2.iloc[:,0].mean(),sit_train3.iloc[:,0].mean(),sit_train4.iloc[:,0].mean(),sit_train5.iloc[:,0].mean(),sit_train6.iloc[:,0].mean(),sit_train7.iloc[:,0].mean(),sit_train8.iloc[:,0].mean(),sit_train9.iloc[:,0].mean(),sit_train10.iloc[:,0].mean(),sit_train11.iloc[:,0].mean(),sit_train12.iloc[:,0].mean(),stand_train1.iloc[:,0].mean(),stand_train2.iloc[:,0].mean(),stand_train3.iloc[:,0].mean(),stand_train4.iloc[:,0].mean(),stand_train5.iloc[:,0].mean(),stand_train6.iloc[:,0].mean(),stand_train7.iloc[:,0].mean(),stand_train8.iloc[:,0].mean(),stand_train9.iloc[:,0].mean(),stand_train10.iloc[:,0].mean(),stand_train11.iloc[:,0].mean(),stand_train12.iloc[:,0].mean(),walk_train1.iloc[:,0].mean(),walk_train2.iloc[:,0].mean(),walk_train3.iloc[:,0].mean(),walk_train4.iloc[:,0].mean(),walk_train5.iloc[:,0].mean(),walk_train6.iloc[:,0].mean(),walk_train7.iloc[:,0].mean(),walk_train8.iloc[:,0].mean(),walk_train9.iloc[:,0].mean(),walk_train10.iloc[:,0].mean(),walk_train11.iloc[:,0].mean(),walk_train12.iloc[:,0].mean()]
split_min2 = [bend1_train1.iloc[:,1].min(),bend1_train2.iloc[:,1].min(),bend1_train3.iloc[:,1].min(),bend1_train4.iloc[:,1].min(),bend1_train5.iloc[:,1].min(),bend2_train1.iloc[:,1].min(),bend2_train2.iloc[:,1].min(),bend2_train3.iloc[:,1].min(),bend2_train4.iloc[:,1].min(),cycle_train1.iloc[:,1].min(),cycle_train2.iloc[:,1].min(),cycle_train3.iloc[:,1].min(),cycle_train4.iloc[:,1].min(),cycle_train5.iloc[:,1].min(),cycle_train6.iloc[:,1].min(),cycle_train7.iloc[:,1].min(),cycle_train8.iloc[:,1].min(),cycle_train9.iloc[:,1].min(),cycle_train10.iloc[:,1].min(),cycle_train11.iloc[:,1].min(),cycle_train12.iloc[:,1].min(),lye_train1.iloc[:,1].min(),lye_train2.iloc[:,1].min(),lye_train3.iloc[:,1].min(),lye_train4.iloc[:,1].min(),lye_train5.iloc[:,1].min(),lye_train6.iloc[:,1].min(),lye_train7.iloc[:,1].min(),lye_train8.iloc[:,1].min(),lye_train9.iloc[:,1].min(),lye_train10.iloc[:,1].min(),lye_train11.iloc[:,1].min(),lye_train12.iloc[:,1].min(),sit_train1.iloc[:,1].min(),sit_train2.iloc[:,1].min(),sit_train3.iloc[:,1].min(),sit_train4.iloc[:,1].min(),sit_train5.iloc[:,1].min(),sit_train6.iloc[:,1].min(),sit_train7.iloc[:,1].min(),sit_train8.iloc[:,1].min(),sit_train9.iloc[:,1].min(),sit_train10.iloc[:,1].min(),sit_train11.iloc[:,1].min(),sit_train12.iloc[:,1].min(),stand_train1.iloc[:,1].min(),stand_train2.iloc[:,1].min(),stand_train3.iloc[:,1].min(),stand_train4.iloc[:,1].min(),stand_train5.iloc[:,1].min(),stand_train6.iloc[:,1].min(),stand_train7.iloc[:,1].min(),stand_train8.iloc[:,1].min(),stand_train9.iloc[:,1].min(),stand_train10.iloc[:,1].min(),stand_train11.iloc[:,1].min(),stand_train12.iloc[:,1].min(),walk_train1.iloc[:,1].min(),walk_train2.iloc[:,1].min(),walk_train3.iloc[:,1].min(),walk_train4.iloc[:,1].min(),walk_train5.iloc[:,1].min(),walk_train6.iloc[:,1].min(),walk_train7.iloc[:,1].min(),walk_train8.iloc[:,1].min(),walk_train9.iloc[:,1].min(),walk_train10.iloc[:,1].min(),walk_train11.iloc[:,1].min(),walk_train12.iloc[:,1].min()]
split_max2 = [bend1_train1.iloc[:,1].max(),bend1_train2.iloc[:,1].max(),bend1_train3.iloc[:,1].max(),bend1_train4.iloc[:,1].max(),bend1_train5.iloc[:,1].max(),bend2_train1.iloc[:,1].max(),bend2_train2.iloc[:,1].max(),bend2_train3.iloc[:,1].max(),bend2_train4.iloc[:,1].max(),cycle_train1.iloc[:,1].max(),cycle_train2.iloc[:,1].max(),cycle_train3.iloc[:,1].max(),cycle_train4.iloc[:,1].max(),cycle_train5.iloc[:,1].max(),cycle_train6.iloc[:,1].max(),cycle_train7.iloc[:,1].max(),cycle_train8.iloc[:,1].max(),cycle_train9.iloc[:,1].max(),cycle_train10.iloc[:,1].max(),cycle_train11.iloc[:,1].max(),cycle_train12.iloc[:,1].max(),lye_train1.iloc[:,1].max(),lye_train2.iloc[:,1].max(),lye_train3.iloc[:,1].max(),lye_train4.iloc[:,1].max(),lye_train5.iloc[:,1].max(),lye_train6.iloc[:,1].max(),lye_train7.iloc[:,1].max(),lye_train8.iloc[:,1].max(),lye_train9.iloc[:,1].max(),lye_train10.iloc[:,1].max(),lye_train11.iloc[:,1].max(),lye_train12.iloc[:,1].max(),sit_train1.iloc[:,1].max(),sit_train2.iloc[:,1].max(),sit_train3.iloc[:,1].max(),sit_train4.iloc[:,1].max(),sit_train5.iloc[:,1].max(),sit_train6.iloc[:,1].max(),sit_train7.iloc[:,1].max(),sit_train8.iloc[:,1].max(),sit_train9.iloc[:,1].max(),sit_train10.iloc[:,1].max(),sit_train11.iloc[:,1].max(),sit_train12.iloc[:,1].max(),stand_train1.iloc[:,1].max(),stand_train2.iloc[:,1].max(),stand_train3.iloc[:,1].max(),stand_train4.iloc[:,1].max(),stand_train5.iloc[:,1].max(),stand_train6.iloc[:,1].max(),stand_train7.iloc[:,1].max(),stand_train8.iloc[:,1].max(),stand_train9.iloc[:,1].max(),stand_train10.iloc[:,1].max(),stand_train11.iloc[:,1].max(),stand_train12.iloc[:,1].max(),walk_train1.iloc[:,1].max(),walk_train2.iloc[:,1].max(),walk_train3.iloc[:,1].max(),walk_train4.iloc[:,1].max(),walk_train5.iloc[:,1].max(),walk_train6.iloc[:,1].max(),walk_train7.iloc[:,1].max(),walk_train8.iloc[:,1].max(),walk_train9.iloc[:,1].max(),walk_train10.iloc[:,1].max(),walk_train11.iloc[:,1].max(),walk_train12.iloc[:,1].max()]
split_mean2 = [bend1_train1.iloc[:,1].mean(),bend1_train2.iloc[:,1].mean(),bend1_train3.iloc[:,1].mean(),bend1_train4.iloc[:,1].mean(),bend1_train5.iloc[:,1].mean(),bend2_train1.iloc[:,1].mean(),bend2_train2.iloc[:,1].mean(),bend2_train3.iloc[:,1].mean(),bend2_train4.iloc[:,1].mean(),cycle_train1.iloc[:,1].mean(),cycle_train2.iloc[:,1].mean(),cycle_train3.iloc[:,1].mean(),cycle_train4.iloc[:,1].mean(),cycle_train5.iloc[:,1].mean(),cycle_train6.iloc[:,1].mean(),cycle_train7.iloc[:,1].mean(),cycle_train8.iloc[:,1].mean(),cycle_train9.iloc[:,1].mean(),cycle_train10.iloc[:,1].mean(),cycle_train11.iloc[:,1].mean(),cycle_train12.iloc[:,1].mean(),lye_train1.iloc[:,1].mean(),lye_train2.iloc[:,1].mean(),lye_train3.iloc[:,1].mean(),lye_train4.iloc[:,1].mean(),lye_train5.iloc[:,1].mean(),lye_train6.iloc[:,1].mean(),lye_train7.iloc[:,1].mean(),lye_train8.iloc[:,1].mean(),lye_train9.iloc[:,1].mean(),lye_train10.iloc[:,1].mean(),lye_train11.iloc[:,1].mean(),lye_train12.iloc[:,1].mean(),sit_train1.iloc[:,1].mean(),sit_train2.iloc[:,1].mean(),sit_train3.iloc[:,1].mean(),sit_train4.iloc[:,1].mean(),sit_train5.iloc[:,1].mean(),sit_train6.iloc[:,1].mean(),sit_train7.iloc[:,1].mean(),sit_train8.iloc[:,1].mean(),sit_train9.iloc[:,1].mean(),sit_train10.iloc[:,1].mean(),sit_train11.iloc[:,1].mean(),sit_train12.iloc[:,1].mean(),stand_train1.iloc[:,1].mean(),stand_train2.iloc[:,1].mean(),stand_train3.iloc[:,1].mean(),stand_train4.iloc[:,1].mean(),stand_train5.iloc[:,1].mean(),stand_train6.iloc[:,1].mean(),stand_train7.iloc[:,1].mean(),stand_train8.iloc[:,1].mean(),stand_train9.iloc[:,1].mean(),stand_train10.iloc[:,1].mean(),stand_train11.iloc[:,1].mean(),stand_train12.iloc[:,1].mean(),walk_train1.iloc[:,1].mean(),walk_train2.iloc[:,1].mean(),walk_train3.iloc[:,1].mean(),walk_train4.iloc[:,1].mean(),walk_train5.iloc[:,1].mean(),walk_train6.iloc[:,1].mean(),walk_train7.iloc[:,1].mean(),walk_train8.iloc[:,1].mean(),walk_train9.iloc[:,1].mean(),walk_train10.iloc[:,1].mean(),walk_train11.iloc[:,1].mean(),walk_train12.iloc[:,1].mean()]
split_min3 = [bend1_train1.iloc[:,-1].min(),bend1_train2.iloc[:,-1].min(),bend1_train3.iloc[:,-1].min(),bend1_train4.iloc[:,-1].min(),bend1_train5.iloc[:,-1].min(),bend2_train1.iloc[:,-1].min(),bend2_train2.iloc[:,-1].min(),bend2_train3.iloc[:,-1].min(),bend2_train4.iloc[:,-1].min(),cycle_train1.iloc[:,-1].min(),cycle_train2.iloc[:,-1].min(),cycle_train3.iloc[:,-1].min(),cycle_train4.iloc[:,-1].min(),cycle_train5.iloc[:,-1].min(),cycle_train6.iloc[:,-1].min(),cycle_train7.iloc[:,-1].min(),cycle_train8.iloc[:,-1].min(),cycle_train9.iloc[:,-1].min(),cycle_train10.iloc[:,-1].min(),cycle_train11.iloc[:,-1].min(),cycle_train12.iloc[:,-1].min(),lye_train1.iloc[:,-1].min(),lye_train2.iloc[:,-1].min(),lye_train3.iloc[:,-1].min(),lye_train4.iloc[:,-1].min(),lye_train5.iloc[:,-1].min(),lye_train6.iloc[:,-1].min(),lye_train7.iloc[:,-1].min(),lye_train8.iloc[:,-1].min(),lye_train9.iloc[:,-1].min(),lye_train10.iloc[:,-1].min(),lye_train11.iloc[:,-1].min(),lye_train12.iloc[:,-1].min(),sit_train1.iloc[:,-1].min(),sit_train2.iloc[:,-1].min(),sit_train3.iloc[:,-1].min(),sit_train4.iloc[:,-1].min(),sit_train5.iloc[:,-1].min(),sit_train6.iloc[:,-1].min(),sit_train7.iloc[:,-1].min(),sit_train8.iloc[:,-1].min(),sit_train9.iloc[:,-1].min(),sit_train10.iloc[:,-1].min(),sit_train11.iloc[:,-1].min(),sit_train12.iloc[:,-1].min(),stand_train1.iloc[:,-1].min(),stand_train2.iloc[:,-1].min(),stand_train3.iloc[:,-1].min(),stand_train4.iloc[:,-1].min(),stand_train5.iloc[:,-1].min(),stand_train6.iloc[:,-1].min(),stand_train7.iloc[:,-1].min(),stand_train8.iloc[:,-1].min(),stand_train9.iloc[:,-1].min(),stand_train10.iloc[:,-1].min(),stand_train11.iloc[:,-1].min(),stand_train12.iloc[:,-1].min(),walk_train1.iloc[:,-1].min(),walk_train2.iloc[:,-1].min(),walk_train3.iloc[:,-1].min(),walk_train4.iloc[:,-1].min(),walk_train5.iloc[:,-1].min(),walk_train6.iloc[:,-1].min(),walk_train7.iloc[:,-1].min(),walk_train8.iloc[:,-1].min(),walk_train9.iloc[:,-1].min(),walk_train10.iloc[:,-1].min(),walk_train11.iloc[:,-1].min(),walk_train12.iloc[:,-1].min()]
split_max3 = [bend1_train1.iloc[:,-1].max(),bend1_train2.iloc[:,-1].max(),bend1_train3.iloc[:,-1].max(),bend1_train4.iloc[:,-1].max(),bend1_train5.iloc[:,-1].max(),bend2_train1.iloc[:,-1].max(),bend2_train2.iloc[:,-1].max(),bend2_train3.iloc[:,-1].max(),bend2_train4.iloc[:,-1].max(),cycle_train1.iloc[:,-1].max(),cycle_train2.iloc[:,-1].max(),cycle_train3.iloc[:,-1].max(),cycle_train4.iloc[:,-1].max(),cycle_train5.iloc[:,-1].max(),cycle_train6.iloc[:,-1].max(),cycle_train7.iloc[:,-1].max(),cycle_train8.iloc[:,-1].max(),cycle_train9.iloc[:,-1].max(),cycle_train10.iloc[:,-1].max(),cycle_train11.iloc[:,-1].max(),cycle_train12.iloc[:,-1].max(),lye_train1.iloc[:,-1].max(),lye_train2.iloc[:,-1].max(),lye_train3.iloc[:,-1].max(),lye_train4.iloc[:,-1].max(),lye_train5.iloc[:,-1].max(),lye_train6.iloc[:,-1].max(),lye_train7.iloc[:,-1].max(),lye_train8.iloc[:,-1].max(),lye_train9.iloc[:,-1].max(),lye_train10.iloc[:,-1].max(),lye_train11.iloc[:,-1].max(),lye_train12.iloc[:,-1].max(),sit_train1.iloc[:,-1].max(),sit_train2.iloc[:,-1].max(),sit_train3.iloc[:,-1].max(),sit_train4.iloc[:,-1].max(),sit_train5.iloc[:,-1].max(),sit_train6.iloc[:,-1].max(),sit_train7.iloc[:,-1].max(),sit_train8.iloc[:,-1].max(),sit_train9.iloc[:,-1].max(),sit_train10.iloc[:,-1].max(),sit_train11.iloc[:,-1].max(),sit_train12.iloc[:,-1].max(),stand_train1.iloc[:,-1].max(),stand_train2.iloc[:,-1].max(),stand_train3.iloc[:,-1].max(),stand_train4.iloc[:,-1].max(),stand_train5.iloc[:,-1].max(),stand_train6.iloc[:,-1].max(),stand_train7.iloc[:,-1].max(),stand_train8.iloc[:,-1].max(),stand_train9.iloc[:,-1].max(),stand_train10.iloc[:,-1].max(),stand_train11.iloc[:,-1].max(),stand_train12.iloc[:,-1].max(),walk_train1.iloc[:,-1].max(),walk_train2.iloc[:,-1].max(),walk_train3.iloc[:,-1].max(),walk_train4.iloc[:,-1].max(),walk_train5.iloc[:,-1].max(),walk_train6.iloc[:,-1].max(),walk_train7.iloc[:,-1].max(),walk_train8.iloc[:,-1].max(),walk_train9.iloc[:,-1].max(),walk_train10.iloc[:,-1].max(),walk_train11.iloc[:,-1].max(),walk_train12.iloc[:,-1].max()]
split_mean3 = [bend1_train1.iloc[:,-1].mean(),bend1_train2.iloc[:,-1].mean(),bend1_train3.iloc[:,-1].mean(),bend1_train4.iloc[:,-1].mean(),bend1_train5.iloc[:,-1].mean(),bend2_train1.iloc[:,-1].mean(),bend2_train2.iloc[:,-1].mean(),bend2_train3.iloc[:,-1].mean(),bend2_train4.iloc[:,-1].mean(),cycle_train1.iloc[:,-1].mean(),cycle_train2.iloc[:,-1].mean(),cycle_train3.iloc[:,-1].mean(),cycle_train4.iloc[:,-1].mean(),cycle_train5.iloc[:,-1].mean(),cycle_train6.iloc[:,-1].mean(),cycle_train7.iloc[:,-1].mean(),cycle_train8.iloc[:,-1].mean(),cycle_train9.iloc[:,-1].mean(),cycle_train10.iloc[:,-1].mean(),cycle_train11.iloc[:,-1].mean(),cycle_train12.iloc[:,-1].mean(),lye_train1.iloc[:,-1].mean(),lye_train2.iloc[:,-1].mean(),lye_train3.iloc[:,-1].mean(),lye_train4.iloc[:,-1].mean(),lye_train5.iloc[:,-1].mean(),lye_train6.iloc[:,-1].mean(),lye_train7.iloc[:,-1].mean(),lye_train8.iloc[:,-1].mean(),lye_train9.iloc[:,-1].mean(),lye_train10.iloc[:,-1].mean(),lye_train11.iloc[:,-1].mean(),lye_train12.iloc[:,-1].mean(),sit_train1.iloc[:,-1].mean(),sit_train2.iloc[:,-1].mean(),sit_train3.iloc[:,-1].mean(),sit_train4.iloc[:,-1].mean(),sit_train5.iloc[:,-1].mean(),sit_train6.iloc[:,-1].mean(),sit_train7.iloc[:,-1].mean(),sit_train8.iloc[:,-1].mean(),sit_train9.iloc[:,-1].mean(),sit_train10.iloc[:,-1].mean(),sit_train11.iloc[:,-1].mean(),sit_train12.iloc[:,-1].mean(),stand_train1.iloc[:,-1].mean(),stand_train2.iloc[:,-1].mean(),stand_train3.iloc[:,-1].mean(),stand_train4.iloc[:,-1].mean(),stand_train5.iloc[:,-1].mean(),stand_train6.iloc[:,-1].mean(),stand_train7.iloc[:,-1].mean(),stand_train8.iloc[:,-1].mean(),stand_train9.iloc[:,-1].mean(),stand_train10.iloc[:,-1].mean(),stand_train11.iloc[:,-1].mean(),stand_train12.iloc[:,-1].mean(),walk_train1.iloc[:,-1].mean(),walk_train2.iloc[:,-1].mean(),walk_train3.iloc[:,-1].mean(),walk_train4.iloc[:,-1].mean(),walk_train5.iloc[:,-1].mean(),walk_train6.iloc[:,-1].mean(),walk_train7.iloc[:,-1].mean(),walk_train8.iloc[:,-1].mean(),walk_train9.iloc[:,-1].mean(),walk_train10.iloc[:,-1].mean(),walk_train11.iloc[:,-1].mean(),walk_train12.iloc[:,-1].mean()]

# %%
split_table = pd.DataFrame()
split_table.insert(0,"Min1",split_min1)
split_table.insert(1,"Max1",split_max1)
split_table.insert(2,"Mean1",split_mean1)
split_table.insert(3,"Min2",split_min2)
split_table.insert(4,"Max2",split_max2)
split_table.insert(5,"Mean2",split_mean2)
split_table.insert(6,"Min3",split_min3)
split_table.insert(7,"Max3",split_max3)
split_table.insert(8,"Mean3",split_mean3)

# %%
bend_min = {'avg_rss12' : split_table.iloc[0:9,0], 'var_rss12' : split_table.iloc[0:9,3], 'var_rss23' : split_table.iloc[0:9,6]}
bend_split_min = pd.DataFrame(bend_min)
bend_max = {'avg_rss12' : split_table.iloc[0:9,1], 'var_rss12' : split_table.iloc[0:9,4], 'var_rss23' : split_table.iloc[0:9,7]}
bend_split_max = pd.DataFrame(bend_max)
bend_mean = {'avg_rss12' : split_table.iloc[0:9,2], 'var_rss12' : split_table.iloc[0:9,5], 'var_rss23' : split_table.iloc[0:9,-1]}
bend_split_mean = pd.DataFrame(bend_mean)

# %%
activity_min = {'avg_rss12' : split_table.iloc[10:,0], 'var_rss12' : split_table.iloc[10:,3], 'var_rss23' : split_table.iloc[10:,6]}
activity_split_min = pd.DataFrame(activity_min)
activity_split_min = activity_split_min.reset_index()
activity_max = {'avg_rss12' : split_table.iloc[10:,1], 'var_rss12' : split_table.iloc[10:,4], 'var_rss23' : split_table.iloc[10:,7]}
activity_split_max = pd.DataFrame(activity_max)
activity_split_max = activity_split_max.reset_index()
activity_mean = {'avg_rss12' : split_table.iloc[10:,2], 'var_rss12' : split_table.iloc[10:,5], 'var_rss23' : split_table.iloc[10:,-1]}
activity_split_mean = pd.DataFrame(activity_mean)
activity_split_mean = activity_split_mean.reset_index()

# %% [markdown]
# __Scatter plot of Minimum feature, Pink denotes Bending & yellow denotes Other activities.__

# %%
axis = bend_split_min.plot(style='mo',legend=False)
activity_split_min.iloc[:,1:4].plot(style='yo',ax=axis,legend=False)
print("Bending - Pink dots")
print("Other Activities - Yellow dots")
plt.show()
# Out:
# Bending - Pink dots
# Other Activities - Yellow dots

# %% [markdown]
# <br>__Scatter plot of Maximum feature, Pink denotes Bending & yellow denotes Other activities.__

# %%
axis = bend_split_max.plot(style='mo',legend=False)
activity_split_max.iloc[:,1:4].plot(style='yo',ax=axis,legend=False)
print("Bending - Pink dots")
print("Other Activities - Yellow dots")
plt.show()
# Out:
# Bending - Pink dots
# Other Activities - Yellow dots

# %% [markdown]
# <br>__Scatter plot of Minimum feature, Pink denotes Bending & yellow denotes Other activities.__

# %%
axis = bend_split_mean.plot(style='mo',legend=False)
activity_split_mean.iloc[:,1:4].plot(style='yo',ax=axis,legend=False)
print("Bending - Pink dots")
print("Other Activities - Yellow dots")
plt.show()
# Out:
# Bending - Pink dots
# Other Activities - Yellow dots

# %% [markdown]
# __There is no difference between the above plots and that of 1(d)i. The graphs look similar.__

# %% [markdown]
# <br>__1. (d) iii.__

# %%
training_sets = [bending1_train_data1,bending1_train_data2,bending1_train_data3,bending1_train_data4,bending1_train_data5,bending2_train_data1,bending2_train_data2,bending2_train_data3,bending2_train_data4,cycling_train_data1,cycling_train_data2,cycling_train_data3,cycling_train_data4,cycling_train_data5,cycling_train_data6,cycling_train_data7,cycling_train_data8,cycling_train_data9,cycling_train_data10,cycling_train_data11,cycling_train_data12,lying_train_data1,lying_train_data2,lying_train_data3,lying_train_data4,lying_train_data5,lying_train_data6,lying_train_data7,lying_train_data8,lying_train_data9,lying_train_data10,lying_train_data11,lying_train_data12,sitting_train_data1,sitting_train_data2,sitting_train_data3,sitting_train_data4,sitting_train_data5,sitting_train_data6,sitting_train_data7,sitting_train_data8,sitting_train_data9,sitting_train_data10,sitting_train_data11,sitting_train_data12,standing_train_data1,standing_train_data2,standing_train_data3,standing_train_data4,standing_train_data5,standing_train_data6,standing_train_data7,standing_train_data8,standing_train_data9,standing_train_data10,standing_train_data11,standing_train_data12,walking_train_data1,walking_train_data2,walking_train_data3,walking_train_data4,walking_train_data5,walking_train_data6,walking_train_data7,walking_train_data8,walking_train_data9,walking_train_data10,walking_train_data11,walking_train_data12]

train_df_list = ["Training_set1","Training_set2","Training_set3","Training_set4","Training_set5","Training_set6","Training_set7","Training_set8","Training_set9","Training_set10","Training_set11","Training_set12","Training_set13","Training_set14","Training_set15","Training_set16","Training_set17","Training_set18","Training_set19","Training_set20"]

# %%
for i in range(0,20): 
    train_df_list[i] = pd.DataFrame(columns=["avg_rss12_min","var_rss12_min","avg_rss13_min","var_rss13_min","avg_rss23_min","var_rss23_min","avg_rss12_max","var_rss12_max","avg_rss13_max","var_rss13_max","avg_rss23_max","var_rss23_max","avg_rss12_mean","var_rss12_mean","avg_rss13_mean","var_rss13_mean","avg_rss23_mean","var_rss23_mean","avg_rss12_median","var_rss12_median","avg_rss13_median","var_rss13_median","avg_rss23_median","var_rss23_median","avg_rss12_sd","var_rss12_sd","avg_rss13_sd","var_rss13_sd","avg_rss23_sd","var_rss23_sd","avg_rss12_1stQuant","var_rss12_1stQuant","avg_rss13_1stQuant","var_rss13_1stQuant","avg_rss23_1stQuant","var_rss23_1stQuant","avg_rss12_3rdQuant","var_rss12_3rdQuant","avg_rss13_3rdQuant","var_rss13_3rdQuant","avg_rss23_3rdQuant","var_rss23_3rdQuant"])
    for j in range(0,69): 
        temp =  np.array_split(training_sets[j],i+1)
        for h in range(0,i+1):
            l_min = temp[h].min()
            l_max = temp[h].max()
            l_mean = temp[h].mean()
            l_median = temp[h].median()
            l_sd = temp[h].std()
            l_1stQuant = temp[h].quantile(0.25)
            l_3rdQuant = temp[h].quantile(0.75)
            series = [l_min[1:],l_max[1:],l_mean[1:],l_median[1:],l_sd[1:],l_1stQuant[1:],l_3rdQuant[1:]]
            train_df_list[i] = train_df_list[i].append(pd.Series(list(itertools.chain.from_iterable(series)),index=train_df_list[i].columns),ignore_index=True)

# %%
k = [0]*9
l = [1]*60
count = 1
y_Train = (k*count)+(l*count)
accuracy = 0
best_l = 0
rfeTrain_avg_scores = []
for i in range(0,20):    
    y_Train = (k*count)+(l*count)
    model = LogisticRegression()
    rfe = RFE(model,7)
    rfe = rfe.fit(train_df_list[i],y_Train)
    #print(rfe.support_)
    #print(rfe.ranking_)
    count = count+1
    scores = cross_val_score(rfe, train_df_list[i], y_Train, cv=5)
    print("5-fold cross validation average accuracy for l=",i+1,": %.3f" % (scores.mean()))
    max_l=scores.mean()
    rfeTrain_avg_scores = np.append(rfeTrain_avg_scores,scores.mean())
    if(max_l>accuracy):
        accuracy=max_l
        best_l=i+1
print("Best value of pair (l,p) is (",best_l,",7) with accuracy=",accuracy)
# Out:
# 5-fold cross validation average accuracy for l= 1 : 0.986
# 5-fold cross validation average accuracy for l= 2 : 0.900
# 5-fold cross validation average accuracy for l= 3 : 0.869
# 5-fold cross validation average accuracy for l= 4 : 0.891
# 5-fold cross validation average accuracy for l= 5 : 0.846
# 5-fold cross validation average accuracy for l= 6 : 0.862
# 5-fold cross validation average accuracy for l= 7 : 0.870
# 5-fold cross validation average accuracy for l= 8 : 0.866
# 5-fold cross validation average accuracy for l= 9 : 0.871
# 5-fold cross validation average accuracy for l= 10 : 0.912
# 5-fold cross validation average accuracy for l= 11 : 0.896
# 5-fold cross validation average accuracy for l= 12 : 0.917
# 5-fold cross validation average accuracy for l= 13 : 0.869
# 5-fold cross validation average accuracy for l= 14 : 0.896
# 5-fold cross validation average accuracy for l= 15 : 0.912
# 5-fold cross validation average accuracy for l= 16 : 0.890
# ...

# %% [markdown]
# __Best value of pair (l,p) is (1,7) as shown above. So we select the Training set l=1 going forward.__<br><br>

# %%
k = [0]*9
l = [1]*60
y = k+l
x = train_df_list[0].as_matrix()
Train_X, Test_X, Train_Y, Test_Y = train_test_split(x,y,test_size=0.30,random_state=0)

# %% [markdown]
# __1) d) iv)Confusion Matrix:__

# %%
model = LogisticRegression(solver='newton-cg',C=5.0)
model.fit(Train_X, Train_Y)
y_pred = model.predict(Test_X)
confusion_matrix = confusion_matrix(Test_Y,y_pred)
print(confusion_matrix)
# Out:
# [[ 2  0]
#  [ 0 19]]

# %% [markdown]
# <br>__ROC and AOC for the Classifier:__

# %%
probas_ = model.predict_proba(Test_X)[:,1]
fpr, tpr, _ = roc_curve(Test_Y, probas_)
roc_auc = auc(fpr, tpr)
print("AUC : ",roc_auc)
# Out:
# AUC :  1.0

# %%
plt.plot(fpr, tpr,color='darkorange',lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# <br>__Regression co-efficients and p-values associated.__

# %%
ols_model = sm.OLS(Train_Y,Train_X)
ols_result = ols_model.fit()
ols_result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                     154.7
# Date:                Mon, 25 Feb 2019   Prob (F-statistic):           2.41e-08
# Time:                        22:57:08   Log-Likelihood:                 95.334
# No. Observations:                  48   AIC:                            -110.7
# Df Residuals:                       8   BIC:                            -35.82
# Df Model:                          40
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0100      0.006      1.673      0.133      -0.004       0.024
# ...

# %% [markdown]
# <br>__1) d) v)__

# %%
Test_sets = [bending1_test_data1 ,bending1_test_data2 ,bending2_test_data1 ,bending2_test_data2 ,cycling_test_data1 ,cycling_test_data2 ,cycling_test_data3 ,lying_test_data1 ,lying_test_data2 ,lying_test_data3 ,sitting_test_data1 ,sitting_test_data2 ,sitting_test_data3 ,standing_test_data1 ,standing_test_data2 ,standing_test_data3 ,walking_test_data1 ,walking_test_data2 ,walking_test_data3]
test_df_list = ["Test_set1","Test_set2","Test_set3","Test_set4","Test_set5","Test_set6","Test_set7","Test_set8","Test_set9","Test_set10","Test_set11","Test_set12","Test_set13","Test_set14","Test_set15","Test_set16","Test_set17","Test_set18","Test_set19","Test_set20"]

# %%
for i in range(0,20): 
    test_df_list[i] = pd.DataFrame(columns=["avg_rss12_min","var_rss12_min","avg_rss13_min","var_rss13_min","avg_rss23_min","var_rss23_min","avg_rss12_max","var_rss12_max","avg_rss13_max","var_rss13_max","avg_rss23_max","var_rss23_max","avg_rss12_mean","var_rss12_mean","avg_rss13_mean","var_rss13_mean","avg_rss23_mean","var_rss23_mean","avg_rss12_median","var_rss12_median","avg_rss13_median","var_rss13_median","avg_rss23_median","var_rss23_median","avg_rss12_sd","var_rss12_sd","avg_rss13_sd","var_rss13_sd","avg_rss23_sd","var_rss23_sd","avg_rss12_1stQuant","var_rss12_1stQuant","avg_rss13_1stQuant","var_rss13_1stQuant","avg_rss23_1stQuant","var_rss23_1stQuant","avg_rss12_3rdQuant","var_rss12_3rdQuant","avg_rss13_3rdQuant","var_rss13_3rdQuant","avg_rss23_3rdQuant","var_rss23_3rdQuant"])
    for j in range(0,19): 
        temp =  np.array_split(Test_sets[j],i+1)
        for h in range(0,i+1):
            l_min = temp[h].min()
            l_max = temp[h].max()
            l_mean = temp[h].mean()
            l_median = temp[h].median()
            l_sd = temp[h].std()
            l_1stQuant = temp[h].quantile(0.25)
            l_3rdQuant = temp[h].quantile(0.75)
            series = [l_min[1:],l_max[1:],l_mean[1:],l_median[1:],l_sd[1:],l_1stQuant[1:],l_3rdQuant[1:]]
            test_df_list[i] = test_df_list[i].append(pd.Series(list(itertools.chain.from_iterable(series)),index=test_df_list[i].columns),ignore_index=True)

# %%
k = [0]*4
l = [1]*15
count = 1
y_Test = (k*count)+(l*count)
accuracy = 0
best_l = 0
for i in range(0,20):    
    y_Test = (k*count)+(l*count)
    model1 = LogisticRegression()
    rfe = RFE(model,7)
    rfe = rfe.fit(test_df_list[i],y_Test)
    #print(rfe.support_)
    #print(rfe.ranking_)
    count = count+1
    scores = cross_val_score(rfe, test_df_list[i], y_Test, cv=5)
    print("5-fold cross validation average accuracy for l=",i+1,": %.3f" % (scores.mean()))
    max_l=scores.mean()
    if(max_l>accuracy):
        accuracy=max_l
        best_l=i+1
print("Best value of pair (l,p) is (",best_l,",7) with accuracy=",accuracy)
# Out:
# C:\Users\subhi\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 4 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# 5-fold cross validation average accuracy for l= 1 : 0.950
# 5-fold cross validation average accuracy for l= 2 : 0.896
# 5-fold cross validation average accuracy for l= 3 : 0.965
# 5-fold cross validation average accuracy for l= 4 : 0.973
# 5-fold cross validation average accuracy for l= 5 : 0.979
# 5-fold cross validation average accuracy for l= 6 : 0.964
# 5-fold cross validation average accuracy for l= 7 : 0.970
# 5-fold cross validation average accuracy for l= 8 : 0.987
# 5-fold cross validation average accuracy for l= 9 : 0.988
# 5-fold cross validation average accuracy for l= 10 : 0.974
# 5-fold cross validation average accuracy for l= 11 : 0.985
# ...

# %% [markdown]
# __Comparing the best accuracy obtained for the Test set above to the best accuracy obtained for Training Set, we can say that the cross-validation for Test set is more accurate compared to Training Set.__

# %% [markdown]
# <br>__1) d) vi)__

# %%
k = [0]*68
l = [1]*255
y = k+l
x = test_df_list[16].as_matrix()
Train_X, Test_X, Train_Y, Test_Y = train_test_split(x,y,test_size=0.30,random_state=0)
ols_model = sm.OLS(Train_Y,Train_X)
ols_result = ols_model.fit()
ols_result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.966
# Model:                            OLS   Adj. R-squared:                  0.958
# Method:                 Least Squares   F-statistic:                     124.8
# Date:                Mon, 25 Feb 2019   Prob (F-statistic):          2.03e-114
# Time:                        22:58:05   Log-Likelihood:                 84.953
# No. Observations:                 226   AIC:                            -85.91
# Df Residuals:                     184   BIC:                             57.76
# Df Model:                          42
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0031      0.012      0.267      0.790      -0.020       0.026
# ...

# %% [markdown]
# __As we do not see any infinity values in the coefficients listed above, we can say that there is no instability in calculating logistic regression parameters.__

# %% [markdown]
# <br>__1) d) vii) Confusion Matrix for test set:__

# %%
model = LogisticRegression(solver='newton-cg',C=5.0)
model = model.fit(Train_X, Train_Y)
y_pred = model.predict(Test_X)
y_pred_Series = pd.Series(y_pred)
y_Test_Series = pd.Series(Test_Y)
print("Confusion Matrix: ")
pd.crosstab(y_Test_Series, y_pred_Series, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Confusion Matrix:
# Predicted   0   1  All
# True
# 0          26   0   26
# 1           0  71   71
# All        26  71   97

# %% [markdown]
# __From the above confusion matrix, we do not see any imbalanced classes__

# %% [markdown]
# <br><br>__1) (e) Binary Classification Using L1-penalized logistic regression__

# %%
k = [0]*9
l = [1]*60
count = 1
y_Train = (k*count)+(l*count)
accuracy = 0
best_l = 0
l1Train_avg_scores = []
for i in range(0,20):    
    y_Train = (k*count)+(l*count)
    model = LogisticRegression(penalty='l2',solver='liblinear',C=1)
    model = model.fit(train_df_list[i],y_Train)
    count = count+1
    scores = cross_val_score(model, train_df_list[i], y_Train, cv=5)
    print("5-fold cross validation average accuracy for l=",i+1,": %.3f" % (scores.mean()))
    max_l=scores.mean()
    l1Train_avg_scores = np.append(l1Train_avg_scores,scores.mean())
    if(max_l>accuracy):
        accuracy=max_l
        best_l=i+1
print("Best value of pair (l,p) is (",best_l,",7) with accuracy=",accuracy)
# Out:
# 5-fold cross validation average accuracy for l= 1 : 0.986
# 5-fold cross validation average accuracy for l= 2 : 0.892
# 5-fold cross validation average accuracy for l= 3 : 0.893
# 5-fold cross validation average accuracy for l= 4 : 0.924
# 5-fold cross validation average accuracy for l= 5 : 0.890
# 5-fold cross validation average accuracy for l= 6 : 0.894
# 5-fold cross validation average accuracy for l= 7 : 0.895
# 5-fold cross validation average accuracy for l= 8 : 0.904
# 5-fold cross validation average accuracy for l= 9 : 0.889
# 5-fold cross validation average accuracy for l= 10 : 0.912
# 5-fold cross validation average accuracy for l= 11 : 0.893
# 5-fold cross validation average accuracy for l= 12 : 0.897
# 5-fold cross validation average accuracy for l= 13 : 0.889
# 5-fold cross validation average accuracy for l= 14 : 0.899
# 5-fold cross validation average accuracy for l= 15 : 0.881
# 5-fold cross validation average accuracy for l= 16 : 0.885
# ...

# %% [markdown]
# <br>__1) (e) ii) Comparing the L1-penalized with variable selection using p-values by checking the scores obtained from 5-fold cross-validation of both the models.__

# %%
print("Max score obtained with variable selection using p-values: ",rfeTrain_avg_scores.max())
print("Mean score obtained with variable selection using p-values: ",rfeTrain_avg_scores.mean())
print("Max score obtained with variable selection using L1-penalized: ",l1Train_avg_scores.max())
print("Mean score obtained with variable selection using L1-penalized: ",l1Train_avg_scores.mean())
# Out:
# Max score obtained with variable selection using p-values:  0.9857142857142858
# Mean score obtained with variable selection using p-values:  0.887588444442611
# Max score obtained with variable selection using L1-penalized:  0.9857142857142858
# Mean score obtained with variable selection using L1-penalized:  0.8993977505072561

# %% [markdown]
# __From the above scores we can see that max score for both models are same. But mean score for L1-penalized is greater than p-value model. So we can say that L1-penalized model is slightly more efficient compared to p-value model & hence L1-penalized model performs better.__

# %% [markdown]
# __According to my opinion, both the models are equivalently easy to implement.__

# %% [markdown]
# __1) (f) Multi-class Classification (The Realistic Case)__

# %% [markdown]
# __i) L1-penalized multinomial regression model__

# %%
warnings.filterwarnings("ignore", category=FutureWarning)
bend = [0]*9
cycle = [1]*12
lye = [2]*12
sit = [3]*12
stand = [4]*12
walk = [5]*12
count = 1
accuracy = 0
best_l = 0
MCTrain_avg_scores = []
for i in range(0,20):    
    y_Train = (bend*count)+(cycle*count)+(lye*count)+(sit*count)+(stand*count)+(walk*count)
    model = LogisticRegression(penalty='l1',solver='saga',C=1,multi_class='multinomial',warm_start=True)
    model = model.fit(train_df_list[i],y_Train)
    count = count+1
    scores = cross_val_score(model, train_df_list[i], y_Train, cv=5)
    print("5-fold cross validation average accuracy for l=",i+1,": %.3f" % (scores.mean()))
    max_l=scores.mean()
    MCTrain_avg_scores = np.append(MCTrain_avg_scores,scores.mean())
    if(max_l>accuracy):
        accuracy=max_l
        best_l=i+1
# Out:
# 5-fold cross validation average accuracy for l= 1 : 0.885
# C:\Users\subhi\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\subhi\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\subhi\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\subhi\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# ...

# %%
print("Best value of pair (l,p) is (",best_l,",7) with accuracy=",accuracy)
print("Mean score obtained with L1-penalized multinomial regression :",MCTrain_avg_scores.mean())
# Out:
# Best value of pair (l,p) is ( 1 ,7) with accuracy= 0.8847593582887701
# Mean score obtained with L1-penalized multinomial regression : 0.7981348154863547

# %%
y = bend+cycle+lye+sit+stand+walk
X_train, X_test, y_train, y_test = train_test_split(train_df_list[0], y, test_size=.5,random_state=0)
model = LogisticRegression(penalty='l1',solver='saga',C=1,multi_class='multinomial',warm_start=True)
model = model.fit(X_train,y_train)
test_error = model.score(X_test,y_test)
print("Test Error: ",test_error)
# Out:
# Test Error:  0.7714285714285715
# C:\Users\subhi\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)

# %% [markdown]
# __ROC curves for each class:__

# %%
y = bend+cycle+lye+sit+stand+walk
y = label_binarize(y, classes=[0, 1, 2, 3, 4, 5])
random_state = np.random.RandomState(0)
n_classes = y.shape[1]
X_train, X_test, y_train, y_test = train_test_split(train_df_list[0], y, test_size=.5,random_state=0)
clf = OneVsRestClassifier(svm.SVC(kernel='linear', probability=True,
                                 random_state=random_state))
y_score = clf.fit(X_train, y_train).decision_function(X_test)
y_pred = clf.predict(X_test)
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    
# Plot of a ROC curve for a specific class
for i in range(n_classes):
    plt.figure()
    plt.plot(fpr[i], tpr[i], color='darkorange', lw=2,label='ROC curve of class {0} (area = {1:0.2f})'''.format(i, roc_auc[i]))
    plt.plot([0, 1], [0, 1], 'k--',color='navy',lw=2)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# __Confusion Matrix for each class:__

# %%
from sklearn.metrics import confusion_matrix
for i in range(n_classes):
    cm = confusion_matrix(y_test[:, i], y_pred[:, i])
    print("Confusion Matrix for class ",i," is :")
    print(cm)
    print()
# Out:
# Confusion Matrix for class  0  is :
# [[31  0]
#  [ 2  2]]
#
# Confusion Matrix for class  1  is :
# [[30  2]
#  [ 0  3]]
#
# Confusion Matrix for class  2  is :
# [[27  1]
#  [ 0  7]]
#
# Confusion Matrix for class  3  is :
# [[19 10]
#  [ 0  6]]
#
# Confusion Matrix for class  4  is :
# [[27  0]
#  [ 6  2]]
#
# Confusion Matrix for class  5  is :
# [[28  0]
#  [ 0  7]]

# %% [markdown]
# <br>__1) (f) ii) Multi-class Classification using Gaussian Naive Bayers'.__

# %%
bend = [0]*9
cycle = [1]*12
lye = [2]*12
sit = [3]*12
stand = [4]*12
walk = [5]*12
count = 1
accuracy = 0
best_l = 0
GNB_avg_scores = []
for i in range(0,20):    
    y_Train = (bend*count)+(cycle*count)+(lye*count)+(sit*count)+(stand*count)+(walk*count)
    model = GaussianNB()
    model = model.fit(train_df_list[i],y_Train)
    count = count+1
    scores = cross_val_score(model, train_df_list[i], y_Train, cv=5)
    print("5-fold cross validation average accuracy for l=",i+1,": %.3f" % (scores.mean()))
    max_l=scores.mean()
    GNB_avg_scores = np.append(GNB_avg_scores,scores.mean())
    if(max_l>accuracy):
        accuracy=max_l
        best_l=i+1
print("Best value of pair (l,p) is (",best_l,",7) with accuracy=",accuracy)
print("Mean score obtained with Gaussian Naive Bayers' :",GNB_avg_scores.mean())
# Out:
# 5-fold cross validation average accuracy for l= 1 : 0.816
# 5-fold cross validation average accuracy for l= 2 : 0.897
# 5-fold cross validation average accuracy for l= 3 : 0.801
# 5-fold cross validation average accuracy for l= 4 : 0.791
# 5-fold cross validation average accuracy for l= 5 : 0.780
# 5-fold cross validation average accuracy for l= 6 : 0.784
# 5-fold cross validation average accuracy for l= 7 : 0.799
# 5-fold cross validation average accuracy for l= 8 : 0.769
# 5-fold cross validation average accuracy for l= 9 : 0.779
# 5-fold cross validation average accuracy for l= 10 : 0.757
# 5-fold cross validation average accuracy for l= 11 : 0.755
# 5-fold cross validation average accuracy for l= 12 : 0.756
# 5-fold cross validation average accuracy for l= 13 : 0.760
# 5-fold cross validation average accuracy for l= 14 : 0.749
# 5-fold cross validation average accuracy for l= 15 : 0.751
# 5-fold cross validation average accuracy for l= 16 : 0.752
# ...

# %% [markdown]
# __Multi-class Classification using Multinomial Naive Bayers'.__

# %%
bend = [0]*9
cycle = [1]*12
lye = [2]*12
sit = [3]*12
stand = [4]*12
walk = [5]*12
count = 1
accuracy = 0
best_l = 0
MNB_avg_scores = []
for i in range(0,20):    
    y_Train = (bend*count)+(cycle*count)+(lye*count)+(sit*count)+(stand*count)+(walk*count)
    model = MultinomialNB()
    model = model.fit(train_df_list[i],y_Train)
    count = count+1
    scores = cross_val_score(model, train_df_list[i], y_Train, cv=5)
    print("5-fold cross validation average accuracy for l=",i+1,": %.3f" % (scores.mean()))
    max_l=scores.mean()
    MNB_avg_scores = np.append(MNB_avg_scores,scores.mean())
    if(max_l>accuracy):
        accuracy=max_l
        best_l=i+1
print("Best value of pair (l,p) is (",best_l,",7) with accuracy=",accuracy)
print("Mean score obtained with Multinomial Naive Bayers' :",MNB_avg_scores.mean())
# Out:
# 5-fold cross validation average accuracy for l= 1 : 0.838
# 5-fold cross validation average accuracy for l= 2 : 0.748
# 5-fold cross validation average accuracy for l= 3 : 0.757
# 5-fold cross validation average accuracy for l= 4 : 0.735
# 5-fold cross validation average accuracy for l= 5 : 0.742
# 5-fold cross validation average accuracy for l= 6 : 0.735
# 5-fold cross validation average accuracy for l= 7 : 0.724
# 5-fold cross validation average accuracy for l= 8 : 0.745
# 5-fold cross validation average accuracy for l= 9 : 0.741
# 5-fold cross validation average accuracy for l= 10 : 0.739
# 5-fold cross validation average accuracy for l= 11 : 0.728
# 5-fold cross validation average accuracy for l= 12 : 0.730
# 5-fold cross validation average accuracy for l= 13 : 0.740
# 5-fold cross validation average accuracy for l= 14 : 0.725
# 5-fold cross validation average accuracy for l= 15 : 0.728
# 5-fold cross validation average accuracy for l= 16 : 0.722
# ...

# %% [markdown]
# __Comparing the results of Gaussian Naive Bayers and Multinomial Naive Bayers, we can see that Best accuracy & Average score for Gaussian Naive Bayers' is greater than that of Multinomial Naive Bayers. Hence we can say that Gaussian Naive Bayers performs better than Multinomial Naive Bayers.__
